# %% [markdown]
# <a href="https://colab.research.google.com/github/nonotoy/poysuwop/blob/main/02_Poysuwop_Cyclic_Translation_AJA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Poysuwop_Nr2 / Cyclic Translation Ain -> Jpn -> Ain

# %% [markdown]
# ## MBart

# %% [markdown]
# ### 0_Library install

# %%
# !pip install transformers[torch] datasets sentencepiece sacremoses sacrebleu mecab-python3 unidic-lite
# !pip install accelerate -U

# %%
# Library
import glob
import json
import re
import collections
import os
import sys

import pandas as pd
import torch
from transformers import (
    pipeline,
    MBartForConditionalGeneration,
    MBart50Tokenizer,
    Seq2SeqTrainingArguments,
    Seq2SeqTrainer,
    EarlyStoppingCallback,
    RobertaTokenizerFast,
    GenerationConfig
)
from datasets import DatasetDict, Dataset
from sklearn.model_selection import train_test_split
import sacrebleu
import MeCab

# Change Current Directory
os.chdir('/content/drive/MyDrive/Colab Notebooks/Poysuwop')

# Load preprocess module
from modules import ainPreprocess

# %% [markdown]
# ### 1_Load Dataset

# %%
# Setup - model & tokenizer
model_name = 'facebook/mbart-large-50-many-to-many-mmt'
tokenizer = MBart50Tokenizer.from_pretrained(model_name)
model = MBartForConditionalGeneration.from_pretrained(model_name)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Load dataset
file_path = 'poysuwop_corpus.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()

data = [line.strip().split('\t') for line in lines]

line_no, ain_txt, jpn_txt = zip(*[(parts[0], parts[1], parts[2]) for parts in data])

# Store to df
df = pd.DataFrame({
    'no.': line_no,
    'ain': ain_txt,
    'jpn': jpn_txt
})

dataset = Dataset.from_pandas(df)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/529 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/649 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/261 [00:00<?, ?B/s]

# %% [markdown]
# ### 2_Train translator

# %%
def train_translator(src_lang, tgt_lang, cycle=0)

    # Load tokenizer
    if src_lang == 'ain' and tgt_lang == 'jpn':
        tokenizer = RobertaTokenizerFast.from_pretrained("AinuBERTTokenizer")

    elif src_lang == 'jpn' and tgt_lang == 'ain':
        tokenizer = MBart50Tokenizer.from_pretrained("facebook/mbart-large-50", src_lang='ja_XX')

    else:
        raise ValueError("src_lang and/or tgt_lang must be 'ain' or 'jpn'.")

    # Load model
    model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50")

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    # Split train & test data
    train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

    train_data = {
        "source": train_df[src_lang].tolist(),
        "target": train_df[tgt_lang].tolist()
    }

    eval_data = {
        "source": test_df[src_lang].tolist(),
        "target": test_df[tgt_lang].tolist()
    }

    # Convert to Dataset
    train_dataset = DatasetDict({'train': Dataset.from_dict(train_data)})
    eval_dataset = DatasetDict({'eval': Dataset.from_dict(eval_data)})

    tokenized_train_dataset = train_dataset.map(tokenize, batched=True, remove_columns=["source", "target"])
    tokenized_eval_dataset = eval_dataset.map(tokenize, batched=True, remove_columns=["source", "target"])

    # Generation Config
    generation_config = GenerationConfig(
        max_length=200,
        early_stopping=True,
        num_beams=5,
        forced_eos_token_id=2
    )

    # Trainer Arguments
    training_args = Seq2SeqTrainingArguments(
        output_dir = './results',
        evaluation_strategy = 'epoch',
        learning_rate = 2e-5,
        per_device_train_batch_size = 4,
        per_device_eval_batch_size = 4,
        weight_decay = 0.01,
        save_total_limit = 2,
        num_train_epochs = 100,
        gradient_accumulation_steps = 4,
        fp16 = True if torch.cuda.is_available() else False,
        load_best_model_at_end = True,
        metric_for_best_model = 'eval_loss',
        save_strategy = 'epoch'
    )

    # Early stopping callback
    early_stopping_callback = EarlyStoppingCallback(early_stopping_patience=3)

    # Trainer
    trainer = Seq2SeqTrainer(
        model = model,
        args=training_args,
        train_dataset=tokenized_train_dataset['train'],
        eval_dataset=tokenized_eval_dataset['eval'],
        tokenizer=tokenizer,
        callbacks=[early_stopping_callback],
        generation_config=generation_config
    )

    # Training
    trainer.train()

    # Evaluate
    trainer.evaluate()

    # Save finetuned model & tokenizer
    save_path = './{0}_{1}_finetuned_model_{2}'.format(src_lang, tgt_lang, cycle)
    model.save_pretrained(save_path)

    if src_lang == 'ain':
        tokenizer.save_pretrained(save_path)

    print("Model saved at:", save_path)
    print('------------------')


# Tokenize function
def tokenize(examples):
    inputs = examples['source']
    targets = examples['target']

    model_inputs = tokenizer(inputs, max_length=128, truncation=True, padding="max_length")
    labels = tokenizer(targets, max_length=128, truncation=True, padding="max_length", return_tensors="pt")

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
# Train
train_translator('ain', 'jpn', cycle=0)
train_translator('jpn', 'ain', cycle=0)

# %% [markdown]
# ### 3_Set up Translate formula

# %%
# Setup - model & tokenizer
model_aj = MBartForConditionalGeneration.from_pretrained("./ain_jpn_finetuned_model_0")
tokenizer_aj = RobertaTokenizerFast.from_pretrained("AinuBERTTokenizer")

model_ja = MBartForConditionalGeneration.from_pretrained("./jpn_ain_finetuned_model_0")
tokenizer_ja = MBart50Tokenizer.from_pretrained("facebook/mbart-large-50", src_lang='ja_XX')

# Setup - GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_aj.to(device)
model_ja.to(device)

def translate(text, src_lang, tgt_lang):

    if src_lang == 'ain':
        model = model_aj
        tokenizer = tokenizer_aj

    elif src_lang == 'jpn':
        model = model_ja
        tokenizer = tokenizer_ja

    else:
        raise ValueError("src_lang must be 'ain' or 'jpn'.")

    # Tokenize
    inputs = tokenizer(text, return_tensors="pt", max_length=128, truncation=True).to(device)

    # Translate
    translated_tokens = model.generate(**inputs,
                                       max_length=128,
                                       num_beams=4,
                                       early_stopping=True,
                                       decoder_start_token_id=model.config.decoder_start_token_id
                                       )

    # Decode
    translated_text = tokenizer.decode(translated_tokens[0], skip_special_tokens=True)

    return translated_text

# %% [markdown]
# #### Test

# %% [markdown]
# ##### Ain -> Jpn

# %%
# Sample text
sample_text = ["teeta okay aynu utar opitta kira wa isam.", "昔いた人たちはみんな逃げていなくなった。"]

# Sample source text and corresponding reference translation
source_text = sample_text[0]
gold_translation = sample_text[1]

# Generate translation
translated_text = translate(source_text, 'ain', 'jpn')

def tokenize_japanese(text):
    mecab = MeCab.Tagger("-Owakati")
    return mecab.parse(text).strip()

# Tokenize
tokenized_translation = tokenize_japanese(translated_text)
tokenized_gold = tokenize_japanese(gold_translation)

# BLEU
bleu = sacrebleu.corpus_bleu([tokenized_translation], [[tokenized_gold]])

print("Translated text:", translated_text)
print("BLEU score:", bleu.score)
# Out:
# Translated text: 昔のことたち、人間たちはみんな逃げてしまったのだ。
# BLEU score: 25.748661016289674

# %%
source_text = "teeta okay aynu utar opitta kira wa isam."
print(translate(source_text, 'ain', 'jpn')) # Gold: 昔いた人たちはみんな逃げていなくなった。
# Out:
# 昔の人間たちはみんな逃げてしまいました。

# %%
source_text = "kotan kor kamuy oka an ruwe kuþ nukar." #(lit.) kotan kor kamuy ku=nukar.
print(translate(source_text, 'ain', 'jpn')) # Gold: フクロウ/村神がいることを私は見た。
# Out:
# 村の神様がいるのを見ていました。

# %%
source_text = "kotan kor kamuy oka an ruwe aþ nukar." #(lit.) kotan kor kamuy a=nukar.
print(translate(source_text, 'ain', 'jpn')) # Gold: 我はフクロウ/村神がいることを見た。
# Out:
# 村の神がいるのを私は見ていました。

# %%
source_text = "kotan kor kamuy nukar ka somo ki."
print(translate(source_text, 'ain', 'jpn')) # Gold: (彼は) フクロウ/村神を見ていない。
# Out:
# 村の神を見ることもありません。

# %%
source_text = "pis ta okkaypo utar uwekarpa wa caranke kor an."
print(translate(source_text, 'ain', 'jpn')) # Gold: 浜辺で若者たちが集まって談判をしていました。
# Out:
# 浜で若者たちが集まってきて談判をしていました。

# %%
source_text = "sisam mosir un hosippa hi ora a=oyamokte itak patek ye yak aþ ye." #(lit.) panampe sisammosir un hosippa hi ora a=oyamokte oruspe patek ye yak a=ye.
print(translate(source_text, 'ain', 'jpn')) # Gold: (彼は) 和人のところから帰ってきた時から、おかしな話ばかり言っているそうだ。
# Out:
# 和人の帰ってきたことを何度も言葉ばかりだと言いました。

# %% [markdown]
# ##### Jpn -> Ain

# %%
# Sample text
sample_text = ["teeta okay aynu utar opitta kira wa isam.", "昔いた人たちはみんな逃げていなくなった。"]

# Sample source text and corresponding reference translation
source_text = sample_text[1]
gold_translation = sample_text[0]

# Generate translation
translated_text = translate(source_text, 'jpn', 'ain')

# BLEU
bleu = sacrebleu.corpus_bleu([translated_text], [[gold_translation]])

print("Translated text:", translated_text)
print("BLEU score:", bleu.score)
# Out:
# Translated text: teeta kane oka utar opitta kira wa isam
# BLEU score: 47.750342648354646

# %% [markdown]
# ### 4_Cyclic translate

# %%
# Run 3. Translate formula at first

# Language
src_lang = 'ain'
tgt_lang = 'jpn'

# Set lists from corpus dataframe
texts_no = df['no.'].tolist()
src_texts = df['ain'].tolist()

for i, original in enumerate(src_texts):

    # Translate from ain to jpn
    translated_text = translate(original, src_lang, tgt_lang)

    # Back translate from jpn to ain
    backtranslated_text = translate(translated_text, tgt_lang, src_lang)

    # add to df
    df.loc[i, 'translated_jpn'] = translated_text
    df.loc[i, 'backtranslated_ain'] = backtranslated_text

    if i % 5000 == 0 or i == len(src_texts):
        print(i, '/', len(src_texts))

df.to_csv('backtranslated_ain.txt', index=False, encoding='utf-8', sep='\t')
# Out:
# 0 / 33121
# 100 / 33121
# 200 / 33121
# 300 / 33121
# 400 / 33121
# 500 / 33121
# 600 / 33121
# 700 / 33121
# 800 / 33121
# 900 / 33121
# 1000 / 33121
# 1100 / 33121
# 1200 / 33121
# 1300 / 33121
# 1400 / 33121
# 1500 / 33121
# 1600 / 33121
# 1700 / 33121
# 1800 / 33121
# 1900 / 33121
# 2000 / 33121
# 2100 / 33121
# 2200 / 33121
# 2300 / 33121
# 2400 / 33121
# 2500 / 33121
# 2600 / 33121
# 2700 / 33121
# 2800 / 33121
# 2900 / 33121
# 3000 / 33121
# 3100 / 33121
# 3200 / 33121
# 3300 / 33121
# 3400 / 33121
# 3500 / 33121
# 3600 / 33121
# 3700 / 33121
# 3800 / 33121
# 3900 / 33121
# 4000 / 33121
# 4100 / 33121
# 4200 / 33121
# 4300 / 33121
# 4400 / 33121
# 4500 / 33121
# 4600 / 33121
# 4700 / 33121
# 4800 / 33121
# 4900 / 33121
# 5000 / 33121
# 5100 / 33121
# 5200 / 33121
# 5300 / 33121
# 5400 / 33121
# 5500 / 33121
# 5600 / 33121
# 5700 / 33121
# 5800 / 33121
# 5900 / 33121
# 6000 / 33121
# 6100 / 33121
# 6200 / 33121
# 6300 / 33121
# 6400 / 33121
# 6500 / 33121
# 6600 / 33121
# 6700 / 33121
# 6800 / 33121
# 6900 / 33121
# 7000 / 33121
# 7100 / 33121
# 7200 / 33121
# 7300 / 33121
# 7400 / 33121
# 7500 / 33121
# 7600 / 33121
# 7700 / 33121
# 7800 / 33121
# 7900 / 33121
# 8000 / 33121
# 8100 / 33121
# 8200 / 33121
# 8300 / 33121
# 8400 / 33121
# 8500 / 33121
# 8600 / 33121
# 8700 / 33121
# 8800 / 33121
# 8900 / 33121
# 9000 / 33121
# 9100 / 33121
# 9200 / 33121
# 9300 / 33121
# 9400 / 33121
# 9500 / 33121
# 9600 / 33121
# 9700 / 33121
# 9800 / 33121
# 9900 / 33121
# 10000 / 33121
# 10100 / 33121
# 10200 / 33121
# 10300 / 33121
# 10400 / 33121
# 10500 / 33121
# 10600 / 33121
# 10700 / 33121
# 10800 / 33121
# 10900 / 33121
# 11000 / 33121
# 11100 / 33121
# 11200 / 33121
# 11300 / 33121
# 11400 / 33121
# 11500 / 33121
# 11600 / 33121
# 11700 / 33121
# 11800 / 33121
# 11900 / 33121
# 12000 / 33121
# 12100 / 33121
# 12200 / 33121
# 12300 / 33121
# 12400 / 33121
# 12500 / 33121
# 12600 / 33121
# 12700 / 33121
# 12800 / 33121
# 12900 / 33121
# 13000 / 33121
# 13100 / 33121
# 13200 / 33121
# 13300 / 33121
# 13400 / 33121
# 13500 / 33121
# 13600 / 33121
# 13700 / 33121
# 13800 / 33121
# 13900 / 33121
# 14000 / 33121
# 14100 / 33121
# 14200 / 33121
# 14300 / 33121
# 14400 / 33121
# 14500 / 33121
# 14600 / 33121
# 14700 / 33121
# 14800 / 33121
# 14900 / 33121
# 15000 / 33121
# 15100 / 33121
# 15200 / 33121
# 15300 / 33121
# 15400 / 33121
# 15500 / 33121
# 15600 / 33121
# 15700 / 33121
# 15800 / 33121
# 15900 / 33121
# 16000 / 33121
# 16100 / 33121
# 16200 / 33121
# 16300 / 33121
# 16400 / 33121
# 16500 / 33121
# 16600 / 33121
# 16700 / 33121
# 16800 / 33121
# 16900 / 33121
# 17000 / 33121
# 17100 / 33121
# 17200 / 33121
# 17300 / 33121
# 17400 / 33121
# 17500 / 33121
# 17600 / 33121
# 17700 / 33121
# 17800 / 33121
# 17900 / 33121
# 18000 / 33121

# %% [markdown]
# # Archive

# %% [markdown]
# ### 1_Library

# %%
import os
import random
import math

import torch
import torch.nn as nn
import torch.optim as optim
from datasets import Dataset
import datasets
from torch.nn.utils.rnn import pad_sequence
import spacy
import numpy as np
from transformers import TFMT5ForConditionalGeneration

# Change Current Directory
os.chdir('/content/drive/MyDrive/Colab Notebooks/Poysuwop')

# Load preprocess module
#sys.path.append('/content/drive/MyDrive/Colab Notebooks/Poysuwop')
from modules import ainPreprocess

# %% [markdown]
# ### 2_Tokenizers

# %%
from tokenizers import Tokenizer
from transformers import RobertaTokenizerFast, AutoTokenizer

ain_tokenizer = RobertaTokenizerFast.from_pretrained("AinuBERTTokenizer")
input_string = ainPreprocess.preprocess("ohonno somo unukar=an")
print(ain_tokenizer(input_string))

jpn_tokenizer = AutoTokenizer.from_pretrained("cl-tohoku/bert-base-japanese")
# print(jpn_tokenizer("久しぶりだね"))
# Out:
# {'input_ids': [0, 2272, 394, 4100, 272, 2], 'attention_mask': [1, 1, 1, 1, 1, 1]}
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/479 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/258k [00:00<?, ?B/s]

# %% [markdown]
# #### データ読み込み

# %%
from datasets import Dataset
import pandas as pd

# read txt file
df_ain = pd.read_csv("poysuwop_ain.txt", sep="\t", header=None)
df_jpn = pd.read_csv("poysuwop_jpn.txt", sep="\t", header=None)

# rename columns
df_ain.columns = ["ain"]
df_jpn.columns = ["jpn"]

def gen():
    for i in range(len(df_ain)):
        yield {
            'ain': df_ain["ain"][i],
            'jpn': df_jpn["jpn"][i]
        }

ds = Dataset.from_generator(gen)
for example in ds:
    print(example)

print(len(ds))
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# {'ain': 'okamkir', 'jpn': 'わざと'}
# {'ain': 'sisam utari', 'jpn': '和人'}
# {'ain': 'sisam', 'jpn': '和人'}
# {'ain': 'hempara ne yakka raykoraci patek kþ an wa', 'jpn': 'いつでも、死ぬような思いばかりして暮らしているよ。'}
# {'ain': 'kurmat', 'jpn': '和人の女'}
# {'ain': 'iyoyra ruy', 'jpn': '物忘れが激しい、忘れっぽい'}
# {'ain': 'oyra', 'jpn': '…を忘れる'}
# {'ain': 'ponno', 'jpn': 'わずかに'}
# {'ain': 'mimaraha', 'jpn': '…の余った残り'}
# {'ain': 'hon utursam', 'jpn': '横腹'}
# {'ain': 'taan topenpe usaraye yan', 'jpn': 'このお菓子を別々にしなさい。'}
# {'ain': 'paykar an kor upas ru wa apkas ka icakkere', 'jpn': '春になると雪が解けて歩くのも汚い（？）。'}
# {'ain': 'aa toan matkaci ramuan hawe', 'jpn': 'ああ、あの娘は利口だ。'}
# {'ain': 'uosurpa', 'jpn': '離婚する'}
# {'ain': 'kasi opiwki', 'jpn': '助けに行く'}
# {'ain': 'tusunike', 'jpn': 'リス、キネズミ'}
# {'ain': 'pirka', 'jpn': '立派だ'}
# {'ain': 'na ponno enþ kore', 'jpn': 'もうちょっとください。'}
# {'ain': 'kama or wakka aþ omare wa aþ sesekka akusu tane pa at na yanke yan', 'jpn': '鉄瓶に水を入れて沸かしたたら、もう湯気が立っているから、鉄瓶を（火から）あげなさい。'}
# {'ain': 'kesukuran an kor toan menoko hinak un ka arpa', 'jpn': '毎晩、あの女はどこかに行く。'}
# {'ain': 'kesukuran an kor sinen ne patek kþ an wa kuþ yayramsitne', 'jpn': '毎晩一人でいて、私はつらい。'}
# {'ain': 'kasi ota', 'jpn': '…を…の上にかける'}
# {'ain': 'taanpe pirka na', 'jpn': 'それは綺麗だね。'}
# {'ain': 'suwesuwe', 'jpn': '…を（何度も）揺さぶる'}
# {'ain': 'kani', 'jpn': '私'}
# {'ain': 'umomare', 'jpn': '…を拾い集める'}
# {'ain': 'iwasi sum', 'jpn': '鰯油'}
# {'ain': 't r us', 'jpn': '垢がついている、汚れている'}
# {'ain': 'kina ohaw aþ kar kor iwasi sum ponno omare wa aþ e kor yupta', 'jpn': '山菜汁を作って鰯油を入れて食べると…'}
# {'ain': 't rus', 'jpn': '垢がついている、汚れている'}
# {'ain': 't rus', 'jpn': '垢がついている、汚れている'}
# {'ain': 't rus', 'jpn': '垢がついている、汚れている'}
# {'ain': 'aþ kotukka ya oyakoyak un aþ kikkik wa kunne wa okere wa isa or un kuneywa okuyma sospari akusu sekor sekor hure wa aþ kikkik wa tane ray noyne an wa isa or un aþ tura akusu isa or ta ray tte sekor kuþ nukar kor', 'jpn': 'くっつけられたりや、あちこちを殴られて、黒くなってしまって、医者のところへ…、朝、小便した…寝小便したと言われて（？）殴られて、もはや死んだようになって、医者に連れて行かれると医者のところで死んだっていうのを私は見て…'}
# {'ain': 'kuþ mipihi kuþ huraye ka somo ki p ne kusu ene tur us ruwe ne', 'jpn': '私の着物を洗わなかったものだから、このように汚れているよ。'}
# {'ain': 'kþ enukosne', 'jpn': '聞きたくもない'}
# {'ain': 'asinuma', 'jpn': '私（４人称代名詞）'}
# {'ain': 'coka', 'jpn': '私達'}
# {'ain': 'coka anakne mukawa un menoko ciþ ne wa', 'jpn': '私たちは鵡川の女だよ。'}
# {'ain': 'ikepkepi', 'jpn': '私にとって役に立たない人（私のすねをかじる人）'}
# {'ain': 'nuyto uesikke wa cinkihi kuþ ninu ka eaykap', 'jpn': '縫い糸がもつれて、すそを縫うこともできない。'}
# {'ain': 'husko toy wano', 'jpn': '昔から、古くから'}
# {'ain': 'kuþ kor cise', 'jpn': '私の家'}
# {'ain': 'perpa', 'jpn': '…を破る'}
# {'ain': 'kþ unihi', 'jpn': '私の家'}
# {'ain': 'aynupata', 'jpn': '私もああいうふうになりたいな、うらやましい'}
# {'ain': 'tekehe omare', 'jpn': '…に渡す、…に手渡す'}
# {'ain': 'kþ eraman', 'jpn': '（私はそれを）了解した'}
# {'ain': 'tekkiray', 'jpn': '指櫛'}
# {'ain': 'yarke', 'jpn': '…をすり切らす'}
# {'ain': 'kuþ sapaha otopi herisarisa wa kþ eyaysitoma kusu senkaki ani kuþ sapa kuþ seske', 'jpn': '私の頭の髪の毛がぐちゃぐちゃで恥ずかしいから、布で頭をおおう。'}
# {'ain': 'nispa ek sekor kuþ nu wa kþ eyaysitoma kusu senkaki kuþ hekari', 'jpn': '旦那が来ると聞いて、（私のぐちゃぐちゃの髪の毛が）恥ずかしいから、布を頭に巻いて。'}
# {'ain': 'tekkiray', 'jpn': '指櫛'}
# {'ain': 'noye', 'jpn': '…をよじる'}
# {'ain': 'tomotuye', 'jpn': '…を横切る、…を渡る'}
# {'ain': 'pet tomotuy', 'jpn': '川を渡る'}
# {'ain': 'yaka', 'jpn': '指さす'}
# {'ain': 'kuþ saha kuþ tura wa biyoin or un kþ arpa wa kusuri eunkeray uske kþ erampewtek wa sitturaynu', 'jpn': '私は妹を連れて病院に行って、薬をもらう所がわからなくて、道に迷った。'}
# {'ain': 'urenpiskani', 'jpn': '…の両側'}
# {'ain': 'rayparaparak', 'jpn': 'ひどくわあわあ泣く'}
# {'ain': 'mina rusuy', 'jpn': '笑いたい'}
# {'ain': 'munin wa isam sekor kuþ yaynu kor kuþ nukar akusu ramne', 'jpn': '腐ってしまったと私は思いながら見たら、傷んで無くて…'}
# {'ain': 'm na', 'jpn': '笑う'}
# {'ain': 'kþ onaha kþ unuhu pikanpikan wa kþ eyaykopuntek', 'jpn': '私の父と母は、はつらつとしていて嬉しい。'}
# {'ain': 'm nare', 'jpn': '…を笑わす'}
# {'ain': 'oyat ta', 'jpn': '他の所に'}
# {'ain': 'oyat ta', 'jpn': '他の所に'}
# {'ain': 'perpa', 'jpn': '…を割る'}
# {'ain': 'urentek', 'jpn': '両手'}
# {'ain': 'topenpe eciþ kore na urentek sanke yan', 'jpn': 'お菓子あげるから両手を出しなさい。'}
# {'ain': 'wen', 'jpn': '悪い'}
# {'ain': 'tane anakne ioyra patek kuþ ki p ne kusu nisatta aþ kar pe anakne opitta kampi or un kuþ nuye kor kþ an', 'jpn': '今はもう物忘ればかり私はするものだから、明日することは全部、紙に書いている。'}
# {'ain': 'wen kamuy', 'jpn': '悪い神'}
# {'ain': 'sospa', 'jpn': '…を剥く'}
# {'ain': 'kuþ cise or un kuþ hosipi kusu okimne kuþ san', 'jpn': '自分の家に帰るのに山から下りた。'}
# {'ain': 'sipicar ta wenpe an wa kþ arpa akusu su poro su ani soy ta ohaw aþ kar siri kuþ nukar', 'jpn': '静内で不幸があって、そこに私が行ったら、三つの鍋、大鍋で外で汁物を作っている様子を見た。'}
# {'ain': 'sirwen', 'jpn': '天気が悪い'}
# {'ain': 'kapu soso', 'jpn': '…の皮を剥く'}
# {'ain': 'sikina okkayo kina anakne ciyehe haru an kusu ne kor pirka korka sinmun an kor etupsike tontone', 'jpn': 'ガマの男は陰茎(穂)が、豊作になるはずだと、きれいだけれど、不作（？）のときは先が禿げる。'}
# {'ain': 'wen siyeye', 'jpn': '悪い病気'}
# {'ain': 'ri', 'jpn': '（獣の皮を）剥ぐ'}
# {'ain': 'uren', 'jpn': '両方'}
# {'ain': 'ikisakane', 'jpn': 'もみぎり'}
# {'ain': 'iramepakari', 'jpn': '予測する'}
# {'ain': 'tanto upas yupke noyne kþ erampakari', 'jpn': '今日は雪がひどうなりそうだと予想する。'}
# {'ain': 'wenpe taype', 'jpn': '貧乏人の子（？）'}
# {'ain': 'urenker', 'jpn': '両方の靴'}
# {'ain': 'suke', 'jpn': '料理する'}
# {'ain': 'ohasir an', 'jpn': '留守なのかい？'}
# {'ain': 'iyohaysitomare', 'jpn': 'おやまあ、おどろいた。'}
# {'ain': 'wenpasrota', 'jpn': '悪口、悪口を言う'}
# {'ain': 'pasrota', 'jpn': '悪口、悪口を言う'}
# {'ain': 'sirkote', 'jpn': '…をゆわえる'}
# {'ain': 'iteki oyra na', 'jpn': '決して忘れるんじゃないよ。'}
# {'ain': 'hoka o', 'jpn': '…を燃やす、…を火にくべる、…を足し前として燃やす'}
# {'ain': 'kuriante', 'jpn': '…の悪口を言う'}
# {'ain': 'ohaykekar', 'jpn': '…の悪口を言う、…の陰口を言う'}
# {'ain': 'tanto', 'jpn': '今日、'}
# {'ain': 'tanto nen ka ek noyne kþ ekamke', 'jpn': '今日、誰か来るようだと予知する。'}
# {'ain': 'humihi humihi', 'jpn': '響き、音'}
# {'ain': 'humihi', 'jpn': '響き、音'}
# {'ain': 'kurkotunas noyne hoastari kor apkas siri kuþ nukar kþ erampokiwen', 'jpn': '麻痺がある様でびっこをひきながら歩いている様子を私は見た。かわいそうに思った。'}
# {'ain': 'hemanta humihi an', 'jpn': '何の音だろう'}
# {'ain': 'hemanta humihi an', 'jpn': '何の音だろう'}
# {'ain': 'euopitte', 'jpn': '…を結ぶ'}
# {'ain': 'an hine', 'jpn': '…になって'}
# {'ain': 'an hine', 'jpn': '…になって'}
# {'ain': 'wenpasrota', 'jpn': '悪口を言う'}
# {'ain': 'wenpasrota', 'jpn': '悪口を言う'}
# {'ain': 'sirpeker', 'jpn': '夜が明ける'}
# {'ain': 'nep ne yakka notakop', 'jpn': '何であっても刃物'}
# {'ain': 'pirka wa', 'jpn': 'いいよ。'}
# {'ain': 'itata kusu', 'jpn': 'きざむから'}
# {'ain': 'kþ erampewtek', 'jpn': '私は知らない。'}
# {'ain': 'aþ eywanke hoyco ne yakka makiri ne yakka notakop nata ne yakka emus ne yakka notakop', 'jpn': '私たちが使う包丁も小刀も刃物。鉈も刀も刃物。'}
# {'ain': 'wen pe', 'jpn': '悪者'}
# {'ain': 'yaysamne eþ ek', 'jpn': '何事もなく来たかい？'}
# {'ain': 'kuneywa', 'jpn': '朝'}
# {'ain': 'kuneywa', 'jpn': '朝'}
# {'ain': 'kuneywa', 'jpn': '朝'}
# {'ain': 'siyeye', 'jpn': '病気'}
# {'ain': 'eþ us pe an somo kþ us pe anakne isam pe ne wa hantasi kuþ ne wa', 'jpn': 'あなたは履き物はあるのかい？―いや。私は履き物がないものだから裸足でいるよ。'}
# {'ain': 'kþ us pe ka isam wa hantasi kuþ ne wa', 'jpn': '私は履き物がないものだから裸足でいるよ。'}
# {'ain': 'pis ta kuþ san rusuy akusu kþ uk pe ka kuþ tekehayta kor kuþ hoyupi', 'jpn': '浜に下りたくて、とるものもとりあえず走った。'}
# {'ain': 'so kar', 'jpn': '茣蓙を敷く'}
# {'ain': 'hantasi ne wa', 'jpn': '裸足である……だよ。'}
# {'ain': 'kani', 'jpn': '我'}
# {'ain': 'yayomonnure', 'jpn': '我褒め、自分自身を褒める、自慢する'}
# {'ain': 'iyoski kur', 'jpn': '酔っ払い'}
# {'ain': 'coka', 'jpn': '我ら、私達'}
# {'ain': 'perke', 'jpn': '割れる'}
# {'ain': 'itanki', 'jpn': '椀'}
# {'ain': 'ru ruipokas', 'jpn': '少し醜い'}
# {'ain': 'kuþ matnepo', 'jpn': '私の娘'}
# {'ain': 'kuþ matnepo', 'jpn': '私の娘'}
# {'ain': 'kesto kesto', 'jpn': '連日、毎日'}
# {'ain': 'isa', 'jpn': '実が入る'}
# {'ain': 'apeoy', 'jpn': '炉'}
# {'ain': 'anepitta', 'jpn': '夜じゅう、夜どおし'}
# {'ain': 'onne kur', 'jpn': '老人'}
# {'ain': 'annoski', 'jpn': '夜中'}
# {'ain': 'inukuri', 'jpn': '老衰で動けない'}
# {'ain': 'pana', 'jpn': '埃'}
# {'ain': 'ancikar tanne', 'jpn': '夜長である、夜が長い'}
# {'ain': 'hokure sipine yan', 'jpn': '早く支度してちょうだい。'}
# {'ain': 'pon soy unuhu nepki kusu soyne wa isam pe ne kusu totto nunnun rusuy kusu cis kor patek an pe ne kusu sucihi kaptora nunnunte wa kor an', 'jpn': '子供が母親が仕事で外に出てしまったものだから、お乳が飲みたくて泣いてばかりいるので、祖母が老いた乳房を吸わせていた。'}
# {'ain': 'ponson kunnecis wa nep ka ekamke hawe ne sekor hapo utar ye kor senkaki uype uhuyka wa', 'jpn': '赤ん坊が夜泣きして、何か予感がしているんだろうと母達が言いながら、木綿の端切れを燃やして'}
# {'ain': 'suat', 'jpn': '炉かぎ'}
# {'ain': 'iwan', 'jpn': '六、六の…'}
# {'ain': 'pon makkaci', 'jpn': '六歳から十二歳ぐらいの女の子'}
# {'ain': 'ser', 'jpn': 'むせる'}
# {'ain': 'apekes utur', 'jpn': '炉尻'}
# {'ain': 'aa toan huci tane onne p ne kusu opecikcik kor arpa siri', 'jpn': 'あー、あの婆さんは年をとったもんだから、おしっこ漏らしながら行ってるよ。'}
# {'ain': 'ancikartakne', 'jpn': '夜短'}
# {'ain': 'apesam', 'jpn': '炉縁'}
# {'ain': 'apepasuy', 'jpn': '炉辺に置いてある箸'}
# {'ain': 'inumpe', 'jpn': '炉縁'}
# {'ain': 'sey', 'jpn': 'お湯'}
# {'ain': 'karip', 'jpn': '輪'}
# {'ain': 'rayparaparak', 'jpn': 'わあわあ泣く'}
# {'ain': 'noya sito', 'jpn': 'ヨモギ餅'}
# {'ain': 'iyohay sonno he', 'jpn': 'よもや、まさか'}
# {'ain': 'nonkar', 'jpn': '…の様子を見る'}
# {'ain': 'pewre humse', 'jpn': '若い雄たけび'}
# {'ain': 'kuþ pon hi or ta ekasi ne ya huci ne ya uekarpa wa uwepeker uenewsar an siri kuþ nu ka ki', 'jpn': '私が幼い頃、爺ちゃんや婆ちゃんが集って、散文説話やよもやま話をしていたようなのを聞いたりもした。'}
# {'ain': 'pirka aep kuþ kar hi ta awta or un kþ ere rusuy kusu oypepi or un ape omare wa ne aep kuþ kor wa awta kuþ kor wa kþ apkas', 'jpn': '美味しい食べ物を作った時に、隣に食べさせたいので、皿に入れて……火を入れて、\u3000その食べ物を持って、隣に持って歩いた。'}
# {'ain': 'ape ruy', 'jpn': '火が燃える'}
# {'ain': 'kuþ sampesituri', 'jpn': '私は胸がすーっとした。'}
# {'ain': 'pewre menoko', 'jpn': '若い女'}
# {'ain': 'rametok', 'jpn': '勇敢さ、勇気'}
# {'ain': 'ponmenoko', 'jpn': '若い女'}
# {'ain': 'usey', 'jpn': '沸かし湯'}
# {'ain': 'popte', 'jpn': '…を沸かす'}
# {'ain': 'sesekka', 'jpn': '…を沸かす'}
# {'ain': 'cep aþ ma wa aþ e ro', 'jpn': '魚を焼いて食べましょう。'}
# {'ain': 'usey kar yan', 'jpn': 'お湯を沸かしなさい。'}
# {'ain': 'ukousaraye', 'jpn': '…を分かち合う'}
# {'ain': 'ukousaraye', 'jpn': '…を分かち合う'}
# {'ain': 'nisatta kuneywa', 'jpn': '翌朝'}
# {'ain': 'kuþ tuymanokkus', 'jpn': '私はそっぽを向く'}
# {'ain': 'hu nipes ne', 'jpn': '生のシナなの？'}
# {'ain': 'hu nipes ne popte nipes ne ya', 'jpn': '生のシナ皮なの？\u3000煮たシナ皮なの？'}
# {'ain': 'kuþ tuymanokkus', 'jpn': '私はそっぽを向く'}
# {'ain': 'erampewtek erampewtek', 'jpn': '…がわからない'}
# {'ain': 'henoye', 'jpn': '立ち寄る'}
# {'ain': 'ramuhawke', 'jpn': '優しい'}
# {'ain': 'kuþ kor kut pita wa enþ kore yan', 'jpn': '私の帯をほどいてくれ。'}
# {'ain': 'toan kur isoytak hawe kuþ nu wa kuþ tuyaskar pa wa kuþ cis', 'jpn': 'あの人の話すことを私は聞いて、同情して泣いた。'}
# {'ain': 'nep ta neun kþ arpa yakka pirka aep patek poronno aþ sanke kusu kuþ ipe a kuþ ipe a kuþ ipe a kuþ ipe a wa keraan wa kuþ ipeno', 'jpn': 'どこに行っても美味しいものばかり沢山出されるので私は食べて食べて美味しくて、よく食べる。'}
# {'ain': 'eani anakne eþ niwasnu p ne kusu nep ne yakka pirkano kar siri', 'jpn': 'あなたはとても働き者で、何でも上手にするねえ！'}
# {'ain': 'okokko', 'jpn': '化物'}
# {'ain': 'enþ teksam ta anu yan', 'jpn': '私の傍に置いてください。'}
# {'ain': 'ekari nezumi oranote kupapa wa kþ eramutuy wa kuþ hopuni wa kuþ as wa kþ as wa kuþ suyesuye yakka', 'jpn': '手に向かってネズミ、おらの手にネズミがかみついたから、私は驚いて飛び上がって、こうやってぶらぶらしても…'}
# {'ain': 'enþ teksam', 'jpn': '私の傍'}
# {'ain': 'enþ sam ta anu yan', 'jpn': '私の傍に置いてください。'}
# {'ain': 'sapaha pirka', 'jpn': '頭がいい'}
# {'ain': 'so', 'jpn': '床'}
# {'ain': 'sinire', 'jpn': '…を休ませる'}
# {'ain': 'ekiroroan', 'jpn': '…が愉快だ、…を愉快に思う'}
# {'ain': 'sinrit mosir', 'jpn': '先祖の国'}
# {'ain': 'usey purse na puta uk yan', 'jpn': 'お湯が沸き上がっているから、ふたを取りなさい。'}
# {'ain': 'nispa aþ nu aþ nu', 'jpn': '旦那さん、もしもし？'}
# {'ain': 'kiroroan', 'jpn': '愉快だ、楽しい'}
# {'ain': 'mosir hoppa', 'jpn': '世を去る'}
# {'ain': 'kuþ kor ekasi pirka ekasi ne a p mosir hoppa wa tane anakne isam', 'jpn': '私の爺さんは、素敵な爺さんだった。世を去ってしまって、今はいない。'}
# {'ain': 'itacorpok ta seta ahun wa pokor', 'jpn': '床下に犬が入って出産した。'}
# {'ain': 'kuþ kor cape itacorpok or un osma wa pokor kor an', 'jpn': '私の猫が、床下に入って出産していた。'}
# {'ain': 'esirwante', 'jpn': '（…を探して）あたりを見まわす、（…を探して）あたりを見渡す'}
# {'ain': 'toan totto eytasa sesek na oyak ta anu yan', 'jpn': 'その牛乳は熱くなりすぎてしまうよ、別のとこに置きなさい。'}
# {'ain': 'nisuk nisuk', 'jpn': '…に頼む、募集する'}
# {'ain': 'poyyanpe', 'jpn': 'ユカラの主人公'}
# {'ain': 'cimpacimpa', 'jpn': '（髪の毛など）をかき分ける'}
# {'ain': 'sam', 'jpn': 'そば、横'}
# {'ain': 'okamkirno', 'jpn': 'わざと'}
# {'ain': 'ahunkanit', 'jpn': '横糸を巻く細い棒'}
# {'ain': 'yaayka', 'jpn': 'やっと'}
# {'ain': 'yaayka', 'jpn': 'やっと'}
# {'ain': 'honuhonu', 'jpn': '腹ばいで進む。'}
# {'ain': 'tuyaskar', 'jpn': '（同情する）'}
# {'ain': 'niwen', 'jpn': '乱暴な、気が荒い'}
# {'ain': 'w r o', 'jpn': '…を水に浸ける'}
# {'ain': 'uhekote', 'jpn': '互いの方に向かって、向かい合って'}
# {'ain': 'eramuan', 'jpn': '…を理解する、…がわかる'}
# {'ain': 'koyayramu', 'jpn': '…を忘れて思い出せない'}
# {'ain': 'hoski pa upas poro wa upas kuþ ke kusu kuþ yaywennukar', 'jpn': '昨年は雪がつもって雪かきをするのに苦労した。'}
# {'ain': 'oskeporo', 'jpn': '利口だ、大人びている'}
# {'ain': 'upas yupke', 'jpn': '雪がひどい'}
# {'ain': 'kene tuk', 'jpn': '芽が出る。'}
# {'ain': 'sipasnu', 'jpn': '頭がいい'}
# {'ain': 'paykar an kor upas ru wa neun ka kþ arpa rusuy korka icakkere p ne kusu kþ arpa ka kþ etoranne', 'jpn': '春になると雪が解けて、どこかに行きたいけど汚いものだから行くのも億劫だ。'}
# {'ain': 'mokor', 'jpn': '眠る'}
# {'ain': 'inte', 'jpn': '目くそ'}
# {'ain': 'kuþ niska sekor kuþ yaynu korka tane kþ eywanke ka somo ki p ne kusu kþ osura', 'jpn': '私は勿体ないと思うんだけど、もう使わないので捨てた。'}
# {'ain': 'anun kotan', 'jpn': '別の村、よその村'}
# {'ain': 'eutunne', 'jpn': '下座'}
# {'ain': 'icakkerere', 'jpn': '…を汚す'}
# {'ain': 'icakkerere', 'jpn': '…を汚す'}
# {'ain': 'pet or un susu ham aþ omare akusu susam ne aþ kar wa aþ utari utar e kuskeraypo', 'jpn': '川に柳の葉を入れるとシシャモに変わり、先祖がそれを食べたお陰で…'}
# {'ain': 'ouske', 'jpn': '根元'}
# {'ain': 'nupuri', 'jpn': '山'}
# {'ain': 't rus', 'jpn': '垢がついている、汚れている'}
# {'ain': 'na na enþ kore yan', 'jpn': 'もっともっとください。'}
# {'ain': 'ecikiki', 'jpn': '…をゆでこぼす'}
# {'ain': 'ipesak', 'jpn': '狩りが下手だ'}
# {'ain': 'tanto sirmeman', 'jpn': '今日は涼しい。'}
# {'ain': 'tek etupske', 'jpn': '指先'}
# {'ain': 'noyke', 'jpn': 'よじれる'}
# {'ain': 'amip', 'jpn': '着物'}
# {'ain': 'amip kuþ kor pe', 'jpn': '着物、私の持ち物'}
# {'ain': 'noynoyke', 'jpn': 'よじれている'}
# {'ain': 'toan kur hemanta nukar wa yakayaka kor an', 'jpn': 'あの人は何を見て指差してるんだ'}
# {'ain': 'herikasi inkar', 'jpn': '見上げる'}
# {'ain': 'rutu', 'jpn': '…をずらす'}
# {'ain': 'oyak ta', 'jpn': '他の所に'}
# {'ain': 'ekimne kþ arpa korka ponno patek kina kuþ kar wa kuþ san hi ta tuyma korka ekimne supuya at siri kuþ nukar wa makanak ne sekor kuþ yaynu kuþ tura utari turano kuþ nukar kor kþ an akusu sir uhuy wa iyohay sekor kuþ yaynu', 'jpn': '山に行ったけれど、ちょっとだけ山菜を採って私が下りた時、遠くだけれど、山で煙が上がっている様子を見て、どうしたのかと私は思った。私と一緒に行った仲間と一緒に見ていたら山火事で、おやおやと思った。'}
# {'ain': 'kuþ mokor akusu kuþ cinita wa kuþ sinki wa kþ eramtuy', 'jpn': '私が寝ると夢でうなされて、疲れて、それに驚いた。'}
# {'ain': 'iri', 'jpn': '身内、親戚'}
# {'ain': 'iri', 'jpn': '身内、親戚'}
# {'ain': 'cep ne ya amam ne ya ani kasi kik', 'jpn': '魚だの、穀物だのでお祓いした。'}
# {'ain': 'sospa', 'jpn': '…を剥く'}
# {'ain': 'suwesuwe', 'jpn': '…を揺らす'}
# {'ain': 'iresu kamuy', 'jpn': '火の神様、子育てする神'}
# {'ain': 'repnaoske', 'jpn': '三つ編みにする'}
# {'ain': 'puri wen pe', 'jpn': '悪い者、精神の悪い人'}
# {'ain': 'ohhorrrrrrrrr ohhohe a horrrrrrrrr ohhohe mokor totto ranran hamuki kane ne ohhorenka suye ohorrrrrrrrr ho ho he', 'jpn': '（あやす声）／お乳を飲んで寝なさい／ねんねするんだよ／ゆりかごを揺らすよ（あやす声）'}
# {'ain': 'mehuntokiki', 'jpn': '（片膝を立てるか横座りして）背中をまるめてうなだれるような格好で座る'}
# {'ain': 'sawnu', 'jpn': '（帯などが）ゆるい'}
# {'ain': 'wenpe sani', 'jpn': '悪い者の血統'}
# {'ain': 'pecakayne', 'jpn': '糊気がない'}
# {'ain': 'asuttasa', 'jpn': '弔問する'}
# {'ain': 'sarake', 'jpn': '尻尾(？)'}
# {'ain': 'oyak un', 'jpn': 'よそで、別なところで'}
# {'ain': 'kuþ ye ka eaykap kuþ iruska wa wenpe sani wenpe taype sekor kuþ hawean', 'jpn': '私は言うこともできない。私は怒って、悪いものの血統だと言った。'}
# {'ain': 'humiruycikap', 'jpn': 'ヤマドリ'}
# {'ain': 'nitata', 'jpn': '…を両方の脇から支える'}
# {'ain': 'anun kotan', 'jpn': 'よその村'}
# {'ain': 'oyak un arpa', 'jpn': 'よそへ行く。'}
# {'ain': 'sawnure', 'jpn': '（帯など）をゆるめる'}
# {'ain': 'wen iyokunure', 'jpn': '悪くたまげる'}
# {'ain': 'terebi eteun kirure yan', 'jpn': 'テレビをこっちに向けてちょうだい。'}
# {'ain': 'sinen ne kþ an wa kuþ iruska oruspe ka sine p ka isam', 'jpn': '私は一人で暮らしていて、怒ることも一つもない。'}
# {'ain': 'tane anakne ohasirke ne wa tane anak ohasirke ne wa', 'jpn': '今は空き家なのだ'}
# {'ain': 'eþ non ratci kor an', 'jpn': 'よだれが垂れているよ。'}
# {'ain': 'sontak unuhu apkas kor osikkurkote', 'jpn': '赤ん坊が、お母さんが歩くのについて歩く。'}
# {'ain': 'iteki oyra ani', 'jpn': '決して忘れるんじゃないよ。'}
# {'ain': 'ekemke', 'jpn': '…を予知する'}
# {'ain': 'nen', 'jpn': '誰か'}
# {'ain': 'ne to', 'jpn': '四日'}
# {'ain': 'nupur', 'jpn': '霊力のある'}
# {'ain': 'ahupkar', 'jpn': '…を貰う、…を貰いに行く'}
# {'ain': 'maw ne yakka', 'jpn': 'ハマナスでも。'}
# {'ain': 'toan pon menoko iku wa iku wa oraun iyoski wa iyoskicis kor an', 'jpn': 'あの娘は飲んで飲んでそれで酔っぱらい、酔っぱらって泣いているよ。'}
# {'ain': 'kuþ kor matnepo', 'jpn': '私の娘'}
# {'ain': 'kuþ kaspaotte', 'jpn': '私は言い置いた'}
# {'ain': 'ponmenoko', 'jpn': '娘さん、若い娘'}
# {'ain': 'apto poronno ruy wa kuþ soyne ka kuþ nuykes', 'jpn': '雨がたくさん激しくて外にも出かねる'}
# {'ain': 'ataye hawke', 'jpn': '廉価'}
# {'ain': 'tane anakne amip ne ya uspe ne ne ya arikinne hawke', 'jpn': '今は着る物や履物がとても'}
# {'ain': 'kesto kesto an kor', 'jpn': '連日、毎日'}
# {'ain': 'kesto kesto an kor sinen ne patek kþ an pe ne kusu ipe ka kþ etoranne', 'jpn': '連日、一人ぼっちでいるものだから、食事するのも面倒くさい。'}
# {'ain': 'taanpe ka eþ kor pe', 'jpn': 'これもあなたのもの？'}
# {'ain': 'unkeray', 'jpn': '…を貰う'}
# {'ain': 'kþ erampewtek', 'jpn': '私は分からない'}
# {'ain': 'ancikar tanne', 'jpn': '夜長である、夜が長い'}
# {'ain': 'kunnecis', 'jpn': '夜泣きする'}
# {'ain': 'etoko tusmak', 'jpn': '…の先回りをする'}
# {'ain': 'tanas', 'jpn': '盛り上がっている'}
# {'ain': 'hotuypa haw', 'jpn': '大声で呼ぶ声'}
# {'ain': 'na arsuy kuþ nukar rusuy', 'jpn': 'もう一度、会いたいなぁ。'}
# {'ain': 'po hene', 'jpn': 'なおさら'}
# {'ain': 'tanto anakne kuþ sapo tura upawre þan', 'jpn': '今日は姉さんと口論した'}
# {'ain': 'teeta anakne askepeci or un sippo usi wa ani kuþ mimaki kuþ huraye', 'jpn': '昔は指に塩をつけて、それで私の歯を私は洗った。'}
# {'ain': 'tanto anakne kuþ mataki turano upaore þas', 'jpn': '今日は私の妹と口論した'}
# {'ain': 'hotuyekar', 'jpn': '…を呼ぶ'}
# {'ain': 'cup ahun', 'jpn': '日が沈む'}
# {'ain': 'katu pirka', 'jpn': '容姿が良い'}
# {'ain': 'eciþ kore wa', 'jpn': 'あなたに…をあげるよ。'}
# {'ain': 'katu pirka', 'jpn': '容姿が良い'}
# {'ain': 'katuhu', 'jpn': '…の容姿'}
# {'ain': 'teyne cikuni aþ huyka kor uhuy ka somo ki no supuya patek at wa rekuci wen kuþ kor hapo anakne supuya musiska wa omkeomke wa kþ erampokiwen', 'jpn': '濡れた木を燃やしていても、燃えないで煙ばかり上がる。喘息の私の母は、煙でむせて、こんこんと何度も咳をするから、私はそれをかわいそうに思った。'}
# {'ain': 'kosmat', 'jpn': '嫁'}
# {'ain': 'ponson', 'jpn': '幼児'}
# {'ain': 'toan seta tus kote yan', 'jpn': 'あの犬を紐につなぎなさい。'}
# {'ain': 'apepasuy', 'jpn': '炉辺に置いてある箸'}
# {'ain': 'apepasuy', 'jpn': '炉辺に置いてある箸'}
# {'ain': 'atuhu', 'jpn': '紐'}
# {'ain': 'yayutupare', 'jpn': '用心する'}
# {'ain': 'utcikam utcikam', 'jpn': 'ふくらはぎ'}
# {'ain': 'katu', 'jpn': '…の様子'}
# {'ain': 'kokuban kuþ sapaha eun turse wa', 'jpn': '黒板が私の頭に落ちて'}
# {'ain': 'tane toyta þan kusu ne korka nen ka isam na ney ta ka arpa wa aynunisuk wa ek', 'jpn': '畑を耕すつもりだけど、誰もいないよ。どこか行って人頼みしてきて。'}
# {'ain': 'iyohay sonno he', 'jpn': 'よもや、まさか'}
# {'ain': 'kuai anak kþ erampewtek', 'jpn': '私はわからない。'}
# {'ain': 'usa okay pe aþ enþ kire kusu ye kor an', 'jpn': 'いろいろなことを私にさせるために言っている。'}
# {'ain': 'uenewsar', 'jpn': 'よもやま話をする'}
# {'ain': 'kuþ kor wa kþ apkas', 'jpn': '私はそれを持って歩く。'}
# {'ain': 'menokopo menokopo', 'jpn': '若い女'}
# {'ain': 'kosimpuy', 'jpn': '妖精'}
# {'ain': 'ne ciki', 'jpn': '…や、…も'}
# {'ain': 'ne ciki', 'jpn': '…や、…も'}
# {'ain': 'koyyanke', 'jpn': '寄り上がる'}
# {'ain': 'rametok', 'jpn': '勇敢さ、勇気'}
# {'ain': 'cinoyeinaw', 'jpn': 'よりあわせた削りかけ、よりあわあせたイナウ'}
# {'ain': 'iramkittarara', 'jpn': 'やかましい、うるさい、周りが騒がしくて気になる'}
# {'ain': 'iramkittara', 'jpn': 'やかましい、うるさい、周りが騒がしくて気になる'}
# {'ain': 'popte potte', 'jpn': '…を沸かす'}
# {'ain': 'sampeekoyki', 'jpn': '胸焼けする'}
# {'ain': 'onuman ipe kuþ kar ka somo ki p ne na eciþ ere ka somo ki no eciþ paye yan hani', 'jpn': '夕食を作ってないものだから、食べさせないで行ってちょうだいね。'}
# {'ain': 'nunke', 'jpn': '…を選ぶ'}
# {'ain': 'aynu nunke', 'jpn': '人を選ぶ'}
# {'ain': 'ukohopire', 'jpn': '…を分かれて行かせる'}
# {'ain': 'ukuran', 'jpn': '夕べ'}
# {'ain': 'kþ eramuan', 'jpn': '私はわかった'}
# {'ain': 'toan kurmat nep ka kar yakka niwasnu siri', 'jpn': 'あのご婦人は何をするにも一生懸命なようだな。'}
# {'ain': 'eramuan', 'jpn': '…がわかる'}
# {'ain': 'eþ nu eþ nu', 'jpn': 'もしもし'}
# {'ain': 'konci', 'jpn': '頭巾'}
# {'ain': 'rera hawke', 'jpn': '風が弱い'}
# {'ain': 'kani anakne sekor kuþ yaynu', 'jpn': '私はそうだと思う。'}
# {'ain': 'semitak', 'jpn': '予言する'}
# {'ain': 'uwekarpare', 'jpn': '…を集める、募集する'}
# {'ain': 'uwekarpare', 'jpn': '…を集める、募集する'}
# {'ain': 'somo', 'jpn': 'いいえ'}
# {'ain': 'aþ kor ekasi ponno iku kor sonno ramuriten siri', 'jpn': '私のおじいさんは少し飲むと、とても朗らかになるなあ。'}
# {'ain': 'huton puni wa ukao yan', 'jpn': '布団を上げて、しまいなさい。'}
# {'ain': 'cep an wa kþ eramasuy wa neun neun ka kuþ kar akusu pise ne poro pise ne wa iruskacep sekor aþ ye hawe ne', 'jpn': '魚がいて私は楽しくて何かかにかすると、膨らんで、大きく膨らんで、「怒る魚(フグ)」という話だ。'}
# {'ain': 'niste kam ne yakun poronno aþ popte yakun keraan', 'jpn': '固い肉だからいっぱい茹でたら美味しい。'}
# {'ain': 'poronno aþ suwe kor keraan riten wa keraan', 'jpn': 'たくさん煮ると美味しい。やわらかくなって美味しい。'}
# {'ain': 'yayka', 'jpn': 'やっと'}
# {'ain': 'kuþ kor unihi', 'jpn': '私の家'}
# {'ain': 'kuþ kor cise', 'jpn': '私の家'}
# {'ain': 'kuþ kor cise', 'jpn': '私の家'}
# {'ain': 'kuþ cise or un paye þan ro', 'jpn': '私の家へ行きましょう。'}
# {'ain': 'kuþ cise or un paye þan ro', 'jpn': '私の家へ行きましょう。'}
# {'ain': 'sisam', 'jpn': '和人'}
# {'ain': 'uhekote', 'jpn': '互いの方に向かって、向かい合って'}
# {'ain': 'w ro', 'jpn': '…を水に浸ける'}
# {'ain': 'mame kuþ toyta akusu ri wa pirka', 'jpn': '豆を植えたら、それが伸びて良かった。'}
# {'ain': 'eramuan', 'jpn': '…を理解する、…がわかる'}
# {'ain': 'ene pakno', 'jpn': 'これだけ？'}
# {'ain': 'toykikkar', 'jpn': '…をひどく殴る'}
# {'ain': 'iyotta poro cise', 'jpn': '最も大きな家'}
# {'ain': 'iyotta siretokkor kur', 'jpn': '最もきれいな人'}
# {'ain': 'icakkere', 'jpn': '汚れている'}
# {'ain': 'sine to sine to', 'jpn': '日に日に'}
# {'ain': 'umomare', 'jpn': '…を拾い集める'}
# {'ain': 'iyapo hapo utar', 'jpn': '両親'}
# {'ain': 'emina', 'jpn': '…を笑う'}
# {'ain': 'ona utar', 'jpn': '両親'}
# {'ain': 'eþ kor amip kuþ kor amip utasare þan ro', 'jpn': 'お前の着物と私の着物を取り替えよう'}
# {'ain': 'ekampak', 'jpn': '…を予想する'}
# {'ain': 'urentek ani cikuni kþ ehonkokisma', 'jpn': '両手で薪を私が腹で抱えた。'}
# {'ain': 'urentek ani cikuni kþ ekoraye wa kþ ehonkokisma', 'jpn': '私は両手で薪をかき寄せて、腹で抱えた。'}
# {'ain': 'husko amip', 'jpn': '古い着物'}
# {'ain': 'kapuhu ri', 'jpn': '…の皮を剥ぐ'}
# {'ain': 'tanto upas ruy noyne kuþ ramepakari', 'jpn': '今日は雪がひどうなりそうだと予想する。'}
# {'ain': 'kuþ iruska kor wenpe sani sekor kuþ pasrota', 'jpn': '私は怒りながら、悪いものの血統だとののしった。'}
# {'ain': 'aun acapo ramma koraci cikuni patek tuye kor an', 'jpn': '隣のおじさんはいつものように薪を切ってばかりいる。'}
# {'ain': 'taanpe anakne aþ eyam pe ne na iteki oyra na', 'jpn': 'これは大事なものだから、忘れるんじゃないよ。'}
# {'ain': 'numan susam kamuynomi an wa poronno tonoto kuþ ku wa kuþ yoski', 'jpn': '昨日、シシャモ祭があって、私は沢山お酒を飲んで酔っ払った。'}
# {'ain': 'tane isa wa', 'jpn': 'もう熟しているから'}
# {'ain': 'yaske', 'jpn': '割れる'}
# {'ain': 'kþ enupekne', 'jpn': '私はもらい泣きする（？）'}
# {'ain': 'kuþ hopuni ka niwkes wa kuþ reyereye kor nagasi or un kþ arpa', 'jpn': '私は立つこともできずによつんばいになって流しに行った。'}
# {'ain': 'kap', 'jpn': '皮膚'}
# {'ain': 'hem', 'jpn': '…も'}
# {'ain': 'kamkasike', 'jpn': '皮膚'}
# {'ain': 'anepitta uepeker uenewsar kor an uepeker kor an', 'jpn': '夜通し、物語やよもやま話をしていた。物語を語っていた。'}
# {'ain': 'anepitta huci ekasi utar uekarpa wa kuþ pon hi ta uepeker kor oka hawe kuþ nu', 'jpn': '夜通し、婆ちゃんや爺ちゃんたちが集って、私が小さい時には、物語を語っていた声を聞いた。'}
# {'ain': 'ihoski', 'jpn': '酔う'}
# {'ain': 'kani anakne kþ erampewtek', 'jpn': '私は知らない。'}
# {'ain': 'ekasi', 'jpn': 'おじいさん'}
# {'ain': 'kaboca isa wa aþ e easkay', 'jpn': 'かぼちゃが実ったから、それを食べられる。'}
# {'ain': 'eani araskay wa arpa siri ne kusu toanpe kor wa arpa ka somo ki', 'jpn': 'あんた、身軽で行くようだから、それを持って行かないのかい？'}
# {'ain': 'nen', 'jpn': '四人'}
# {'ain': 'tupesan to', 'jpn': '八日'}
# {'ain': 'ancikartakne', 'jpn': '夜短'}
# {'ain': 'eciþ kore na', 'jpn': 'あなたに…をあげるよ。'}
# {'ain': 'kosmat', 'jpn': '嫁'}
# {'ain': 'katu', 'jpn': '…の様子'}
# {'ain': 'cip asam cip asam', 'jpn': '船底'}
# {'ain': 'sirpeker', 'jpn': '夜が明ける'}
# {'ain': 'enþ kao se', 'jpn': '土産として持って来る'}
# {'ain': 'nihum', 'jpn': '木片、木端'}
# {'ain': 'henoe', 'jpn': '立ち寄る'}
# {'ain': 'ramuritenka', 'jpn': '…を喜ばせる'}
# {'ain': 'aykap menoko anakne nuyto tanne wa hokuhu sikihi okke', 'jpn': '不器用な女は糸が長くて夫の目を突く。'}
# {'ain': 'ikiyanun tan ukuran apto ruy yakun kuþ sakke cep teyne ciki kþ eranak', 'jpn': 'もし、今晩雨が降るなら、私の干した魚が湿ってしまうんじゃないかと心配だ。'}
# {'ain': 'somo', 'jpn': 'いいえ。'}
# {'ain': 'nitat', 'jpn': '谷地'}
# {'ain': 'hamnesuwe', 'jpn': '…を丸ごと煮る'}
# {'ain': 'tane okkayo ek wa ahun noyne an korka nep ka nukar wa kimatek wa hosipi wa isam', 'jpn': '今、男性が来て家に入ったようだけれど、何か見てあわてて帰ってしまった。'}
# {'ain': 'eyaysukupka', 'jpn': '…のことを根に持つ'}
# {'ain': 'kuþ kor cise soy ta okokko etomotuye wa kuþ kimatek', 'jpn': '私の家の表で恐ろしい物（蛇）が横切っていて、びっくりした。'}
# {'ain': 'hosere', 'jpn': '…に返事をさせる、…に呼びかけに答えさせる'}
# {'ain': 'kuþ mokor wa kþ an akusu kuþ poho ek wa kuþ mos', 'jpn': '私が寝ていたが子どもが来たので私は目が覚めた'}
# {'ain': 'tanto anakne sirwen wa eþ soyne ka', 'jpn': '今日は天気が悪いのであなたは外にでることも'}
# {'ain': 'mun ri na', 'jpn': '草が伸びたよ'}
# {'ain': 'kina', 'jpn': '山菜…'}
# {'ain': 'eramkikkar', 'jpn': '…が嫌だ、…にうんざりする'}
# {'ain': 'sine itak patek ye wa kþ eramkikkar', 'jpn': '一つの言葉ばっかり言って私は嫌になる。'}
# {'ain': 'iranakka', 'jpn': 'いやだ、うるさい'}
# {'ain': 'iranakka', 'jpn': 'いやだ、うるさい'}
# {'ain': 'poppise', 'jpn': '水ぶくれ'}
# {'ain': 'kani anakne mukawa un menoko kuþ ne wa', 'jpn': '私は鵡川の女だよ。'}
# {'ain': 'toy wano', 'jpn': 'から…'}
# {'ain': 'aþ eywanke p ne wa', 'jpn': '使われてきたものだよ。'}
# {'ain': 'nupe tura itak kþ osura', 'jpn': '私は泣きながら遺言した'}
# {'ain': 'toankur ahunte yan', 'jpn': 'あの人を入れなさい。'}
# {'ain': 'ikasma', 'jpn': '余剰、余る'}
# {'ain': 'hekote', 'jpn': '…へ向かって'}
# {'ain': 'kþ eraman', 'jpn': '私は…を了解する'}
# {'ain': 'noyke', 'jpn': 'よじれる'}
# {'ain': 'umomare', 'jpn': '…を拾い集める'}
# {'ain': 'rataskep', 'jpn': 'よせ煮'}
# {'ain': 'toankur utar anakne iyapo hapo utar siri ne', 'jpn': 'あの人たちは両親であるようだ。'}
# {'ain': 'sipine', 'jpn': '装う、身支度する、まかなう'}
# {'ain': 'sipine', 'jpn': '装う、身支度する、まかなう'}
# {'ain': 'kuþ sipine', 'jpn': '私は身支度した。'}
# {'ain': 'imotekire na enþ kasuy wa pirka ruwe', 'jpn': 'ちょうどよかったよ。私を手伝ってくれてよかった。'}
# {'ain': 'sinotca', 'jpn': '歌、即興歌'}
# {'ain': 'renuspe', 'jpn': '三つ星'}
# {'ain': 'kemaha nitne wa kuþ riterite kor kþ an', 'jpn': '足が固くなったから揉みほぐしているよ。'}
# {'ain': 'sukus', 'jpn': '日光、日の光'}
# {'ain': 'eþ paha nenpak pa a', 'jpn': 'あなたの年は何才なの？'}
# {'ain': 'pis ta kuþ san akusu sey poronno yan wa paskur kotoyse wa sey risparispa kor an siri kuþ nukar wa', 'jpn': '浜に私が下りると、貝がたくさん上がっていてカラスが群がってその貝をむしっている様子を私は見たよ。'}
# {'ain': 'toan ta pon cikap an wa kuþ kisma rusuy akusu kþ orawki', 'jpn': 'あそこに小鳥がいて私は捕まえたくていたところ、取り逃がした。'}
# {'ain': 'yattuy rit ta anu wa enþ kore rit ta yattuy anu wa enþ kore', 'jpn': 'ゴザを上に置いてください。上にゴザを置いてください。'}
# {'ain': 'kuþ yupo toan isepo kapuhu ri wa enþ kore', 'jpn': '私の息子よ、あのうさぎの皮を?いで。'}
# {'ain': 'atce un kur tane ek na', 'jpn': 'よその人が今来たよ。'}
# {'ain': 'rera hawke', 'jpn': '風が弱い。'}
# {'ain': 'ninpaninpa', 'jpn': '…を引っ張る'}
# {'ain': 'katu nukar', 'jpn': '…を見どころがあると思う、…を将来性があると見込む'}
# {'ain': 'kimatek', 'jpn': 'びっくりする'}
# {'ain': 'nep', 'jpn': '四つ'}
# {'ain': 'toan pon menoko iku wa iku wa oraun cis kor an siri', 'jpn': 'あの娘は飲んで飲んで、それで泣いているよ。'}
# {'ain': 'kesukuran an kor kuþ hokke yakka kuþ mokor ka eaykap kor sikihi makaka wa soy ta kuþ nukar kor toan puyar kari nociw kuþ nukar wa ne nociw hinak pak ek sekor kuþ yaynu kor keskuran an kor an', 'jpn': '毎晩、私は横になっても眠れないと、目を開けて外を見ると、あの窓から星を見て、「あの星はどこまで来た」と思いながら毎晩過ごしている。'}
# {'ain': 'isaroykip', 'jpn': 'やや大型の背負い袋'}
# {'ain': 'noya kar wa sito or omare wa keraan no aþ enþ ere', 'jpn': 'ヨモギをつんで、シトに入れて美味しく食べさせてくれた。'}
# {'ain': 'ho', 'jpn': 'はい'}
# {'ain': 'toan ape eytasa ruy na ponno uska yan', 'jpn': 'あの火はあまりにも強いよ。ちょっと消しなさい。'}
# {'ain': 't kes', 'jpn': '夕方、昼過ぎ'}
# {'ain': 'noyne', 'jpn': '（…する）ようだ'}
# {'ain': 'ekasi', 'jpn': '養父'}
# {'ain': 'noe', 'jpn': '…をよる'}
# {'ain': 'tus kuþ kar kusu kuþ noyenoye', 'jpn': '網をつくるために、それをよった。'}
# {'ain': 'nupes kuþ kep wa pirkano kuþ min wa tus kuþ kar rusuy kusu kuþ noyenoye', 'jpn': 'シナ皮をはいで、きれいに一本一本裂いて、網をつくるためにそれをよった。'}
# {'ain': 'kuþ pon hi ta kani patek ape kuþ una wa', 'jpn': '私が小さい時は、私ばかり火に灰をかけていたよ。'}
# {'ain': 'usa usa', 'jpn': 'めいめい'}
# {'ain': 'apa caka', 'jpn': '戸を開ける。'}
# {'ain': 'hemanta ka turse', 'jpn': '何かが落ちた。'}
# {'ain': 'samo', 'jpn': '和人'}
# {'ain': 'mimara', 'jpn': '…の余った残り'}
# {'ain': 'epeka', 'jpn': '…を目がける'}
# {'ain': 'kanna kamuy', 'jpn': '竜'}
# {'ain': 't rus', 'jpn': '垢がついている、汚れている'}
# {'ain': 'ney ta ne yakka kotan or ta isonkur ka ipesakkur ka okay pe ne haweas wa ipesak pe anakne ikoytupa wa isonkur tura wa ekimne ne yakka pet or un nakka arpa rusuy korka isonkur utar anakne eynupitara wa aþ hoppa wa paye wa isam sekor kazoku no mono kazoku utar anakne cis kor oka sekor kuþ nu', 'jpn': 'どこにでも、集落には猟運の強い人も猟運の無い人もいるものだと言って、猟運のない者はうらやましがって、猟運の強い人と一緒に山へでも川へでも行きたいんだけど、猟運の強い人達はその人を嫌がり、置き去りにされて行ってしまうと家族の者達は泣いていたと私は聞いた。'}
# {'ain': 'tekehe omare', 'jpn': '…に渡す、…に手渡す'}
# {'ain': 'kuþ kor hapo ekuskonna hese ka niwkes wa iyapo kimatek wa hapo penramu or un hussa eciw kor an yakka wen wa ape huci kamuy or un hemanta ka ye kor hoyupu wa rorun puray or un arpa wa rorun puray cakke wa kani pon pe ne kusu pewtanke sekor kuþ yaynu korka hemanta hawehe otusuy resuy ki wa yakka wen wa hosipi wa suy hapo kisma kor kimatek þan akusu hapo ponno ponno poka pirka wa earkinne kimatek siri kuþ nukar', 'jpn': '私の母が突然息もできなくなって父は慌てて、母の胸の上にフッサしていたが、だめで、火の神様に何か言いながら走って東の窓へ行って、東の窓を開けて、私は小さかったので、ペウタンケだと思っていたけれど、何か声を二度三度出してもだめで、戻って母を掴むと慌てていたのだが、母は少しだけよくなって本当に驚いた様子を私は見た。'}
# {'ain': 'anun kur', 'jpn': 'よそから来た人'}
# {'ain': 'sawsawke wa kuþ mi p okari orarirari wa enþ kore', 'jpn': 'ゆるんでいるから、私の布団のまわりを押さえつけてちょうだい。'}
# {'ain': 'siktokoko', 'jpn': '目をぱっちり見開く'}
# {'ain': 'pikuyra', 'jpn': '…をこっそり尾行する'}
# {'ain': 'kani anakne ininu ininninu kor patek kþ an wa', 'jpn': '私は縫い物(編み物)ばかりしているよ。'}
# {'ain': 'osikkote', 'jpn': '…に見惚れる'}
# {'ain': 'kuþ kokowe', 'jpn': 'うちの婿（娘の夫、姉婿、妹婿のことを言う）'}
# {'ain': 'kuþ kokowehe anakne sonno pirka okkaypo ne', 'jpn': 'うちの婿さんは本当によくできた人だ。'}
# {'ain': 'oya mosir or wa nispa utar arki noyne hawas', 'jpn': '別な国から旦那たちが来たような声がする。'}
# {'ain': 'po', 'jpn': '小さい（指小辞）'}
# {'ain': 'toan menoko toan okkaypo tura arupakpe ne kusu iku patek ki wa nepki ka somo ki', 'jpn': 'あの女とあの男は、そろって似た者同士で酒を飲んでばっかりで働きもしない。'}
# {'ain': 'ne rok utar', 'jpn': '例の人々'}
# {'ain': 'iram ikurkur', 'jpn': '面倒臭い'}
# {'ain': 'kani hat kþ e rusuy kusu mata an kor kim ta kþ arpa korka tane anakne hat ka isam aþ uk uske ka isam', 'jpn': '私はヤマブドウが食べたいので、冬になって山に行ったけれど、もはやヤマブドウは無かった。採れる所も無かった。'}
# {'ain': 'tumam', 'jpn': '木の幹'}
# {'ain': 'seta enþ komik wa suma ani kuþ piyekar wa kira wa arpa', 'jpn': '犬が私に吠えたので、石をぶつけると逃げて行った。'}
# {'ain': 'sonno aþ epirka', 'jpn': 'とてもいい。'}
# {'ain': 'penram', 'jpn': '胸'}
# {'ain': 'ekamke', 'jpn': '…の予感がする'}
# {'ain': 'nispane kur', 'jpn': '裕福な人'}
# {'ain': 'esoye', 'jpn': '（箕を揺すって）…を選り分ける'}
# {'ain': 'nisatta kuneywa', 'jpn': '翌朝'}
# {'ain': 'mata an kor kunneasin kþ etoranne', 'jpn': '冬になると夜に便所へ行くのも面倒だ。'}
# {'ain': 'cepkoyki kusu pet or un kþ arpa', 'jpn': '魚を獲るために川に行った。'}
# {'ain': 'nepki kur', 'jpn': '仕事をする人'}
# {'ain': 'keni tuk', 'jpn': '芽が伸びる'}
# {'ain': 'si', 'jpn': '自ら'}
# {'ain': 'kani anakne kþ eramuskari', 'jpn': '私は知らない。'}
# {'ain': 'ci', 'jpn': '自ら'}
# {'ain': 'inkar', 'jpn': '見る'}
# {'ain': 'esirwante', 'jpn': '（…を探して）あたりを見まわす、（…を探して）あたりを見渡す'}
# {'ain': 'nitat', 'jpn': '谷地'}
# {'ain': 'sikittektek', 'jpn': '身をひるがえす'}
# {'ain': 'kuþ hokuhu ponpene wa kisarpuy poypapoypa wa enþ kore sekor hawean kor kuþ kokkapake eninuy', 'jpn': '夫は甘えて「耳をかいてくれ」というと私の膝をまくらにした。'}
# {'ain': 'eciþ hutuyekar yakka somo hose', 'jpn': '私はあなた(あなた達)を呼んだけれど、返事しない。'}
# {'ain': 'eramuan', 'jpn': '…を理解する、…がわかる'}
# {'ain': 'askepet askepet', 'jpn': '指'}
# {'ain': 'eciþ hekota kþ arpa rusuy', 'jpn': 'お前に向かって私は行きたい。'}
# {'ain': 'eciþ hekota kþ arpa rusuy', 'jpn': 'お前に向かって私は行きたい。'}
# {'ain': 'turep taktakse wa satke', 'jpn': 'ウバユリを丸めて干す。'}
# {'ain': 'noye', 'jpn': '…をよじる'}
# {'ain': 'opetperke amip', 'jpn': '破れ着物'}
# {'ain': 'wakka seru', 'jpn': '水でむせる'}
# {'ain': 'nep nep ne yakka', 'jpn': 'なんでも'}
# {'ain': 'ekimne arpa', 'jpn': '山に行く。'}
# {'ain': 'ekimne arpa', 'jpn': '山に行く。'}
# {'ain': 'okimne', 'jpn': '山から'}
# {'ain': 'eþ mokor ka somo ki kor an na', 'jpn': '君は寝ないでいるから'}
# {'ain': 'haruan nankor ne', 'jpn': '豊作だろう'}
# {'ain': 'tanpa anakne sirkem noyne kuþ wentarap', 'jpn': '今年は飢饉らしい夢を見た'}
# {'ain': 'tanpa anakne haru an noyne kuþ wentarap', 'jpn': '今年は豊作らしい夢を私は見た'}
# {'ain': 'sawnu', 'jpn': '（帯などが）ゆるい'}
# {'ain': 'sikiru', 'jpn': '向く、向きなおる'}
# {'ain': 'si e', 'jpn': '糞くらえ'}
# {'ain': 'sawsawke ontaro anakne sawsawke', 'jpn': 'ゆるんでいる。樽はゆるんでいる。'}
# {'ain': 'eyaske', 'jpn': 'ひび'}
# {'ain': 'sittumpeker', 'jpn': '夜が明ける'}
# {'ain': 'kunne apkas', 'jpn': '夜歩きする'}
# {'ain': 'so', 'jpn': '面、座'}
# {'ain': 'so pirka', 'jpn': '（座る）面がいい。'}
# {'ain': 'nen kuþ ipe rapok ta hunna ka enþ hotunuyekar kusu ek', 'jpn': '誰か…私が食事している最中に、誰かが私を呼びに来た。'}
# {'ain': 'use kur', 'jpn': '普通の人、平凡な人'}
# {'ain': 'ahupkar makkaci', 'jpn': '貰い子（女の子）'}
# {'ain': 'ahupkar makkaci', 'jpn': '貰い子（女の子）'}
# {'ain': 'ahupkar matkaci', 'jpn': '貰い子（女の子）'}
# {'ain': 'ahupkar', 'jpn': '…を貰う、…を貰いに行く'}
# {'ain': 'weniyoski', 'jpn': '酔いすぎる、ひどく酔っ払う'}
# {'ain': 'kuþ matnepo', 'jpn': '私の娘'}
# {'ain': 'toan ekasi arpa rusuy noyne an na kemaha ka wen inunukaski p ne na rura wa paye yan', 'jpn': 'あのおじいさんは行きたがっている様子だよ。足も悪くて可哀そうなもんだよ。送っていきなさい。'}
# {'ain': 'usey kuþ ku rusuy korka isam', 'jpn': 'お湯を飲みたかったけど、無かった。'}
# {'ain': 'e', 'jpn': '「うん。」'}
# {'ain': 'kuþ turusi kuþ turusi', 'jpn': '私は朦朧とした。'}
# {'ain': 'to teeta ekasi huci utar isoytak hawe kuþ nu', 'jpn': 'と、昔、爺さん婆さん達が話すのを聞いた。'}
# {'ain': 'cise or un omare wa anu yan', 'jpn': '家の中に'}
# {'ain': 'arpa siri ka kþ erampewtek wa ikokanu wa kþ an', 'jpn': '（彼が）行ったか分からなくて、私は耳を澄まして聞いていた。'}
# {'ain': 'mame pirka uske kuþ numke', 'jpn': '豆のいいほうを選ぶ。'}
# {'ain': 'numke', 'jpn': '…を選ぶ。H140'}
# {'ain': 'uhuyka', 'jpn': '…を焼く、…を燃やす'}
# {'ain': 'uhuyka', 'jpn': '…を焼く、…を燃やす'}
# {'ain': 'mata an kor kunneasin siri kþ etoranne', 'jpn': '冬になると、夜に便所へ行くのも面倒だ。'}
# {'ain': 'purse kor an na', 'jpn': '湧いているよ。'}
# {'ain': 'mean wa cikuni ka isam ni uype poka uwomare wa ek wa ape ari yan mean na', 'jpn': '寒くて薪がない。棒きれでも拾い集めてきて火を焚きなさい。寒いよ。'}
# {'ain': 'papusturiri', 'jpn': 'ふくれっ面する'}
# {'ain': 'kuþ paroho ka ronronke kor nep ka suy kuþ nukar ka kuþ paroruy ka kuþ sitne noyne sekor kuþ yaynu kor', 'jpn': '私の口もぴくぴくして、何かまた私は見るのも、おしゃべりするのも、よじれ苦しむようだと思って'}
# {'ain': 'totto kure yan', 'jpn': '乳を飲ませさい。'}
# {'ain': 'toan oypepi ekte', 'jpn': 'あの食器をよこして。'}
# {'ain': 'arwenkinrakar', 'jpn': 'ひどく興奮する'}
# {'ain': 'kina kuþ kar kusu kim ta or arpa', 'jpn': '山菜を採るために、山に行って'}
# {'ain': 'sukep h ra', 'jpn': '焦げた匂い'}
# {'ain': 'patta kikir', 'jpn': 'バッタ'}
# {'ain': 'mimu', 'jpn': '木によじ登る'}
# {'ain': 'nimu', 'jpn': '木によじ登る'}
# {'ain': 'tokkoni ukonoynoyke wa oka siri aþ nukar wa aþ sitoma kusu korkoni ham ne yakka noya ne ne yakka aþ uk wa kasi aþ kumare kor pirka sekor huci utar isoytak hawe kuþ nu', 'jpn': '蛇がよじり合って交尾しているのを見て恐ろしいから、蕗の葉やヨモギを採って、その上にかぶせるといいと婆ちゃんたちが言っているのを聞いた。'}
# {'ain': 'kim', 'jpn': '山'}
# {'ain': 'tane anakne isam', 'jpn': '今はいない。'}
# {'ain': 'ape uska yan', 'jpn': '火を消しなさい'}
# {'ain': 'seta tup enþ kesanpa kor an', 'jpn': '犬が二匹私を追いかけてきた。'}
# {'ain': 'haru an kor anakne pirka okkaypo ne korka kem an pa anakne etupsike tontone', 'jpn': '豊作になるときれいなオスだけれど、不作の年は先が禿げている。'}
# {'ain': 'pakita', 'jpn': 'たまに'}
# {'ain': 'kþ erampewtek', 'jpn': '私は知らない。'}
# {'ain': 'puri wen pe', 'jpn': '悪い者、精神の悪い人'}
# {'ain': 'iutap', 'jpn': 'パッタリ、踏み臼'}
# {'ain': 'si e', 'jpn': '糞くらえ'}
# {'ain': 'ekimne', 'jpn': '山へ行く'}
# {'ain': 'apunno', 'jpn': '静かに、穏やかに、何事もなく'}
# {'ain': 'soske', 'jpn': '…がむける'}
# {'ain': 'kuþ kokowe', 'jpn': 'うちの婿（娘の夫、姉婿、妹婿のことを言う）'}
# {'ain': 'weniyoski', 'jpn': '酔いすぎる、ひどく酔っ払う'}
# {'ain': 'tanto anakne daresore ek wa ene hawean wa kani ka kuþ tura no kþ enupetne', 'jpn': '今日は、だれそれが来てこのように言って、私も一緒にもらい泣きをした(？)。'}
# {'ain': 'kuþ kor cise okari mun poronno hetuku wa kþ uk ka kþ etoranne', 'jpn': '私の家のまわりの草がいっぱい生えて、取るのも面倒だ。'}
# {'ain': 'kuþ sinki wa hontom ta kuþ sini', 'jpn': '私は疲れて、途中で休んだ。'}
# {'ain': 'tane onuman an kusu ipe etokoyki kuþ ki kusu ne na', 'jpn': 'もう夕方になったので、食事を用意するつもりだよ。'}
# {'ain': 'apa sam ta anu', 'jpn': '戸口に置いた。'}
# {'ain': 'eronne', 'jpn': '東'}
# {'ain': 'cep aþ ma wa aþ e ro', 'jpn': '魚を焼いて食べましょう。'}
# {'ain': 'numke', 'jpn': '…を選る'}
# {'ain': 'yarpok', 'jpn': '脇の下'}
# {'ain': 'itapar', 'jpn': '玄関の上り口の床'}
# {'ain': 'poknasir', 'jpn': 'あの世、地獄'}
# {'ain': 'aynutukap', 'jpn': '亡霊'}
# {'ain': 'icimcimi', 'jpn': 'あら探し、注意深く見る'}
# {'ain': 'easir', 'jpn': '初めて'}
# {'ain': 'ho', 'jpn': 'はい'}
# {'ain': 'tane unukar þan wa uepaspas þan', 'jpn': '今、会ってお互いに駆け寄った。'}
# {'ain': 'ru eronne', 'jpn': '道の東側'}
# {'ain': 'amip patek ne yakun hayta p ne kusu', 'jpn': '着物だけなら、足りないものだから、'}
# {'ain': 'rutom ta', 'jpn': '道路ぶちに'}
# {'ain': 'rutom', 'jpn': '道路ぶち'}
# {'ain': 'toan caca anak wen sampe kor', 'jpn': 'あのおじいさんは根性が悪い？'}
# {'ain': 'toan caca weysampe kor wa toan caca kþ emaka', 'jpn': 'あのおじいさんは根性が悪くて、あのおじいさんは嫌いだ。'}
# {'ain': 'toan caca ek siri noyne an wa kþ eynupitara', 'jpn': 'あのおじいさんが来るようで私は嫌だ。'}
# {'ain': 'ohaw kuþ suye akusu ika wa una or un rur oma wa una patce wa oyoyo sekor kuþ hawean kor kuþ kira', 'jpn': 'お汁を炊いたらあふれて、灰に汁がかかって、灰が飛んで「オヨヨ」と私は言いながら逃げた。'}
# {'ain': 'kani sapporo or un kþ arpa rusuy sapporo or un kþ arpa rusuy kusu kuþ sipine wa', 'jpn': '私は札幌に行くのに…行きたいので、身支度した。'}
# {'ain': 'tosi', 'jpn': 'ふるい'}
# {'ain': 'oputuye', 'jpn': '…を押し戻す'}
# {'ain': 'tane nen ka isam wa tane anak nen ka isam wa', 'jpn': '今は誰もいないよ。'}
# {'ain': 'iyokunnure', 'jpn': 'びっくりする'}
# {'ain': 'tumaoma', 'jpn': 'ひびが入る'}
# {'ain': 'aþ eywanke noyne an pe', 'jpn': '使えそうなもの'}
# {'ain': 'eyasperke', 'jpn': 'ひびが入る'}
# {'ain': 'eyaske', 'jpn': 'ひびが入る'}
# {'ain': 'asir cup', 'jpn': '三日月、新月'}
# {'ain': 'kuneywa', 'jpn': '朝'}
# {'ain': 'reyereye', 'jpn': 'よつんばいになって歩く'}
# {'ain': 'nen', 'jpn': '四人'}
# {'ain': 'pewreno isam', 'jpn': '若死にする'}
# {'ain': 'sikucupupu', 'jpn': '何回も目を閉じる'}
# {'ain': 'kuþ poho nepki ka somo ki no sinot kor patek an wa kuþ kaspaotte yakka wen', 'jpn': '私の息子は働きもしないで遊んでばかりいて私は説教したけれど駄目だ'}
# {'ain': 'katu pirka', 'jpn': '容姿が良い'}
# {'ain': 'korar', 'jpn': '…を人にやる'}
# {'ain': 'cup ran', 'jpn': '日が沈む。'}
# {'ain': 'pon hekaci hunna ka suy kikkik wa ene kirirse kor an hawe', 'jpn': '小さな子が誰かにまた殴られてあのように泣いているようだ。'}
# {'ain': 'ritenka', 'jpn': '…をやわらかくする'}
# {'ain': 'an noyne an na', 'jpn': 'いるようだよ。'}
# {'ain': 'kuþ sampemurmurse', 'jpn': '私は胸騒ぎがする'}
# {'ain': 'ueinkar noyne', 'jpn': '巫力が強いようだ'}
# {'ain': 'aþ ma cep', 'jpn': '焼き魚'}
# {'ain': 'cikuni uhuyka', 'jpn': '木を焼く。'}
# {'ain': 'oteksak', 'jpn': '裕福じゃない'}
# {'ain': 'tuymanokkus', 'jpn': 'そっぽを向く'}
# {'ain': 'tuymanokkus', 'jpn': 'そっぽを向く'}
# {'ain': 'kuþ nippoho kakko or un moyre noyne an wa hoyupu wa arpa', 'jpn': '私の孫は学校に遅れそうで、走って行った。'}
# {'ain': 'ya ka', 'jpn': '…なのか'}
# {'ain': 'sekiyu hako aþ omare wa moro ni aþ kar wa oro un emo ne yakka nep ne yakka aþ omare wa oka þan pe ne awa sine an to ta kuþ kor hapo emo sanke ohaw aþ kar ro sekor hawean kusu kusu moro puta kuþ caka wa kuþ nukar ka nep ka isam hapo emo anakne nep ka isam wa tte makanakne wa isam hawe nap sekor kuþ yaynu tte hapo', 'jpn': '（芋やかぶなどのもらいものは）石油箱に入れられて、室に入れられて、そこに芋でも何でも入れられていたものだったが、ある日、私の母が「芋を出しなさい。オハウ〔汁もの〕をつくろう」と言うので、私はそうするのに、室の蓋を開いて中を見たけど何も無かった。「お母さん、芋も何も無いよ」って（私が言うと）、「どうして無いって話があるかと思うよ」と母が（言うので）'}
# {'ain': 'ya kuþ kisma wa akusu raosma', 'jpn': '網を掴んだところ、落っこちた。'}
# {'ain': 'opecikcik kor an yakka kuþ nu ka eramuskari', 'jpn': 'おもらししていたけれど、私は気付かなかった'}
# {'ain': 'kani ka iwanke wa kþ an na', 'jpn': '私も元気でいたよ。'}
# {'ain': 'amam aþ omare pukuro', 'jpn': '米を入れる袋'}
# {'ain': 'kina aþ cire akusu usey nin wa isam na wakka ponno suy omare yan', 'jpn': '山菜をゆでるとお湯が減ってしまうよ。水をちょっとまた入れなさい。'}
# {'ain': 'puta kankan kuþ suwe akusu nin wa ponno patek ne na', 'jpn': '豚の腸を私が煮ると、少しになってしまった。'}
# {'ain': 'pirasa yan', 'jpn': '開きなさい'}
# {'ain': 'nimu', 'jpn': '木によじ登る'}
# {'ain': 'sinonruki', 'jpn': '生唾を飲む'}
# {'ain': 'cep ponno an wa kuþ sippousi wa kþ anu akusu ma wa kþ e rusuy sekor kuþ yaynu kor horse wa an', 'jpn': '魚が少しあって、塩をして置いておいたところ、焼いて食べようと思うと腐っていた。'}
# {'ain': 'ipe þan ro', 'jpn': '食事をしよう'}
# {'ain': 'horse', 'jpn': '腐乱する、腐る'}
# {'ain': 'hurkap', 'jpn': '抜け殻'}
# {'ain': 'ekampak', 'jpn': '…を予想する'}
# {'ain': 'upas as', 'jpn': '雪が降る'}
# {'ain': 'tus kuþ turpa wa kuþ mipihi kuþ satke', 'jpn': '私は綱を張って私の着物を干した'}
# {'ain': 'makanak eþ hawean hawe', 'jpn': '何て言ったの？'}
# {'ain': 'siyuk siyuk', 'jpn': '装う'}
# {'ain': 'tosi', 'jpn': 'ふるい'}
# {'ain': 'siktokoko', 'jpn': '目をぱっちり見開く'}
# {'ain': 'patukuku', 'jpn': '（口を尖らせて）ふくれる'}
# {'ain': 'toan okkaypo kþ osikkote wa kþ opikuyra', 'jpn': 'あの男の人に私は惚れたのでこっそり後をつけた。'}
# {'ain': 'arsik', 'jpn': '片目'}
# {'ain': 'artusa', 'jpn': '片袖'}
# {'ain': 'sirpopke patek an kusu ontaro ka sawsawke', 'jpn': '暖かい日ばかりだから、樽も（乾いてしまって）ゆるゆるだ。'}
# {'ain': 'emaka', 'jpn': '…が必要ない'}
# {'ain': 'uekap', 'jpn': '懐かしみながら挨拶する'}
# {'ain': 'ataye hawke korka kuþ kor rusuy ka somo ki', 'jpn': '安くなったけれど、欲しくない。'}
# {'ain': 'utur kotne utur tanas', 'jpn': '間がくぼんだり、もりあがったりしている。'}
# {'ain': 'etoko tusmak', 'jpn': '…の先回りをする'}
# {'ain': 'su or un wakka kþ omare kusu', 'jpn': '鍋へ水を入れるために'}
# {'ain': 'hotuypa', 'jpn': '大声で呼ぶ'}
# {'ain': 'makanak aþ kar ciki pirka p ne enþ epakasnu yan', 'jpn': 'どうやったらよいものか。私に教えてちょうだい。'}
# {'ain': 's so', 'jpn': '右座'}
# {'ain': 'harusoyo omare þan ro', 'jpn': '供え物をおきなさい'}
# {'ain': 'sampemurmurse', 'jpn': '胸騒ぎがする、心臓がどきどきする、動機が激しくなる'}
# {'ain': 'ape huci kamuy', 'jpn': '火の神様'}
# {'ain': 'harusoyo yan', 'jpn': '供物を外に出しなさい。'}
# {'ain': 'nupur kor kamuy', 'jpn': '山の神様'}
# {'ain': 'kimunkamuy', 'jpn': 'クマ'}
# {'ain': 'aþ kor pon mosir kamuy', 'jpn': '大地の神様'}
# {'ain': 'aþ kor pon mosir kamuy', 'jpn': '大地の神様'}
# {'ain': 'aþ kor mosir kamuy aþ kor mosir kamuy', 'jpn': '大地の神様'}
# {'ain': 'mosirkor kamuy', 'jpn': '大地の神様'}
# {'ain': 'atuy kor kamuy', 'jpn': '海の神様'}
# {'ain': 'atuy kor kamuy aþ kor mosir epunkine wa enþ kore yan hani', 'jpn': '海の神さま、私たちの大地を守ってください。'}
# {'ain': 'sinpuy kamuy', 'jpn': '井戸の神様'}
# {'ain': 'sinpuy kamuy', 'jpn': '井戸の神様'}
# {'ain': 'aþ kor hekattar ahun rapok epunkine wa enþ kore yan hani apasam un kamuy', 'jpn': '私たちの子供たちが入る時を守ってください。戸口の神さま。'}
# {'ain': 'kani pon makkaci siyeye wa nen aþ kar yakka pirka ka somo ki no kuþ paraparak wa', 'jpn': '私は小さな女の子が病気でどうやってもよくならなくて、私はわあわあと泣いた。'}
# {'ain': 'taan pe akkari toan pe poro', 'jpn': 'これよりもあれのほうが大きい。'}
# {'ain': 'amam okke wa kuþ tuytuye wa kuþ soyesoye', 'jpn': '穀物をついて、箕でふるって籾殻を飛ばして、揺すって選り分けた。'}
# {'ain': 'purpurse', 'jpn': '湧き上がる、湧き出る'}
# {'ain': 'pirka hawe ne', 'jpn': 'いいですね。'}
# {'ain': 'pop kor an', 'jpn': '沸いている。'}
# {'ain': 'peta ru', 'jpn': '水汲みに行く道'}
# {'ain': 'u=pon hi ta anakne yacipocipoci kor kuþ sinot', 'jpn': '私が子どもの頃は、泥んこの中に入ってビチャビチャになりながら遊んだ。'}
# {'ain': 'ona otpare', 'jpn': '父親に不孝をする'}
# {'ain': 'sipasnu', 'jpn': '頭がいい'}
# {'ain': 'upas yupke', 'jpn': '雪がひどい'}
# {'ain': 'sipasnu', 'jpn': '頭がいい'}
# {'ain': 'kuþ nu ka eramuskari', 'jpn': '私は聞いたことがない。'}
# {'ain': 'mosma', 'jpn': '別に'}
# {'ain': 'us', 'jpn': '場所'}
# {'ain': 'mokor', 'jpn': '眠る'}
# {'ain': 'huskotoy wano aþ eywanke', 'jpn': '昔から使ってきた…'}
# {'ain': 'kirirse', 'jpn': '（動物や子どもなどが）キーキーとなく'}
# {'ain': 'kimun kamuy', 'jpn': '山の神様'}
# {'ain': 'cikap poronno soy ta ek kor kani amam kuþ carpacarpa wa kuþ kore', 'jpn': '鳥がたくさん来ると私は穀物を撒いてあげる。'}
# {'ain': 'osura ka eaykap wa ukao wa an', 'jpn': 'すてることもできないでしまってある。'}
# {'ain': 'risparispa', 'jpn': '…をむしり食う、（骨付き肉など）を骨からはがして食べる'}
# {'ain': 'poro opke wa', 'jpn': '大きいおならをして'}
# {'ain': 'utari puri', 'jpn': '仲間の風習'}
# {'ain': 'aynu puri', 'jpn': 'アイヌの風習'}
# {'ain': 'erampewtek', 'jpn': '…がわからない'}
# {'ain': 'keni tuk', 'jpn': '芽が伸びる'}
# {'ain': 'tannere', 'jpn': '…を長く伸ばす'}
# {'ain': 'kuþ kor matnepo kuneywa or wa sirkunne or un pakno eniwasnu wa kþ eyaykopuntek', 'jpn': '私の娘は、朝から晩まで頑張るので、私は嬉しい。'}
# {'ain': 'kuþ kema tukunne wa kuþ turiri rusuy', 'jpn': '私は足がしびれたから伸ばしたい。'}
# {'ain': 'kuþ nu ka erampewtek pe anakne kuþ nu ka eynupitara', 'jpn': '聞いたこともないものだったので私は聞くのも嫌だった(聞くのを避けた)。'}
# {'ain': 'eposokane eposoun', 'jpn': '当たり前だよ。'}
# {'ain': 'katuhu an', 'jpn': '変な格好をしている、格好悪い'}
# {'ain': 'teta maciya or un kþ arpa rusuy kusu nepka kuþ hok wa kþ e rusuy sekor kuþ yaynu wa maci or un kþ arpa rusuy kusu ponno kþ apkas akusu rera yupke p ne kusu kþ apkas ka eaykap wa kuþ hosipi', 'jpn': 'この間、まちに行きたいので、何か買って食べたいと思って、まちに行きたかったので少し歩くと、風が強いものだから歩くこともできなくて帰った。'}
# {'ain': 'imo sito kappakappa yan', 'jpn': 'イモ団子を平らにしてください。'}
# {'ain': 'ceppo koyki kusu pet turasi kþ arpa', 'jpn': '小魚を獲るために川上へのぼって私は行った。'}
# {'ain': 'suy coka anakne arki þas kusu ne na suy coka anakne arki þas kusu ne na', 'jpn': 'また私達はきますよ。また私達はきますよ'}
# {'ain': 'urenkema', 'jpn': '両足'}
# {'ain': 'emo kuþ suye wa cik kusu kþ ecikiki', 'jpn': '芋を茹でて、水が垂れるので煮汁をこぼした。'}
# {'ain': 'rataskep', 'jpn': 'よせ煮'}
# {'ain': 'cipoyep', 'jpn': 'よせ煮'}
# {'ain': 'ape uska', 'jpn': '火を消す'}
# {'ain': 'toponra', 'jpn': '藻'}
# {'ain': 'hamuhu', 'jpn': '…の葉'}
# {'ain': 'soy ta nen ka ek noyne hawas na soyne wa inkar', 'jpn': '誰か外に来ているような音がするから、外に出て見ておいで。'}
# {'ain': 'oykus', 'jpn': '漏る'}
# {'ain': 'oykus', 'jpn': '漏る'}
# {'ain': 'karanke', 'jpn': '近寄る'}
# {'ain': 'toan tus kor ek wa sina wa enþ kore', 'jpn': 'あの紐を持ってきてつないでくれ。'}
# {'ain': 'noya sito', 'jpn': 'ヨモギ餅'}
# {'ain': 'ukousaraye', 'jpn': '…を分かち合う'}
# {'ain': 'tanepo kuþ nu', 'jpn': '私は初めて聞いた。'}
# {'ain': 'ney ta ka kþ arpa wa cise soy kuþ nukar kor pirkano aþ casnure wa kuþ nukar tan cise or ta oka kur anakne niwasnu kur patek an pe ne ruwe ne sekor kuþ yaynu', 'jpn': '私はどこかへ行って家の外を見ると、きれいに掃除してあったのを見た。この家に住む人は働き者ばかりなんだと思った。'}
# {'ain': 'cep kuþ koyki kusu pet or un kþ arpa', 'jpn': '魚を獲るために川に行った。'}
# {'ain': 'yarpok', 'jpn': '脇の下'}
# {'ain': 'yarpok', 'jpn': '脇の下'}
# {'ain': 'arpa þan ro', 'jpn': '行きましょう'}
# {'ain': 'wenpurikor', 'jpn': '罪を犯す'}
# {'ain': 'ruhayta', 'jpn': '愚か者、ばか'}
# {'ain': 'hayta kur', 'jpn': '愚か者、ばか'}
# {'ain': 'usa usa', 'jpn': 'めいめい'}
# {'ain': 'esirwante', 'jpn': '（…を探して）あたりを見まわす、（…を探して）あたりを見渡す'}
# {'ain': 'kani eciþ kemaha kþ oterke wa kþ eyayapapu', 'jpn': '私はあなた達の足を踏んでしまってごめんなさい。'}
# {'ain': 'samakehe', 'jpn': '…のそば、…の横'}
# {'ain': 'suwe', 'jpn': '煮る'}
# {'ain': 'kuþ tokuye utar sinewe kusu ek rusuy sekor hawas wa poronno ek wa iyahunke wa kþ an', 'jpn': '友達が遊びに来たいという話だったので、たくさん来て、私は招き入れていた。'}
# {'ain': 'kuþ kor katkemat utar poronno arki sekor hawas na iyahunke yan', 'jpn': '奥さん方がたくさん来たという話だ。招き入れなさい。'}
# {'ain': 'rareyaka', 'jpn': '目配せする'}
# {'ain': 'uray', 'jpn': 'やな'}
# {'ain': 'upaskikir nukar kor tane upas ruy ruy siri hanke ruwe ne', 'jpn': '雪虫を見ると、もう雪が降るのも近いということだ。'}
# {'ain': 'kim', 'jpn': '山'}
# {'ain': 'esanniyo', 'jpn': '…するつもりだ、…を心づもりする'}
# {'ain': 'kuþ ye ka etoranne', 'jpn': '言いたくもない。'}
# {'ain': 'para', 'jpn': '広い'}
# {'ain': 'etakasure', 'jpn': '最も'}
# {'ain': 'etakasure pirka cise', 'jpn': '最もよい家'}
# {'ain': 'para', 'jpn': '広い'}
# {'ain': 'mike', 'jpn': '照る、光る'}
# {'ain': 'toan kur pinupinu no ormomekar kor an', 'jpn': 'あの人はささやき、なじっている'}
# {'ain': 'enþ piru wa ani soyne wa soy ta makanak iki siri ne yakka kþ erampewtek korka tu suy re suy ene an ikokatun siri kuþ nukar kuþ ki', 'jpn': '私を祓い清めて、それで外に出て、外で何をやっていたのかはわからないけれど二度三度そのようなことをするのを見た。'}
# {'ain': 'ni uype', 'jpn': '木の切れ端'}
# {'ain': 'sirkirap', 'jpn': '悩む'}
# {'ain': 'inanike inanike', 'jpn': 'どれ'}
# {'ain': 'wen ipokas', 'jpn': 'ひどく醜い'}
# {'ain': 'ikor isam wa', 'jpn': 'お金が無くて。'}
# {'ain': 'wenipokas', 'jpn': 'ひどく醜い'}
# {'ain': 'osirus', 'jpn': '病床に伏す'}
# {'ain': 'hotuypa', 'jpn': '大声で呼ぶ'}
# {'ain': 'yu yu', 'jpn': '湯、温泉'}
# {'ain': 'hemanta kþ e ka somo ki pe ne kuþ sampekoyki humi an', 'jpn': '何か食べたわけでもないのに、胸焼けしているようだ。'}
# {'ain': 'popte yan', 'jpn': '沸かしてください。'}
# {'ain': 'noypa', 'jpn': 'ねじる'}
# {'ain': 'toan cape kisma wa enþ kore', 'jpn': 'あの猫を捕まえてくれ'}
# {'ain': 'tanpe hemanta an', 'jpn': 'これは何ですか？'}
# {'ain': 'nep ne yakka kþ erampewtek', 'jpn': '何であれ私はわからない'}
# {'ain': 'tat noypa', 'jpn': '樺皮をよる'}
# {'ain': 'tat noypa', 'jpn': '樺皮をよる'}
# {'ain': 'nep ka', 'jpn': '何か'}
# {'ain': 'nep ka', 'jpn': '何か'}
# {'ain': 'toan ohaw nipopke wa kþ e ka emaka', 'jpn': 'あの汁が腐って、私は食べる……食べるのも、嫌がった。'}
# {'ain': 'taan ohaw nipopke wa kþ e emaka', 'jpn': 'この汁が腐ってしまい、私は食べるのを嫌がった。'}
# {'ain': 'amappo ani ermu kuþ kisma wa pet or un kþ arpa wa raworer wa kuþ rayke', 'jpn': '仕掛け弓で鼠を捕まえて、私は川へ行き、沈めて（？）殺した。'}
# {'ain': 'eþ eramuan', 'jpn': 'わかりましたか？'}
# {'ain': 'ek kane iki', 'jpn': 'ひょっこりとくる'}
# {'ain': 'makkosanpa', 'jpn': '飛び起きる'}
# {'ain': 'he', 'jpn': '…なのか？'}
# {'ain': 'ita pirpa yan', 'jpn': '床拭きなさい。'}
# {'ain': 'uyna', 'jpn': '…を拾う'}
# {'ain': 'suy hatsubu eþ e wa ek ek ruwe ne ne na', 'jpn': 'お前はまたハツブ食べてきたのか。'}
# {'ain': 'apekur yan', 'jpn': '火にあたりなさい。'}
# {'ain': 'tane onuman an na ape ari wa suke etokoyki', 'jpn': 'もう夕方になったよ。火を焚いて料理の準備をしなさい。'}
# {'ain': 'toykokisma', 'jpn': '…を引っ掴む、…をがっちり掴む'}
# {'ain': 'nupuri kes ta iwan cironnup menoko cironnup an wa aþ ekote nispa menoko ru orowa eikka wa arpa wa aþ esinot kor an siri aþ nukar wa iruska ne manu aþ ki wa corawki þan wa', 'jpn': '山裾に六匹の狐、女狐がいて、私の旦那は、女便所から狐にさらわれて行った旦那が遊ばれている様子を目にし、怒りというものを覚えて、それで喧嘩に行って、'}
# {'ain': 'kþ arpa wa iwan cironnup toykotota munkotota wa kuþ rayke wa isam', 'jpn': '私が行くと、六匹の狐を土とともに草とともに刻んで、私は殺してしまった。'}
# {'ain': 'hapo', 'jpn': 'お母さん'}
# {'ain': 'kuþ suke okere na ipe þan ro', 'jpn': '料理が終わりましたよ。食べましょう'}
# {'ain': 'imok', 'jpn': '配る'}
# {'ain': 'mesi', 'jpn': 'ごはん'}
# {'ain': 'wenpe sani', 'jpn': '悪い者の血統'}
# {'ain': 'ruwe kem', 'jpn': '太い針'}
# {'ain': 'enþ kosiponpenere', 'jpn': '私になつく'}
# {'ain': 'enþ kosiponpenere', 'jpn': '私になつく'}
# {'ain': 'eramuosma e kþ eramuosma wa', 'jpn': '同感する？\u3000――はい。私は同感するよ。'}
# {'ain': 'taan oper enþ ko', 'jpn': 'この少女は私に…'}
# {'ain': 'kuþ inkar', 'jpn': '私は見る'}
# {'ain': 'semor or wa cikuni cise or onnayke omare yan', 'jpn': '土間から、木を家の中に入れなさい。'}
# ...
# {'ain': 'sine wo pakno somo aþ eyyok', 'jpn': '五寸ほど売ってくれませんか？'}
# {'ain': 'moma', 'jpn': 'スモモ'}
# {'ain': 'rakur as', 'jpn': '霧が出る、霧雨が降る。'}
# {'ain': 'ahupkar', 'jpn': '～をもらう'}
# {'ain': 'kþ eyramnukuri yakka kuþ ye ya', 'jpn': '申し訳ありませんが、言いましょうか？'}
# {'ain': 'nitay kenas', 'jpn': '林;木原'}
# {'ain': 'oykus', 'jpn': '漏る'}
# {'ain': 'na na akkari', 'jpn': 'もっと;なおそれ以上に'}
# {'ain': 'na pon', 'jpn': 'もっと小さい'}
# {'ain': 'na an', 'jpn': 'もっとある'}
# {'ain': 'na akkari aþ eramasu p isam ruwe', 'jpn': 'もっと面白いものはないの？'}
# {'ain': 'na akkari pirka p isam ruwe an', 'jpn': 'もっといいものはないの？'}
# {'ain': 'na hakei ta arki þan hike makanak ne ruwe an', 'jpn': 'もっと手前に来たらいかがですか？'}
# {'ain': 'ay', 'jpn': '矢'}
# {'ain': 'ay kanci', 'jpn': '矢筈（やはず）'}
# {'ain': 'ay makanit', 'jpn': '矢骨'}
# {'ain': 'ay rap', 'jpn': '矢羽'}
# {'ain': 'ay rum', 'jpn': '矢尻'}
# {'ain': 'ay sup', 'jpn': '矢がら、箆（の）'}
# {'ain': 'tukan', 'jpn': '～を射る'}
# {'ain': 'ay ani yuk rayke ruwe ne', 'jpn': '矢でシカを殺したのだ。'}
# {'ain': 'irampotarare', 'jpn': 'やかましい'}
# {'ain': 'irampotarare paye yan', 'jpn': 'うるさい！ 行きなさい。'}
# {'ain': 'ima cima', 'jpn': '（肉や魚を）焼く;焼く'}
# {'ain': 'imanit', 'jpn': '焼き串'}
# {'ain': 'yomomke', 'jpn': '（焼けて）チリチリにちぢれる'}
# {'ain': 'cima cep', 'jpn': '焼き魚'}
# {'ain': 'ekampakte hi', 'jpn': '約束、前もって知らせたこと'}
# {'ain': 'ekampakte hi ecutko no ki', 'jpn': '約束を破る。'}
# {'ain': 'aþ eywanke eaykap pe', 'jpn': '使えないもの'}
# {'ain': 'sapane kur', 'jpn': '役人'}
# {'ain': 'sapane kur oro un enþ tura yan', 'jpn': '役人のところへ私を連れて行ってください。'}
# {'ain': 'hapur hawke', 'jpn': 'やわらかい;緩い、弱い'}
# {'ain': 'hawke', 'jpn': '安い'}
# {'ain': 'sini', 'jpn': '休む'}
# {'ain': 'tanukuran eþ sini wa eþ an ruwe', 'jpn': '今晩は休んでいますか？'}
# {'ain': 'sattek', 'jpn': 'やせる'}
# {'ain': 'sinen kþ eywanke rusuy', 'jpn': '一人使いたい。'}
# {'ain': 'rewsi cise', 'jpn': '宿屋'}
# {'ain': 'pirka rewsi cise eþ eraman', 'jpn': 'いい宿屋を君は知っていますか？'}
# {'ain': 'pirka rewsi uske oka ruwe an', 'jpn': 'いい宿屋はありますか？'}
# {'ain': 'tanto wano re to pakno enþ rewsire wa enþ kore', 'jpn': '今日から三日間、私を泊まらせてください。'}
# {'ain': 'nep ka aþ ye p an siri an', 'jpn': '何か言うことがありますか？'}
# {'ain': 'kuþ kor pe te ta kor wa ek', 'jpn': '私の持ち物をここに持って来い。'}
# {'ain': 'pirka wa', 'jpn': 'いいですよ。'}
# {'ain': 'amam hempakiw e p aþ kar ruwe an', 'jpn': '何人分のご飯をつくりましょうか？'}
# {'ain': 'amam ren atarimaye kor wa ek', 'jpn': '飯を三人前持って来い。'}
# {'ain': 'nani kuþ kar', 'jpn': 'すぐに作ります。'}
# {'ain': 'tan huton asir huton ne somo kuþ ramu', 'jpn': 'この布団は新しい布団ではないと思います。'}
# {'ain': 'rewsi puma', 'jpn': '宿代'}
# {'ain': 'sake sine itanki eykaunno aþ nuye wa an na', 'jpn': '酒を一杯、余計に付けていますよ。'}
# {'ain': 'nitat yaci siri orawrawke hi', 'jpn': '湿地;泥;地面がぬかるんでいるところ'}
# {'ain': 'yarke tuytektek', 'jpn': '～を破る、～をすり切らす;～をさっと切る'}
# {'ain': 'yar', 'jpn': 'すり切れる'}
# {'ain': 'kuþ mi p perke', 'jpn': '私の着物が破れた。'}
# {'ain': 'siwri susu', 'jpn': 'シウリザクラ;ヤナギ'}
# {'ain': 'unkotuk', 'jpn': 'やに、松やに'}
# {'ain': 'cise soka cise kitay', 'jpn': '屋根;屋根'}
# {'ain': 'so kaske', 'jpn': '床の上'}
# {'ain': 'iwor kim nupuri iwa', 'jpn': '猟場;山;山;岩山'}
# {'ain': 'okimunpe', 'jpn': '山津波'}
# {'ain': 'kim ta', 'jpn': '山に'}
# {'ain': 'ekimne ruwe ne', 'jpn': '山へ行きました。'}
# {'ain': 'kim oro', 'jpn': '山のところ、山の中'}
# {'ain': 'okimun ruwe ne', 'jpn': '山からです。'}
# {'ain': 'sut', 'jpn': 'ふもと'}
# {'ain': 'kitay', 'jpn': '～の頂上'}
# {'ain': 'toan nupuri ot ta hemesu wa inkar', 'jpn': 'あの山に登ってみなさい。'}
# {'ain': 'tan nupuri ot ta hemespa þan ciki hokampa isam', 'jpn': 'この山に登るのは難しくないですか？'}
# {'ain': 'ru pirka ruwe an', 'jpn': '道はいいですか？'}
# {'ain': 'umma aþ o wa hemespaeaskay þan ruwe an', 'jpn': '馬に乗って登れますか？'}
# {'ain': 'arpa eaykap', 'jpn': '行けません'}
# {'ain': 'taskor', 'jpn': '寒さ、寒波'}
# {'ain': 'siyeye tasum', 'jpn': '病気になる'}
# {'ain': 'montum wen', 'jpn': '調子が悪い'}
# {'ain': 'humiruy', 'jpn': 'ヤマドリ、エゾライチョウ'}
# {'ain': 'yayciskar matsak hokusak', 'jpn': 'やもめ;妻を持たない;夫を持たない'}
# {'ain': 'op', 'jpn': '槍'}
# {'ain': 'op kepuspe', 'jpn': '槍の鞘'}
# {'ain': 'kore', 'jpn': '～に～を与える'}
# {'ain': 'tanpe hunna kuþ kore ruwe an', 'jpn': 'これを誰にあげようか？'}
# {'ain': 'tanpe eþ kor mici kore', 'jpn': 'これを君のお父さんにあげなさい。'}
# {'ain': 'eþ sinki kusu tanpe poka eciþ kore na', 'jpn': '君は疲れているから、これだけあげようね。'}
# {'ain': 'tanpe haye no an pe sanke yan', 'jpn': 'これよりも少ないものを出しなさい。'}
# {'ain': 'te ta an kusu eciþ kore', 'jpn': 'ここにあるから君にあげる。'}
# {'ain': 'an korka eciþ kore eaykap', 'jpn': 'あるけれど、君にあげられません。'}
# {'ain': 'somo kþ eywanke kusu', 'jpn': '私は使いませんから。'}
# {'ain': 'ikasma pakno ne na', 'jpn': '余るくらいですよ。'}
# {'ain': 'hapur', 'jpn': 'やわらかい'}
# {'ain': 'tupesanpe', 'jpn': '八つ'}
# {'ain': 'ye itak', 'jpn': '～に言う;話す'}
# {'ain': 'isenramte haw', 'jpn': '相変わらずの声'}
# {'ain': 'iramnukuri', 'jpn': '申し訳なく思う'}
# {'ain': 'ratcitara itak', 'jpn': 'ゆっくり話せ'}
# {'ain': 'siyuppa no ye', 'jpn': 'しっかり言え。'}
# {'ain': 'akkari anakne kuþ ye eaykap na', 'jpn': 'これ以上は言えないよ。'}
# {'ain': 'kuþ ye eaykap wa', 'jpn': '私は言えないよ。'}
# {'ain': 'anukanno ye', 'jpn': 'はっきり言え。（？）'}
# {'ain': 'ye ani', 'jpn': '言いなさいよ。'}
# {'ain': 'ek wa ye ani', 'jpn': '来て言いなさいよ。'}
# {'ain': 'ek kuni ye', 'jpn': '来るように言え。'}
# {'ain': 'aþ ki kuni kusu ye', 'jpn': 'するように言え。'}
# {'ain': 'iteki nep ye', 'jpn': '何も言うな。'}
# {'ain': 'toan kur eun tapne itak', 'jpn': 'あの人へこのように話せ。'}
# {'ain': 'kuþ ye p an na', 'jpn': '私は言うことがありますよ。'}
# {'ain': 'eani eþ sunke hawe ne na', 'jpn': '君はうそをついたな。'}
# {'ain': 'eþ hekote ponno kuþ ye p an na iruka ek', 'jpn': '君に少し言うことがあるよ。ちょっと来い。'}
# {'ain': 'hemanta kusu kuþ ye a p somo eþ ki', 'jpn': '君はなぜ私が言ったことをしないの？'}
# {'ain': 'nep eþ ye ya', 'jpn': '何を言ったの？'}
# {'ain': 'tanpe aynu or un kuþ ye eaykap', 'jpn': 'これをアイヌ語で言えません。'}
# {'ain': 'nep ka eþ ye p an ciki enþ hekote ye', 'jpn': '何か言うことがあったら私に言え。'}
# {'ain': 'enþ ot ta ene itak i', 'jpn': '私にこのように話したこと'}
# {'ain': 'ukuran', 'jpn': 'ゆうべ'}
# {'ain': 'ukuran pirkano eþ mokor ya', 'jpn': '昨夜よく眠りましたか？'}
# {'ain': 'ukuran kuþ mokor koyaykus', 'jpn': 'ゆうべ私は眠れませんでした。'}
# {'ain': 'kusu', 'jpn': '～なので、～だから'}
# {'ain': 'aþ hotuyekar kusu kþ ek', 'jpn': '（彼／彼女が）呼ばれたので私が来ました。'}
# {'ain': 'onuman', 'jpn': '夕方'}
# {'ain': 'upas', 'jpn': '雪'}
# {'ain': 'upas patke', 'jpn': '雪が舞う。'}
# {'ain': 'asir cup ta upas as nankon na', 'jpn': '来月には雪が降るだろうね。'}
# {'ain': 'tan cup wano upas as', 'jpn': '今月から雪が降ります。'}
# {'ain': 'hokkayto tane upas as noyne', 'jpn': '北海道はもう雪が降ったらしい。'}
# {'ain': 'paye þan arpa oman', 'jpn': '行く;行く;行く'}
# {'ain': 'oyak ta arpa', 'jpn': '他のところへ行け。'}
# {'ain': 'ikuyra', 'jpn': 'こっそりついて行け。'}
# {'ain': 'kþ arpa a wa', 'jpn': '私は行きましたよ。'}
# {'ain': 'kþ arpa kusu ne', 'jpn': '私は行くつもりです。'}
# {'ain': 'toani un arpa', 'jpn': 'あちらへ行け。'}
# {'ain': 'tap arpa wa isam', 'jpn': 'たった今、行ってしまいました。'}
# {'ain': 'coka ka paye þas rusuy copitta ka paye þas rusuy', 'jpn': '私たちも行きたい。;私たち全員も行きたい。'}
# {'ain': 'yakun toani un paye yan', 'jpn': 'それならあそこへ行きなさい。'}
# {'ain': 'tun aþ ne paye þan ro', 'jpn': '私たち二人で行こう。'}
# {'ain': 'ren aþ ne wa paye þan ro', 'jpn': '私たち三人で行こう。'}
# {'ain': 'arpa ruwe an', 'jpn': '行ったの？'}
# {'ain': 'tane uweirpak paye þan ruwe an', 'jpn': '私たちは今、一緒に行くのですよ。'}
# {'ain': 'paye þan ro', 'jpn': '行きましょう。'}
# {'ain': 'enþ koyram arpa', 'jpn': '私と一緒に行く。'}
# {'ain': 'neun ka eþ arpa ruwe', 'jpn': '君はどこかへ行くの？'}
# {'ain': 'kþ uni ta kuþ iwak', 'jpn': '私は家に帰ります。'}
# {'ain': 'tane paye þan', 'jpn': '今すぐ行きましょう。'}
# {'ain': 'nani kþ arpa', 'jpn': '私はすぐに行きます。'}
# {'ain': 'nisatta hunak un eþ arpa', 'jpn': '明日、君はどこへ行くの？'}
# {'ain': 'saru un kþ arpa nankor', 'jpn': '沙流へ行くでしょう。'}
# {'ain': 'kuneywano eþ arpa ruwe an', 'jpn': '朝、行くのですか？'}
# {'ain': 'cup hetuku etoko wano kþ arpa', 'jpn': '日が出る前から私は行きます。'}
# {'ain': 'yakun uturano paye þan', 'jpn': 'それなら一緒に行きます。'}
# {'ain': 'yakka pirka', 'jpn': 'それでもいい。'}
# {'ain': 'to renkayne arpa ya somo ya kþ erampewtek', 'jpn': '天気次第で行くか行かないか、わかりません。'}
# {'ain': 'paye etoko ta kuþ ipe tek na yakka pirka ya', 'jpn': '行く前にちょっと食事をしても、いいですか？'}
# {'ain': 'amam ipe an yakne nani paye þan ro', 'jpn': 'ご飯を食べたら、すぐに行きましょう。'}
# {'ain': 'hunak un paye þan ciki saru ta paye þan ruwe an', 'jpn': 'どこへ行ったら沙流に行けますか？'}
# {'ain': 'hunak un paye þan', 'jpn': 'どこへ行くのですか？'}
# {'ain': 'neun ne yakka eþ arpa rusuy uske un paye þan ro', 'jpn': 'どこでも君の行きたいところへ行きましょう。'}
# {'ain': 'neun ne yakka pirka', 'jpn': 'どこでもいい。'}
# {'ain': 'tokyo un paye þan siri an', 'jpn': '東京へ行ったのですか？'}
# {'ain': 'na moyre oman', 'jpn': 'もっと遅く行け。'}
# {'ain': 'askepet', 'jpn': '指'}
# {'ain': 'ruwe askepet onne askepet poro askepet', 'jpn': '親指;親指;親指'}
# {'ain': 'sinnoske us askepet noskike askepet', 'jpn': '中指;中指'}
# {'ain': 'sinnoske un askepet', 'jpn': '中指'}
# {'ain': 'pon askepet mo askepet', 'jpn': '小指;小指'}
# {'ain': 'ku', 'jpn': '弓'}
# {'ain': 'ku ka', 'jpn': '弓の弦'}
# {'ain': 'hokkayto ta ku aþ eywanke ruwe an', 'jpn': '北海道では弓を使うのですか？'}
# {'ain': 'somo teppo eywanke', 'jpn': 'いいえ、鉄砲を使います。'}
# {'ain': 'ku eywanke easkay kur an ruwe an', 'jpn': '弓を使える人はいますか？'}
# {'ain': 'tan ay hinak pakno arpa ruwe an', 'jpn': 'この矢はどこまで届きますか？'}
# {'ain': 'tan ay ani aþ cotca ciki kamuy ray ruwe an', 'jpn': 'この矢に当たったらクマは死にますか？'}
# {'ain': 'ak kur', 'jpn': '射手'}
# {'ain': 'takar cinita', 'jpn': '～を夢に見る;夢をみる、夢、夢でうなされる'}
# {'ain': 'cinitaki cinitakor', 'jpn': '夢を見る;夢を見る'}
# {'ain': 'wentarap nukar', 'jpn': '夢を見る'}
# {'ain': 'turep', 'jpn': 'オオウバユリ'}
# {'ain': 'setakor', 'jpn': 'ゴボウ'}
# {'ain': 'sawrere', 'jpn': '～をゆるめる'}
# {'ain': 'kuþ kuci sawrere', 'jpn': '私の帯を緩めてくれ。'}
# {'ain': 'ratcitara', 'jpn': 'ゆっくりと'}
# {'ain': 'sirpeker', 'jpn': '夜が明ける'}
# {'ain': 'kuneywa', 'jpn': '朝'}
# {'ain': 'pirka', 'jpn': 'よい'}
# {'ain': 'makanak an ciki pirka', 'jpn': 'どうしたらいい？'}
# {'ain': 'pirka puri kuþ erawe ruwe ne', 'jpn': 'いい行いを楽しみにしている。'}
# {'ain': 'sakeposa', 'jpn': '酒の酔いがさめる'}
# {'ain': 'yayetokoyki', 'jpn': '身じたくをする、自分の支度をする'}
# {'ain': 'tane uweirpak paye þan kusu ne na yayetokoyki', 'jpn': '今、一緒に行くつもりですよ。自分の支度をしなさい。'}
# {'ain': 'yayetokoyki eþ okere ruwe an', 'jpn': '身じたくを終えましたか？'}
# {'ain': 'eþ yayetokoyki okere ya', 'jpn': '身じたくし終わりましたか？'}
# {'ain': 'sirpirka', 'jpn': '天気がいい'}
# {'ain': 'tanto sirpirka ruwe an', 'jpn': '今日は天気がいいのですか？'}
# {'ain': 'sirpirka ruwe ne', 'jpn': '天気がいいです。'}
# {'ain': 'iyoski', 'jpn': '酒に酔う'}
# {'ain': 'sake hura ruy', 'jpn': '酒くさい。'}
# {'ain': 'somo kuþ cipsuwa yak pirka na', 'jpn': '船に酔わなかったらいいな。'}
# {'ain': 'cipsuwa wa kusu neun ka aþ kar eaykap ruwe an', 'jpn': '船に酔ったので、私たちはどうすることもできませんか？'}
# {'ain': 'pirkano', 'jpn': 'よく'}
# {'ain': 'pirkano eraman pirkano kewtum ot ta sikkasma', 'jpn': 'ちゃんと覚えろ。;ちゃんと心に留めておけ。'}
# {'ain': 'ekte', 'jpn': '～を寄こす、～を来させる'}
# {'ain': 'icakkere icakkerere', 'jpn': '汚い、よごれる;～を汚くする、～をよごす'}
# {'ain': 'tuy kisara', 'jpn': '横腹'}
# {'ain': 'supki', 'jpn': 'ヨシ、アシ'}
# {'ain': 'kokowe kokow', 'jpn': '～の婿;婿'}
# {'ain': 'teskar', 'jpn': '伝言'}
# {'ain': 'nep ka teskar isam ruwe an', 'jpn': '何か伝言はないですか？'}
# {'ain': 'eyam', 'jpn': '～を心配する、～を大事にする'}
# {'ain': 'pirkano eyam', 'jpn': 'ちゃんと大切にしなさい。'}
# {'ain': 'kotom an', 'jpn': '様子である'}
# {'ain': 'iwor ot ta apto ruy kotom an kusu wakka poro', 'jpn': '猟場のところで雨が激しかったようだから、水が増した。'}
# {'ain': 'oyak ta', 'jpn': 'よそで'}
# {'ain': 'makanak eþ ki wa oyak ta eþ arpa ruwe an', 'jpn': 'どうやって君はよそに行ったの？'}
# {'ain': 'non ohetke', 'jpn': 'よだれが垂れる'}
# {'ain': 'annoske', 'jpn': '夜中'}
# {'ain': 'nepkor an pe', 'jpn': '～のようなもの'}
# {'ain': 'eani nepkor an pe', 'jpn': 'お前のようなもの'}
# {'ain': 'hotuyekar tak', 'jpn': '～を呼ぶ;～を招待する'}
# {'ain': 'aþ e=hotuyekar', 'jpn': '君が呼ばれている。'}
# {'ain': 'isa nispa tak wa enþ kore yan', 'jpn': 'お医者さんを呼んでください。'}
# {'ain': 'maskinno', 'jpn': 'よほど、あまりにも'}
# {'ain': 'oro oytak', 'jpn': '～を読む'}
# {'ain': 'kosmat macihi menoko', 'jpn': '嫁、～の妻;～の妻;女'}
# {'ain': 'noya', 'jpn': 'ヨモギ'}
# {'ain': 'an ayne ayne', 'jpn': '（ずっと）いたあげく;～したあげく'}
# {'ain': 'kari akkari', 'jpn': '～から;～より'}
# {'ain': 'puyar kari inkar', 'jpn': '窓から見る'}
# {'ain': 'oya ru kari', 'jpn': '他の道から'}
# {'ain': 'enþ akkari eþ poro ruwe ne', 'jpn': '私より君は大きい。'}
# {'ain': 'ancikar an', 'jpn': '夜;夜（語根）'}
# {'ain': 'ankes pake ta', 'jpn': '夜明け方に'}
# {'ain': 'ankes', 'jpn': '明け方'}
# {'ain': 'kes ancikar', 'jpn': '毎晩、毎夜'}
# {'ain': 'numke', 'jpn': '～を選ぶ'}
# {'ain': 'ramuriten eyaykopuntek uwenucaktek', 'jpn': '喜ぶ;～を喜ぶ;喜ぶ'}
# {'ain': 'pirka', 'jpn': 'よい'}
# {'ain': 'tane pirka wa', 'jpn': 'もういいよ。'}
# {'ain': 'sinep ne yakka pirka tup somo kuþ kon rusuy', 'jpn': 'ひとつでいいです。ふたつは欲しくありません。'}
# {'ain': 'hawke', 'jpn': '弱い'}
# {'ain': 'ikkewe sak tumsak', 'jpn': '弱い;弱い、力がない'}
# {'ain': 'asir cup', 'jpn': '来月'}
# {'ain': 'oya pa', 'jpn': '来年'}
# {'ain': 'kiseri tumam', 'jpn': 'らお（きせるの火皿と吸い口とをつなぐ竹の管の部分）'}
# {'ain': 'noyne', 'jpn': '～らしい'}
# {'ain': 'tanukuran apto as noyne an', 'jpn': '今夜は雨が降るらしい。'}
# {'ain': 'nen ka ek noyne hum as', 'jpn': '誰か来たような音がする。'}
# {'ain': 'rakko', 'jpn': 'ラッコ'}
# {'ain': 'matnep', 'jpn': 'メス'}
# {'ain': 'pinnep', 'jpn': 'オス'}
# {'ain': 'wen sakanramkor kur', 'jpn': 'ひどく短気な人'}
# {'ain': 'ruop', 'jpn': 'リス'}
# {'ain': 'isam ohasir', 'jpn': 'いない;留守、空き家'}
# {'ain': 'isam', 'jpn': 'いないの？'}
# {'ain': 'te ta an', 'jpn': 'ここにいます。'}
# {'ain': 'isam nankor', 'jpn': 'いないでしょう。'}
# {'ain': 'kþ arpa akusu eþ isam ruwe ne', 'jpn': '私が行くと、君はいなかったのです。'}
# {'ain': 'kþ arpa a korka ohasir an', 'jpn': '私が行ったけれども、留守だった。'}
# {'ain': 'kuþ isam wa kþ eyaykatanu', 'jpn': '私がいなくて、すみませんでした。'}
# {'ain': 'apeoy', 'jpn': '炉'}
# {'ain': 'inumpe', 'jpn': '炉ぶち'}
# {'ain': 'ror', 'jpn': '上座'}
# {'ain': 'harkiso', 'jpn': '左座'}
# {'ain': 'sinci', 'jpn': '六月'}
# {'ain': 'henke caca', 'jpn': 'おじいさん;爺'}
# {'ain': 'ninkari', 'jpn': '耳輪、耳飾り'}
# {'ain': 'kisar un ninkari', 'jpn': '耳輪、耳飾り'}
# {'ain': 'pewre', 'jpn': '若い'}
# {'ain': 'upen kur pewre kur', 'jpn': '若者、青年;若者'}
# {'ain': 'sukup kur', 'jpn': '壮年の者'}
# {'ain': 'sukup noski', 'jpn': '人生の半ば、壮年'}
# {'ain': 'popte sesekka', 'jpn': '～を沸かす;～を暖める'}
# {'ain': 'na nam wa', 'jpn': 'まだ冷たいよ。'}
# {'ain': 'erampewtek', 'jpn': '～がわからない'}
# {'ain': 'tane kuþ ye itak eþ eraman', 'jpn': '今私が言った言葉がわかった？'}
# {'ain': 'tane eþ ki itak pirkano kþ erampewtek na', 'jpn': '今君が言った言葉がよくわかりませんね。'}
# {'ain': 'hunak oro aþ erampewtek', 'jpn': 'どこがわかりませんか？'}
# {'ain': 'kuþ nukar korka kþ erampewtek', 'jpn': '私は見たけれどもわからない。'}
# {'ain': 'to renkayne kþ arpa ya somo kþ erampewtek', 'jpn': '天気次第で行くか行かないか、わかりません。'}
# {'ain': 'eramuan', 'jpn': '～がわかる'}
# {'ain': 'tan kur aynu itak eraman kur he an', 'jpn': 'この人はアイヌ語がわかる人ですか？'}
# {'ain': 'kuþ ye itak eþ eraman', 'jpn': '私の言う言葉がわかりますか？'}
# {'ain': 'kþ eraman', 'jpn': 'わかります。'}
# {'ain': 'kþ eramuskare', 'jpn': '知りません。'}
# {'ain': 'aynu itak ponno kþ eraman korka itak opitta kþ eramiskari', 'jpn': 'アイヌ語は少しわかりますが、全部は知りません。'}
# {'ain': 'ewkopi ukohopi', 'jpn': '互いに、反対に;互いに別れていく'}
# {'ain': 'ewkopi wa oman', 'jpn': '別れて行く'}
# {'ain': 'apunno arpa', 'jpn': '気をつけて行け。'}
# {'ain': 'tane ukohoppa þan na pirka no oka yan aþ utari pirkano epunkine yan', 'jpn': 'もうお別れですよ。さようなら（？）。みんな、気をつけてね（？）。'}
# {'ain': 'pop', 'jpn': '沸く、煮立つ'}
# {'ain': 'wakka pop', 'jpn': '水が沸く。'}
# {'ain': 'yakka pirka wa', 'jpn': 'それでもいいよ。'}
# {'ain': 'raman kur', 'jpn': '利口な人'}
# {'ain': 'ukousaraye usaraye', 'jpn': '～を分かちあう;～を分ける'}
# {'ain': 'nimara enþ kousaraye', 'jpn': '半分私に分けてください。'}
# {'ain': 'kisesseri', 'jpn': 'アイヌワサビ'}
# {'ain': 'kapatcir', 'jpn': 'ワシ（鷲）'}
# {'ain': 'oyra', 'jpn': '～を忘れる'}
# {'ain': 'nep ka somo eþ oyra ya', 'jpn': '何か忘れていませんか？'}
# {'ain': 'kþ oyra nisa ruwe ne', 'jpn': '私は忘れてしまいました。'}
# {'ain': 'iteki nep ka oyra no pirkano epunkine', 'jpn': '何も忘れないようにちゃんと守れ。'}
# {'ain': 'iteki oyra no kor wa ek', 'jpn': '忘れずに持って来い。'}
# {'ain': 'eþ esikarun na', 'jpn': '君は覚えていてね。'}
# {'ain': 'ukuspa usi ikusa i', 'jpn': '渡船場;渡船場'}
# {'ain': 'ukuspa usi hunak ta an ruwe an', 'jpn': '渡船場はどこにありますか？'}
# {'ain': 'petpunki', 'jpn': '渡し守'}
# {'ain': 'kuþ', 'jpn': '私は、私の'}
# {'ain': 'setsu tapne an pe kuþ ne wa', 'jpn': '私はセツという者ですよ。'}
# {'ain': 'ikusa', 'jpn': '（川を舟で）渡す'}
# {'ain': 'ikusa kur', 'jpn': '渡し守'}
# {'ain': 'petpunki cip an ruwe an', 'jpn': '渡し船はありますか？'}
# {'ain': 'kus turasi', 'jpn': '（場所）を通る;～に沿って上手に行く'}
# {'ain': 'wattes', 'jpn': 'わら'}
# {'ain': 'wattes opitta kor wa ek', 'jpn': 'わらを全部持って来い。'}
# {'ain': 'tuwa', 'jpn': 'ワラビ'}
# {'ain': 'ciperpa ni', 'jpn': '割り木'}
# {'ain': 'wen', 'jpn': '悪い'}
# {'ain': 'wenpe', 'jpn': '悪事、悪いこと'}
# {'ain': 'wen kur', 'jpn': '悪人、貧乏人'}
# {'ain': 'hinak oro wen', 'jpn': 'どこが悪いの？'}
# {'ain': 'kuþ katun humi wen', 'jpn': '私は気分が悪い（？）。'}
# {'ain': 'ponno kuþ yaynu humi wen', 'jpn': '私は少し気分が悪い。'}
# {'ain': 'yaysama wen hawe ne', 'jpn': '困ったな！ 悪いことだ。'}
# {'ain': 'hempara wano ene an i an', 'jpn': 'いつからこうなのですか？'}
# {'ain': 'arpa kor wen', 'jpn': '行くと駄目だ。'}
# {'ain': 'itasaitak', 'jpn': '答える、返答する'}
# {'ain': 'perke', 'jpn': '割れる'}
# {'ain': 'aþ ciþ', 'jpn': '私たちが、私たちの;私たちが、私たちの'}
# {'ain': 'aþ kor pe', 'jpn': '私たちのもの'}
# {'ain': 'itanki', 'jpn': '椀'}
# {'ain': 'moy us', 'jpn': '渦巻; 湾'}
# 5048

# %% [markdown]
# #### no use - dataloader

# %%
import torch
from torch.utils.data.dataset import random_split
import torchdata.datapipes as dp
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
import torchtext.transforms as T
from torch.utils.data import DataLoader
from torchtext.data.functional import to_map_style_dataset

def tokenize(text):
    # テキストを単語に分割する処理。この例ではスペースで分割。
    return text.split()

# データパイプラインの定義
datapipe_ain = dp.iter.FileOpener(['poysuwop_ain.txt'], mode='rt'). \
                   readlines(return_path=False). \
                   map(tokenize). \
                   flatten()

# データ読み込み、単語分割(日本語)
datapipe_jpn = dp.iter.FileOpener(['poysuwop_jpn.txt'], mode='rt'). \
                   readlines(return_path=False). \
                   map(tokenize). \
                   flatten()

# アイヌ語・日本語ペアに
datapipe = datapipe_ain.zip(datapipe_jpn)

# 単語辞書作成(アイヌ語)
ain_vocab = build_vocab_from_iterator(datapipe_ain, specials=('<unk>', '<pad>', '<s>', '</s>'))
ain_vocab.set_default_index(ain_vocab['<unk>'])

# 単語辞書作成(日本語)
jpn_vocab = build_vocab_from_iterator(datapipe_jpn, specials=('<unk>', '<pad>', '<s>', '</s>'))
jpn_vocab.set_default_index(jpn_vocab['<unk>'])

# transform生成
ain_transform = T.Sequential(
    T.VocabTransform(ain_vocab),
    T.AddToken(ain_vocab['<s>'], begin=True),
    T.AddToken(ain_vocab['</s>'], begin=False),
    T.ToTensor(padding_value=ain_vocab['<pad>'])
)

jpn_transform = T.Sequential(
    T.VocabTransform(jpn_vocab),
    T.AddToken(jpn_vocab['<s>'], begin=True),
    T.AddToken(jpn_vocab['</s>'], begin=False),
    T.ToTensor(padding_value=jpn_vocab['<pad>'])
)

# ミニバッチ時のデータ変換関数
def collate_batch(batch):
    ens = ain_transform([src for (src, trg) in batch])
    jas = jpn_transform([trg for (src, trg) in batch])
    return ens, jas

# mapに変換
ds = to_map_style_dataset(datapipe)
# DataLoader設定
# data_loader = DataLoader(ds, shuffle=True, batch_size=3, collate_fn=collate_batch)

# 元のデータセットのサイズを取得
dataset_size = len(ds)

# 訓練セットと検証セットのサイズを指定
train_size = int(dataset_size * 0.8)
val_size = dataset_size - train_size

# データセットをランダムに分割
train_dataset, val_dataset = random_split(ds, [train_size, val_size])

# 訓練用 DataLoader
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=3, collate_fn=collate_batch)

# 検証用 DataLoader
val_loader = DataLoader(val_dataset, shuffle=False, batch_size=3, collate_fn=collate_batch)

# %%
import torch
from torch.utils.data.dataset import random_split

# アイヌ語・日本語ペアに
datapipe = datapipe_ain.zip(datapipe_jpn)

# 単語辞書作成(アイヌ語)
ain_vocab = build_vocab_from_iterator(datapipe_ain, specials=('<unk>', '<pad>', '<s>', '</s>'))
ain_vocab.set_default_index(ain_vocab['<unk>'])

# 単語辞書作成(日本語)
jpn_vocab = build_vocab_from_iterator(datapipe_jpn, specials=('<unk>', '<pad>', '<s>', '</s>'))
jpn_vocab.set_default_index(jpn_vocab['<unk>'])

# transform生成
ain_transform = T.Sequential(
    T.VocabTransform(ain_vocab),
    T.AddToken(ain_vocab['<s>'], begin=True),
    T.AddToken(ain_vocab['</s>'], begin=False),
    T.ToTensor(padding_value=ain_vocab['<pad>'])
)

jpn_transform = T.Sequential(
    T.VocabTransform(jpn_vocab),
    T.AddToken(jpn_vocab['<s>'], begin=True),
    T.AddToken(jpn_vocab['</s>'], begin=False),
    T.ToTensor(padding_value=jpn_vocab['<pad>'])
)

# ミニバッチ時のデータ変換関数
def collate_batch(batch):
    ens = ain_transform([src for (src, trg) in batch])
    jas = jpn_transform([trg for (src, trg) in batch])
    return ens, jas

# mapに変換
ds = to_map_style_dataset(datapipe)
# DataLoader設定
# data_loader = DataLoader(ds, shuffle=True, batch_size=3, collate_fn=collate_batch)

# 元のデータセットのサイズを取得
dataset_size = len(ds)

# 訓練セットと検証セットのサイズを指定
train_size = int(dataset_size * 0.8)
val_size = dataset_size - train_size

# データセットをランダムに分割
train_dataset, val_dataset = random_split(ds, [train_size, val_size])

# 訓練用 DataLoader
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=3, collate_fn=collate_batch)

# 検証用 DataLoader
val_loader = DataLoader(val_dataset, shuffle=False, batch_size=3, collate_fn=collate_batch)

# %%
"""
.get_stoi()
Returns:
    Dictionary mapping tokens to indices.
"""

ain_vocab.get_stoi()
# Out:
# {'yupta': 2849,
#  'yupnatara': 2848,
#  'yokohama': 2844,
#  'yen': 2843,
#  'yaysamne': 2836,
#  'yayramsitne': 2835,
#  'yayramnuyna': 2834,
#  'yaynumwen': 2832,
#  'yaykosiramsuypa': 2831,
#  'yaykomismu': 2830,
#  'yaykane': 2829,
#  'yayeinukuri': 2825,
#  'yayciskar': 2824,
#  'yaycire': 2823,
#  'yayasis': 2822,
#  'yaunu': 2819,
#  'yatupoknuma': 2817,
#  'yasa': 2815,
#  'yas': 2814,
#  'yar': 2812,
#  'yaoskep': 2811,
#  'yamsu': 2810,
#  'yamni': 2809,
#  'yakayaka': 2807,
#  'yaka': 2806,
#  'yaetaye': 2805,
#  'yacipocipoci': 2804,
#  'y': 2803,
#  'wose': 2802,
#  'woruncikap': 2801,
#  'wo': 2800,
#  'weysampe': 2799,
#  'wenpurikor': 2798,
#  'wenkur': 2796,
#  'wenipokas': 2795,
#  'wempe': 2794,
#  'wakasa': 2792,
#  'uwotutanpa': 2791,
#  'uwepakita': 2786,
#  'uwenucaktek': 2785,
#  'yuptek': 2850,
#  'uwenewsar': 2784,
#  'uwekari': 2783,
#  'uweerepak': 2782,
#  'uwa': 2781,
#  'utuyaskarap': 2780,
#  'uturunpe': 2779,
#  'utursam': 2778,
#  'utura': 2776,
#  'utuman': 2774,
#  'utka': 2771,
#  'utekanpa': 2770,
#  'utaspa': 2767,
#  'utarihi': 2765,
#  'utare': 2764,
#  'uste': 2762,
#  'usinnano': 2760,
#  'usausak': 2759,
#  'usat': 2757,
#  'usapte': 2756,
#  'uror': 2755,
#  'urespa': 2753,
#  'urepok': 2752,
#  'urenpiskani': 2749,
#  'urenkema': 2747,
#  'uray': 2745,
#  'uramsuye': 2744,
#  'urammokka': 2743,
#  'upiste': 2742,
#  'upakte': 2737,
#  'uosa': 2733,
#  'uonnere': 2732,
#  'unkotuk': 2729,
#  'unkeray': 2728,
#  'uneno': 2726,
#  'unci': 2725,
#  'umta': 2724,
#  'ummaep': 2723,
#  'ukuruype': 2722,
#  'ukuripe': 2721,
#  'unu': 2731,
#  'ukoterke': 2714,
#  'ukosikniwenpare': 2713,
#  'ukorari': 2712,
#  'ukoracino': 2711,
#  'ukopao': 2709,
#  'ukohopire': 2704,
#  'ukocaranke': 2702,
#  'ukasuy': 2700,
#  'uhayta': 2699,
#  'uekap': 2695,
#  'ueinkar': 2694,
#  'u': 2692,
#  'tuytektek': 2691,
#  'tuypatuypa': 2690,
#  'tuymaru': 2689,
#  'tuyaskarap': 2688,
#  'tuwarka': 2686,
#  'tususke': 2684,
#  'turpa': 2680,
#  'turi': 2679,
#  'turepni': 2678,
#  'turamkor': 2676,
#  'tunin': 2674,
#  'tunankar': 2673,
#  'tumaoma': 2672,
#  'tukunne': 2671,
#  'tukko': 2670,
#  'tukar': 2669,
#  'toykikkar': 2665,
#  'totanne': 2662,
#  'toponra': 2661,
#  'topiski': 2660,
#  'topihi': 2659,
#  'topattumi': 2658,
#  'too': 2656,
#  'tonum': 2655,
#  'tononoski': 2653,
#  'tono': 2651,
#  'tonka': 2650,
#  'tomte': 2649,
#  'tomotuy': 2648,
#  'tomosma': 2647,
#  'tokom': 2642,
#  'teynere': 2640,
#  'teynep': 2639,
#  'teta': 2637,
#  'tesmani': 2636,
#  'temnikor': 2630,
#  'teksampe': 2627,
#  'tekparuparu': 2625,
#  'tekko': 2620,
#  'yasya': 2816,
#  'tayko': 2618,
#  'tasiro': 2616,
#  'tapsutu': 2614,
#  'tannere': 2610,
#  'tannecep': 2609,
#  'tampakuop': 2608,
#  'tampako': 2607,
#  'takusa': 2606,
#  'takup': 2605,
#  'taktaku': 2604,
#  'takar': 2601,
#  'suyesuye': 2600,
#  'sutu': 2599,
#  'surku': 2595,
#  'supun': 2594,
#  'sune': 2589,
#  'sumari': 2587,
#  'sukep': 2585,
#  'sukarsey': 2584,
#  'soyke': 2582,
#  'sospari': 2579,
#  'soso': 2578,
#  'soataye': 2573,
#  'siwnin': 2571,
#  'situytuye': 2568,
#  'situriri': 2567,
#  'sittumpeker': 2566,
#  'sittok': 2565,
#  'sittes': 2564,
#  'sitne': 2562,
#  'sitcuk': 2561,
#  'sitcaricari': 2560,
#  'ussiw': 2761,
#  'tempa': 2631,
#  'sisak': 2559,
#  'sirteksam': 2557,
#  'sirsiru': 2556,
#  'sirsak': 2555,
#  'sirouri': 2553,
#  'sirosi': 2552,
#  'sironkane': 2550,
#  'sirmeman': 2549,
#  'sirmata': 2548,
#  'sirmaknatara': 2547,
#  'sirkitaye': 2543,
#  'sirkirap': 2542,
#  'sirkira': 2541,
#  'sirkem': 2540,
#  'sirkawre': 2539,
#  'siretok': 2538,
#  'sirepare': 2537,
#  'sirekutkar': 2536,
#  'sirasirak': 2534,
#  'sirari': 2532,
#  'siran': 2531,
#  'sipuskep': 2530,
#  'sipsip': 2529,
#  'sippousi': 2528,
#  'sipet': 2526,
#  'sinurappa': 2524,
#  'sinrupus': 2523,
#  'sinonruki': 2521,
#  'sinne': 2520,
#  'sinmun': 2518,
#  'sinkep': 2517,
#  'sinire': 2515,
#  'sinepa': 2513,
#  'simawta': 2511,
#  'sikpuye': 2508,
#  'sikpakehe': 2507,
#  'siknure': 2505,
#  'siknak': 2503,
#  'sikkes': 2501,
#  'sikiwtacup': 2500,
#  'sikittektek': 2499,
#  'sikiru': 2498,
#  'sikina': 2497,
#  'siki': 2496,
#  'sikekar': 2495,
#  'sikcupucupu': 2494,
#  'sikari': 2492,
#  'sikannatkire': 2491,
#  'sikannatkino': 2490,
#  'settompa': 2484,
#  'sut': 2597,
#  'setakorkoni': 2483,
#  'setakor': 2482,
#  'seppa': 2478,
#  'sepepakki': 2477,
#  'semor': 2473,
#  'sekukke': 2472,
#  'sawnure': 2468,
#  'satte': 2466,
#  'yaki': 2808,
#  'satcipir': 2465,
#  'sarorun': 2464,
#  'sarampe': 2463,
#  'sarake': 2461,
#  'uesikke': 2698,
#  'sapke': 2459,
#  'sapanpe': 2458,
#  'sapaiyetaptapu': 2457,
#  'sanpesituriri': 2456,
#  'sanka': 2454,
#  'sanike': 2453,
#  'sampetoktokse': 2451,
#  'sampekoyki': 2450,
#  'sampehorarayse': 2449,
#  'samo': 2444,
#  'samanpe': 2443,
#  'samampe': 2442,
#  'samakehe': 2441,
#  'upekano': 2740,
#  'samaka': 2440,
#  'sakanramkor': 2438,
#  'saihu': 2435,
#  'rutu': 2433,
#  'rusihi': 2432,
#  'rupnemaci': 2431,
#  'rupespe': 2430,
#  'ruop': 2429,
#  'runnu': 2428,
#  'ukotukka': 2717,
#  'rum': 2427,
#  'ruipokas': 2426,
#  'ruhayta': 2425,
#  'ror': 2423,
#  'ronronke': 2422,
#  'rokte': 2421,
#  'riyap': 2420,
#  'riterite': 2418,
#  'rimse': 2416,
#  'rikinka': 2415,
#  'rikani': 2413,
#  'tewnintewnin': 2638,
#  'rikan': 2412,
#  'reyep': 2411,
#  'tonoski': 2654,
#  'reye': 2410,
#  'sampehe': 2448,
#  'rewsire': 2409,
#  'rewe': 2407,
#  'tuwayuk': 2687,
#  'resuy': 2405,
#  'respa': 2403,
#  'repnaoske': 2401,
#  'wenno': 2797,
#  'renuspe': 2400,
#  'rekutunpe': 2399,
#  'rekusceppo': 2398,
#  'rekihi': 2396,
#  'rayoci': 2394,
#  'raykur': 2393,
#  'raworer': 2391,
#  'rawne': 2390,
#  'ras': 2384,
#  'rarmani': 2383,
#  'rareyaka': 2382,
#  'rar': 2381,
#  'rapucupki': 2380,
#  'rapokike': 2377,
#  'sep': 2476,
#  'rapempe': 2375,
#  'ramusitne': 2370,
#  'ramusiroma': 2369,
#  'ramuhaytare': 2366,
#  'ramuan': 2364,
#  'ramepakari': 2362,
#  'raman': 2360,
#  'rakur': 2359,
#  'rakko': 2358,
#  'racitkere': 2357,
#  'ipesak': 1107,
#  'uwekarpare': 696,
#  'kan': 1134,
#  'imo': 1101,
#  'hoyco': 1757,
#  'sirkorari': 2544,
#  'imi': 1100,
#  'rupne': 1301,
#  'tekehayta': 2619,
#  'imanit': 1099,
#  'empuyna': 1601,
#  'sanci': 2452,
#  'ikopa': 1097,
#  'ukokarkari': 2706,
#  'ayke': 973,
#  'ikir': 1092,
#  'ahupkar': 254,
#  'ikotuntek': 1799,
#  'ikoypuni': 1800,
#  'kut': 504,
#  'honi': 1075,
#  'uske': 151,
#  'hokuhu': 1074,
#  'tem': 2629,
#  'wor': 1412,
#  'mop': 2081,
#  'hecirasa': 1061,
#  'urar': 925,
#  'mame': 149,
#  'cisaw': 1544,
#  'hapur': 1052,
#  'mus': 1199,
#  'eykoramkor': 1048,
#  'inne': 765,
#  'ewonne': 1043,
#  'ewkopi': 1042,
#  'hoski': 322,
#  'etutanne': 1040,
#  'makanit': 2042,
#  'etupske': 1039,
#  'inaan': 763,
#  'etukka': 1038,
#  'iranakka': 495,
#  'arpare': 406,
#  'ristektek': 2417,
#  'etor': 1037,
#  'rera': 339,
#  'esna': 1034,
#  'nunke': 821,
#  'notkewe': 2159,
#  'esikipit': 1028,
#  'irenka': 1113,
#  'eramusinne': 1024,
#  'tunasno': 307,
#  'anun': 556,
#  'epirka': 1016,
#  'emawri': 1008,
#  'monrayke': 506,
#  'cisuwerup': 1545,
#  'ekatkikus': 1002,
#  'onuman': 155,
#  'sunancup': 2588,
#  'enukar': 1011,
#  'ekampakte': 1000,
#  'ehorka': 997,
#  'hecawe': 1725,
#  'kiray': 1958,
#  'siwentekur': 2570,
#  'corawki': 991,
#  'ciwe': 989,
#  'ciw': 988,
#  'perpa': 845,
#  'omkekar': 2218,
#  'upen': 2741,
#  'hepututu': 1068,
#  'cipoyep': 985,
#  'ohhorrrrrrrrr': 2193,
#  'ran': 525,
#  'ikokantama': 1095,
#  'eysokor': 1050,
#  'biyoin': 976,
#  'ayo': 975,
#  'umma': 113,
#  'eok': 1013,
#  'ipeus': 1108,
#  'cirir': 1542,
#  'eramuusausak': 1635,
#  'atusa': 970,
#  'atpake': 969,
#  'apkor': 961,
#  'einehotne': 1583,
#  'ama': 953,
#  'humpa': 1081,
#  'akup': 951,
#  'ahunte': 948,
#  'aa': 945,
#  'yaysama': 943,
#  'yaykata': 941,
#  'yakne': 938,
#  'yaci': 937,
#  'yaayka': 936,
#  'apehucikamuy': 1459,
#  'wenkamuy': 934,
#  'uype': 933,
#  'sirkote': 2545,
#  'etoyta': 574,
#  'itaknuno': 1118,
#  'yaykaota': 940,
#  'uweirpak': 931,
#  'unuutari': 924,
#  'ununi': 922,
#  'tuytuye': 918,
#  'tustek': 917,
#  'etakasure': 1035,
#  'tusir': 1377,
#  'perke': 645,
#  'toranne': 909,
#  'iyutani': 1885,
#  'teskar': 905,
#  'esisi': 1033,
#  'hawke': 153,
#  'tennep': 904,
#  'teksam': 902,
#  'ermutampu': 1647,
#  'tayki': 900,
#  'etuhotne': 1669,
#  'tanpa': 899,
#  'hurkap': 1082,
#  'oman': 379,
#  'ehokari': 995,
#  'ekatnu': 1587,
#  'munnuwep': 2097,
#  'sirar': 888,
#  'kisannin': 1964,
#  'tomari': 906,
#  'sipasnu': 886,
#  'sirmean': 890,
#  'sinu': 885,
#  'ekopas': 1005,
#  'nankor': 124,
#  'etupsike': 736,
#  'sikucupupu': 2510,
#  'keni': 1149,
#  'iyop': 1878,
#  'haye': 1721,
#  'sikkasmare': 881,
#  'usa': 180,
#  'sawrere': 875,
#  'terkep': 2634,
#  'sapkere': 873,
#  'rur': 871,
#  'repun': 864,
#  'toska': 1369,
#  'korka': 55,
#  'rapok': 861,
#  'honuhonu': 1748,
#  'ponpe': 851,
#  'peot': 844,
#  'sikte': 2509,
#  'pakko': 2274,
#  'menokopo': 805,
#  'oripakno': 832,
#  'uturano': 2777,
#  'paspas': 841,
#  'satporo': 874,
#  'sippo': 887,
#  'pas': 840,
#  'rekte': 2397,
#  'makun': 1185,
#  'oputuye': 831,
#  'opiwki': 829,
#  'ene': 102,
#  'kep': 1150,
#  'oper': 828,
#  'ihok': 1087,
#  'hepita': 1731,
#  'okke': 825,
#  'tumke': 915,
#  'aokay': 1454,
#  'ahunkaonit': 1432,
#  'siw': 2569,
#  'noypa': 820,
#  'eram': 1624,
#  'taype': 1362,
#  'niwen': 816,
#  'pecir': 2297,
#  'nanuhu': 809,
#  'kuta': 800,
#  'apautari': 1458,
#  'kotcake': 795,
#  'tusunike': 2683,
#  'kosmat': 794,
#  'isepo': 593,
#  'kokowe': 791,
#  'kitay': 790,
#  'ukoyramno': 2720,
#  'tepa': 2632,
#  'hose': 1752,
#  'kirirse': 787,
#  'nin': 624,
#  'kippu': 786,
#  'oinuwe': 1231,
#  'eomosiroyre': 1612,
#  'kespa': 784,
#  'karku': 1912,
#  'komo': 1981,
#  'kay': 780,
#  'karkar': 779,
#  'ciste': 986,
#  'kapar': 778,
#  'erawe': 1639,
#  'kane': 775,
#  'uwonnere': 2790,
#  'ittone': 772,
#  'wenpe': 347,
#  'isonkur': 769,
#  'irwak': 768,
#  'kanna': 139,
#  'assa': 1489,
#  'kotor': 1997,
#  'kamasu': 774,
#  'tanne': 397,
#  'inanike': 764,
#  'saraha': 2460,
#  'kisa': 788,
#  'icakkerere': 759,
#  'yak': 158,
#  'erehotne': 1026,
#  'nen': 112,
#  'hotanukar': 756,
#  'akne': 950,
#  'hoka': 749,
#  'hawehe': 1058,
#  'amamecikappo': 1439,
#  'kaparus': 1902,
#  'hankeno': 742,
#  'utumam': 694,
#  'oyaoya': 2261,
#  'sukuscire': 2586,
#  'hamnesuwe': 741,
#  'ciaye': 980,
#  'pirma': 848,
#  'nanta': 2108,
#  'ewar': 739,
#  'ney': 241,
#  'oteksak': 513,
#  'aparu': 1456,
#  'popkeno': 2337,
#  'sospa': 892,
#  'uturu': 695,
#  'eramu': 729,
#  'ecikiki': 725,
#  'uhewpa': 920,
#  'ikkewpone': 1793,
#  'kes': 204,
#  'copitta': 722,
#  'onka': 827,
#  'ceppo': 717,
#  'nata': 810,
#  'kopao': 1986,
#  'eoripak': 1014,
#  'heciraspa': 1062,
#  'asikne': 714,
#  'ohak': 824,
#  'tuypa': 1382,
#  'noe': 2147,
#  'sempir': 2474,
#  'apukki': 712,
#  'yayetokoyki': 700,
#  'yarke': 1414,
#  'sanpe': 1313,
#  'osura': 380,
#  'yanke': 699,
#  'resu': 2404,
#  'isirkurantere': 594,
#  'nukuri': 1222,
#  'unarpe': 692,
#  'wampe': 1408,
#  'aep': 230,
#  'yaywennukar': 1424,
#  'koci': 1973,
#  'ukousaraye': 691,
#  'rapapse': 2374,
#  'cak': 1515,
#  'uepeker': 690,
#  'isa': 263,
#  'yayka': 2828,
#  'mour': 2086,
#  'uenewsar': 689,
#  'papus': 2277,
#  'etumekka': 1674,
#  'susam': 898,
#  'hayka': 1722,
#  'cipacipa': 721,
#  'iyetaptapu': 1876,
#  'turiri': 685,
#  'turep': 684,
#  'siknum': 883,
#  'mono': 621,
#  'tunas': 683,
#  'totto': 681,
#  'ehonkokisma': 996,
#  'kosneno': 1995,
#  'tonoto': 680,
#  'toankur': 678,
#  'puripirka': 1280,
#  'tasum': 676,
#  'ramuwen': 2371,
#  'suye': 675,
#  'yayutupare': 2842,
#  'sunke': 673,
#  'yaysitoma': 2838,
#  'ikasma': 325,
#  'yayomonnure': 2833,
#  'setsu': 1323,
#  'iramnukuri': 1111,
#  'unew': 2727,
#  'keto': 1942,
#  'eraw': 1638,
#  'sinnay': 669,
#  'ancikar': 209,
#  'hine': 748,
#  'simpuy': 667,
#  'nitat': 813,
#  'sesekka': 664,
#  'sawsawke': 663,
#  'tare': 1359,
#  'haru': 319,
#  'tuskote': 2682,
#  'sampesituri': 661,
#  'yukki': 2847,
#  'suma': 895,
#  'rekuci': 657,
#  'hopuni': 110,
#  'rataskep': 656,
#  'ukoyki': 541,
#  'motot': 2085,
#  'ranke': 655,
#  'iyairaykere': 326,
#  'ram': 654,
#  'sitteksam': 1342,
#  'puray': 652,
#  'apa': 181,
#  'kapatcir': 1137,
#  'harusak': 1716,
#  'pukusa': 651,
#  'inumpe': 1103,
#  'hokampa': 1073,
#  'siknu': 882,
#  'hoskino': 754,
#  'mipihi': 1192,
#  'ponte': 650,
#  'pasuy': 842,
#  'mosmano': 436,
#  'hike': 415,
#  'icimcimi': 1086,
#  'rura': 659,
#  'saha': 1308,
#  'ipokas': 767,
#  'oske': 641,
#  'niwasnu': 630,
#  'opke': 640,
#  'onnayke': 638,
#  'ohasir': 637,
#  'ukonoynoyke': 2708,
#  'sermaka': 2481,
#  'etupecikkap': 1680,
#  'kinrakar': 1955,
#  'patke': 2290,
#  'numke': 635,
#  'aynunisuk': 1508,
#  'hemhem': 1063,
#  'kap': 777,
#  'suy': 119,
#  'kimaypa': 1947,
#  'numa': 634,
#  'kaparno': 1901,
#  'noyenoye': 633,
#  'raosma': 860,
#  'teeta': 466,
#  'apeoy': 711,
#  'yaykouwepeker': 942,
#  'eyaske': 1044,
#  'nippoho': 626,
#  'monasap': 620,
#  'mik': 618,
#  'maw': 615,
#  'herasi': 1733,
#  'purse': 653,
#  'kusuri': 612,
#  'kinasutkamuy': 1158,
#  'iwentep': 1873,
#  'kuci': 797,
#  'maratto': 2046,
#  'pase': 2288,
#  'kotukka': 611,
#  'at': 313,
#  'kiki': 606,
#  'soyne': 221,
#  'kesukuran': 605,
#  'kayte': 604,
#  'enukosne': 727,
#  'rupus': 1302,
#  'tekkotoro': 2622,
#  'ikatanikamuy': 1089,
#  'karanke': 602,
#  'sikkamuk': 1326,
#  'kannasuy': 601,
#  'apekes': 959,
#  'tu': 539,
#  'kaki': 599,
#  'etun': 413,
#  'iyoski': 598,
#  'ukohopi': 2703,
#  'anta': 1451,
#  'iyohay': 597,
#  'epatay': 1015,
#  'kuriante': 2024,
#  'arke': 713,
#  'raprap': 2379,
#  'kannakar': 776,
#  'etunracici': 1677,
#  'akketek': 1436,
#  'terebi': 1363,
#  'irankarapte': 592,
#  'ikuspe': 590,
#  'ikeske': 1786,
#  'kappakappa': 1904,
#  'iciri': 588,
#  'yomomke': 2845,
#  'mur': 1198,
#  'honorop': 1746,
#  'huton': 587,
#  'pira': 2320,
#  'hur': 585,
#  'ramuosma': 2367,
#  'itar': 1861,
#  'sontak': 394,
#  'hoyupu': 584,
#  'hat': 577,
#  'ohaykekar': 2188,
#  'hani': 576,
#  'tomotuye': 679,
#  'siaman': 2487,
#  'sitoma': 891,
#  'karimpa': 1908,
#  'oyoyo': 2266,
#  'petneka': 2305,
#  'arsik': 1470,
#  'huskone': 1767,
#  'orepumpe': 2229,
#  'esikari': 572,
#  'emaka': 570,
#  'pise': 451,
#  'ekurok': 569,
#  'ekte': 568,
#  'euopitte': 1041,
#  'manu': 2045,
#  'eiyok': 567,
#  'cupka': 566,
#  'hekote': 321,
#  'toani': 280,
#  'ciramantep': 565,
#  'nanu': 623,
#  'cakke': 563,
#  'ari': 559,
#  'epawre': 1615,
#  'apepasuy': 557,
#  'ante': 555,
#  'osirus': 833,
#  'horka': 583,
#  'sikot': 2506,
#  'paka': 1256,
#  'tanukuran': 222,
#  'citarpe': 987,
#  'yay': 550,
#  'nispa': 185,
#  'epotara': 1017,
#  'yaske': 548,
#  'ikirkar': 1789,
#  'emusnit': 1602,
#  'usaraye': 545,
#  'e=hotuyekar': 1559,
#  'supuya': 674,
#  'unuhu': 544,
#  'ray': 246,
#  'inko': 1817,
#  'amke': 1444,
#  'pop': 245,
#  'tanpe': 52,
#  'kampisos': 1893,
#  'mataki': 2048,
#  'oyak': 244,
#  'ahupte': 702,
#  'erayap': 1025,
#  'eramasu': 255,
#  'yayutek': 2841,
#  'hokke': 236,
#  'ay': 232,
#  'ununiununi': 923,
#  'nispane': 2139,
#  'etu': 486,
#  'utari': 227,
#  'cinoyeinaw': 1536,
#  'osoma': 2244,
#  'poronno': 61,
#  'ankes': 706,
#  'sinotca': 462,
#  'hem': 215,
#  'nupur': 822,
#  'monhawke': 2078,
#  'cire': 212,
#  'isitayki': 1857,
#  'notarap': 2156,
#  'mean': 435,
#  'awa': 315,
#  'etaspe': 1664,
#  'koykar': 2004,
#  'iwan': 423,
#  'nani': 240,
#  'tekunpe': 2628,
#  'usi': 226,
#  'sikkasma': 461,
#  'sinen': 220,
#  'ahup': 476,
#  'ruwehe': 1304,
#  'tus': 208,
#  'harkika': 1054,
#  'artusa': 1473,
#  'icakkere': 203,
#  'an': 6,
#  'wen': 62,
#  'okimne': 1233,
#  'ramuisamka': 1289,
#  'menokoru': 2062,
#  'iperusuy': 591,
#  'yaruycup': 2813,
#  'ekuskonna': 1007,
#  'patek': 60,
#  'orowano': 2233,
#  'epetciw': 1618,
#  'ekottanu': 1006,
#  'toy': 197,
#  'ciki': 83,
#  'camsecamse': 977,
#  'kopasrota': 1987,
#  'akihi': 1435,
#  'oykus': 835,
#  'okere': 194,
#  'arkare': 1468,
#  'atkoci': 1497,
#  'patta': 2291,
#  'nisuk': 629,
#  'sakno': 660,
#  'kamure': 1132,
#  'kasi': 190,
#  'hekattar': 744,
#  'ponpene': 2336,
#  'suwe': 188,
#  'petpunki': 846,
#  'inunukaski': 1104,
#  'kemaha': 782,
#  'sitturaynu': 532,
#  'sanniyo': 2455,
#  'toytoy': 1370,
#  'tan': 30,
#  'mici': 617,
#  'wan': 228,
#  'arki': 172,
#  'tumi': 914,
#  'kuruma': 370,
#  'soy': 187,
#  'kat': 1919,
#  'epurse': 1018,
#  'antuki': 1452,
#  'putaha': 2353,
#  'sinep': 163,
#  'ratci': 2387,
#  'kampi': 289,
#  'uwepokpa': 2788,
#  'cikayanu': 1526,
#  'niwkes': 192,
#  'henke': 1064,
#  'otusuy': 2254,
#  'mun': 177,
#  'etukepuspe': 1673,
#  'rok': 170,
#  'sikkew': 2502,
#  'roski': 870,
#  'piru': 646,
#  'sinuye': 2525,
#  'usey': 225,
#  'toanpe': 2641,
#  'upas': 166,
#  'uwesinnayno': 932,
#  'ohorrrrrrrrr': 2194,
#  'kina': 154,
#  'easkay': 159,
#  'hese': 1738,
#  'iyotta': 160,
#  'yaytunaska': 2840,
#  'cupcupse': 1550,
#  'taan': 156,
#  'otutanu': 642,
#  'ke': 498,
#  'isoitak': 1859,
#  'urki': 2754,
#  'sanke': 129,
#  'okes': 2199,
#  'ramu': 142,
#  'ikokanu': 1096,
#  'nipeknu': 2131,
#  'utasare': 2766,
#  'sirpeker': 671,
#  're': 385,
#  'katu': 264,
#  'eywanke': 125,
#  'imok': 762,
#  'hura': 237,
#  'hinak': 115,
#  'kusne': 184,
#  'nociw': 332,
#  'us': 120,
#  'asinno': 966,
#  'cirkoyki': 1543,
#  'soka': 1346,
#  'kuwanno': 802,
#  'etoranne': 235,
#  'ikatani': 1088,
#  'eraratkire': 1637,
#  'nep': 35,
#  'kamuycep': 1895,
#  'horak': 582,
#  'koraci': 792,
#  'horkew': 1079,
#  'wentarap': 547,
#  'erampewtek': 77,
#  'ohaw': 141,
#  'etup': 1678,
#  'cotca': 723,
#  'camse': 564,
#  'herepasi': 1069,
#  'kurihi': 1180,
#  'moyre': 140,
#  'esirwante': 573,
#  'sawnu': 1318,
#  'noko': 2150,
#  'tap': 398,
#  'araskay': 1466,
#  'nasi': 2111,
#  'sinki': 178,
#  'mos': 808,
#  'ren': 658,
#  'tup': 224,
#  'mokor': 87,
#  'epeka': 1616,
#  'yakka': 23,
#  'parunpe': 2287,
#  'ratcako': 455,
#  'inkar': 138,
#  'atay': 1496,
#  '<pad>': 1,
#  'kouwepeker': 1174,
#  'atu': 1501,
#  'uteseno': 927,
#  'nisoro': 2138,
#  'aynu': 134,
#  'kaskot': 1918,
#  'pinnay': 2316,
#  'iku': 176,
#  'osoro': 834,
#  'mom': 376,
#  'op': 639,
#  'niyatori': 817,
#  'askanneno': 1484,
#  'orwa': 2235,
#  'ecutko': 992,
#  'put': 2352,
#  'pukuro': 853,
#  'amip': 133,
#  'ikamenas': 1780,
#  'etarka': 734,
#  'hapo': 147,
#  'uska': 546,
#  'eramasuy': 728,
#  'kotne': 1173,
#  'ramuriten': 859,
#  'kinkay': 266,
#  'cihotkey': 1524,
#  'hontom': 357,
#  'wakka': 100,
#  'pon': 88,
#  'epakasnu': 351,
#  'kamuy': 49,
#  'ehapur': 994,
#  ...}

# %%
jpn_vocab.get_stoi()
# Out:
# {'～を～にひっかける': 4510,
#  '～を（家に）入れる;～を（場所）に入れる': 4505,
#  '～を飲む;酒を飲む': 4502,
#  '～を隠す': 4499,
#  '～を陸に上げる': 4498,
#  '～を選ぶ': 4495,
#  '～を連れて行く': 4494,
#  '～を負ぶう': 4484,
#  '～を読む': 4483,
#  '～を見失う、～がみつからない': 4481,
#  '～を置く;～を置く;～を置く': 4476,
#  '～を縛る': 4475,
#  '～を締める': 4473,
#  '～を終える': 4472,
#  '～を立てる': 4470,
#  '～を突く': 4468,
#  '～を穴の中に入れる（？）': 4465,
#  '～を研ぐ': 4463,
#  '～を煮る': 4458,
#  '～を沸かす;～を暖める': 4455,
#  '～を沈める': 4454,
#  '～を殺す;～を殺す': 4451,
#  '～を止める': 4450,
#  '～を欠く': 4449,
#  '～を書く': 4448,
#  '～を数える;': 4446,
#  '～を支払う、～を行かせる、～をやる': 4445,
#  '～を掻く': 4444,
#  '～を捨てる': 4441,
#  '～を捕らえる': 4440,
#  '～を拾い集める;～を取る': 4437,
#  '～を拭く': 4436,
#  '～を投げる': 4434,
#  '～を打つ': 4433,
#  '～を憐れむ': 4432,
#  '～を思う': 4430,
#  '～を心配する、～を大事にする': 4427,
#  '～を射る;（矢を）射る': 4422,
#  '～を射る': 4421,
#  '～を始める': 4418,
#  '～を壊す': 4416,
#  '～を回す': 4415,
#  '～を噛む': 4414,
#  '～を呼ぶ;～を招待する': 4413,
#  '～を取る': 4411,
#  '～を取り逃がす、～に遅れる;遅い': 4410,
#  '～を切る（複）;～を切る（単）': 4407,
#  '～を分かちあう;～を分ける': 4405,
#  '～を出す': 4404,
#  '～を嫌がる': 4419,
#  '～を伸ばす': 4400,
#  '～を乾かす': 4399,
#  '～を不思議に思う': 4397,
#  '～をゆるめる': 4396,
#  '～をもらう': 4395,
#  '～をまるめる、～を閉める': 4394,
#  '～をまねる': 4392,
#  '～をまき散らす': 4390,
#  '～をひきずる': 4389,
#  '～をなくす、～を捨てる': 4387,
#  '～をつかむ、～を押さえる;～を地面に押さえつける': 4385,
#  '～をだます': 4384,
#  '～をたたむ、縛る': 4383,
#  '～をしぼる': 4381,
#  '～をしてみる': 4380,
#  '～をからかう': 4378,
#  '～をかき集める（？）、旅支度をする': 4376,
#  '～も': 4373,
#  '～ばかり、～だけ': 4371,
#  '～の鳥の尾羽根': 4370,
#  '～の頂上': 4369,
#  '～の陰;～の陰': 4368,
#  '～の途中': 4367,
#  '～の方へ;～の前に': 4362,
#  '～の懐': 4361,
#  '～の婿;婿': 4359,
#  '～の外で': 4357,
#  '～の向かい側に;向かい側に': 4354,
#  '～の中に、そこに;～の中、～のところ': 4350,
#  '～の中': 4349,
#  '～の上に;その上;高所に': 4348,
#  '～のようなもの': 4347,
#  '～のまわりで': 4346,
#  '～のところに遊びに行く': 4344,
#  '～のとおり、～のように': 4343,
#  '～に～の味見をさせる': 4336,
#  '～に食べさせる': 4335,
#  '～に見覚えがある;互いに親しくつきあう': 4331,
#  '～に結ぶ、～につなぐ': 4330,
#  '～に沿って上方に;～に向かって（逆らって）': 4329,
#  '～に慣れる': 4328,
#  '～に感心する': 4327,
#  '～にほれる': 4322,
#  '～を座らせる': 4425,
#  '～につまずく': 4321,
#  '～にくっつく': 4317,
#  '～にお世辞を言う': 4316,
#  '～なのか？': 4311,
#  '～で損をする': 4309,
#  '～で儲ける': 4308,
#  '～でもって': 4307,
#  '～でない、～しない;ない、いない': 4306,
#  '～か？': 4294,
#  '～から;～より': 4292,
#  '（髪を）とかす': 4285,
#  '（風が）激しい': 4283,
#  '（言葉の）意味': 4281,
#  '（芋やかぶなどのもらいものは）石油箱に入れられて、室に入れられて、そこに芋でも何でも入れられていたものだったが、ある日、私の母が「芋を出しなさい。オハウ〔汁もの〕をつくろう」と言うので、私はそうするのに、室の蓋を開いて中を見たけど何も無かった。「お母さん、芋も何も無いよ」って（私が言うと）、「どうして無いって話があるかと思うよ」と母が（言うので）': 4280,
#  '（箕を揺すって）…を選り分ける': 4276,
#  '（獣の皮を）剥ぐ': 4272,
#  '（彼は）来ると思います。': 4268,
#  '（彼が）行ったか分からなくて、私は耳を澄まして聞いていた。': 4267,
#  '（帯など）をゆるめる': 4266,
#  '（川を舟で）渡す': 4265,
#  '（家の）主人': 4264,
#  '～を編む': 4474,
#  '（動物や子どもなどが）キーキーとなく': 4256,
#  '（人に）使われる': 4253,
#  '（つぶれたイモ、しばれいも）': 4251,
#  '（そういう）ことならいい。': 4250,
#  '（あやす声）／お乳を飲んで寝なさい／ねんねするんだよ／ゆりかごを揺らすよ（あやす声）': 4248,
#  '（…する）ようだ': 4247,
#  '鼻筋、鼻梁': 4244,
#  '鼻水をたらす': 4241,
#  '鼻柱;鼻中隔': 4240,
#  '鼻の穴': 4238,
#  '鼻': 4237,
#  '黙っていろ。': 4235,
#  '黒目': 4234,
#  '黒板が私の頭に落ちて': 4233,
#  '麦;大麦': 4229,
#  '鹿の足跡': 4228,
#  '鳥は木の上にとまる。': 4227,
#  '鳥の尾羽根': 4225,
#  '鰯油': 4221,
#  '魚釣りに私と一緒に行かないか？': 4220,
#  '魚を捕らえる': 4219,
#  '魚の鱗': 4216,
#  '魚の開き干し': 4215,
#  '魚のはらわた': 4212,
#  '魂': 4207,
#  '髪の毛': 4206,
#  '高いところにある家': 4203,
#  '高い': 4202,
#  '骨は何にしますか？': 4200,
#  '驚いた。まだ君は眠っているの？': 4198,
#  '馬鹿にする;馬鹿な': 4196,
#  '馬車いっぱいに和人が乗っている。': 4194,
#  '馬を止めてください。ここで下りますよ。': 4189,
#  '首飾り': 4183,
#  '饒舌だ、おしゃべりだ': 4182,
#  '養父': 4180,
#  '飲み物': 4179,
#  '飲みますか？': 4178,
#  '飲みなさい。飲みなさい。': 4177,
#  '飲みなさい': 4175,
#  '～の片方の耳': 4364,
#  '飲ませてあげるよ。': 4174,
#  '飯を三人前持って来い。': 4173,
#  '飢えに耐えられない': 4170,
#  '食道': 4169,
#  '食事の準備してください、食事したいよ': 4167,
#  '食べ物': 4161,
#  '食べる': 4160,
#  '食べよう': 4159,
#  '食べた残り': 4157,
#  '食べたいもんだったらたくさん食べるよ。': 4155,
#  '飛び起きる': 4154,
#  '風邪をひく': 4153,
#  '風呂': 4151,
#  '風が強くて灰が飛び散るよ。': 4149,
#  '風が弱い': 4146,
#  '顔色が青い、顔色を失う': 4145,
#  '鱗': 4222,
#  '顔色が青い': 4144,
#  '額;額': 4140,
#  '頭を縛ってもいい。': 4137,
#  '～の方へ振り向く': 4363,
#  '頭が痛い': 4134,
#  '頭;～の上端': 4133,
#  '頬': 4132,
#  '靴': 4128,
#  '静内で不幸があって、そこに私が行ったら、三つの鍋、大鍋で外で汁物を作っている様子を見た。': 4125,
#  '露;露': 4120,
#  '霧が出る、霧雨が降る。': 4119,
#  '霞（？）': 4118,
#  '霞の天': 4117,
#  '霊力の強い人のところへ行って聞いた。': 4115,
#  '霊力のある': 4113,
#  '～に～を貸す;～を貸す': 4340,
#  '雷雲': 4112,
#  '雷神': 4111,
#  '雷光': 4110,
#  '雷が落ちなければいいね。': 4107,
#  '雲の天': 4106,
#  '雲が晴れて今はもう嵐はやんだ。': 4105,
#  '雪虫を見ると、もう雪が降るのも（？）近いようだと思う。': 4102,
#  '雪が降るのに（？）近いということだ。': 4100,
#  '～を剃る': 4409,
#  '雪が溶ける': 4097,
#  '雨降りは好きですか？': 4095,
#  '雨が降ると私は思う。': 4091,
#  '雨が降る。': 4089,
#  '雨が降りそうだ。': 4087,
#  '雨が弱い。': 4084,
#  '離婚する': 4080,
#  '離れる': 4079,
#  '雑談する、むやみに話す': 4078,
#  '雌ジカ': 4077,
#  '隣のおじさんはいつものように薪を切ってばかりいる。': 4072,
#  '隠れる': 4071,
#  '険しい山': 4070,
#  '陸を通る': 4068,
#  '陸のほうに家を見た。': 4067,
#  '陸のほうに家が見える。': 4066,
#  '陸に舟を上げる': 4065,
#  '陸': 4063,
#  '陰毛': 4062,
#  '降る': 4061,
#  '開きなさい': 4055,
#  '長らく見ませんでした。今までどこにいましたか？': 4053,
#  '長らく会いませんでした。あなたに会いたくてここで探しました。': 4051,
#  '長らくお目にかかりませんでした。': 4050,
#  '長らくお目にかからず、お会いしたかったのでここで探していました。': 4049,
#  '長さ': 4048,
#  '長い間、私たちは会わなかったけれど、今日会って私は嬉しい。': 4046,
#  '長い間、私たちは会わなかった。': 4045,
#  '長い;（時間的に）長い': 4044,
#  '鐘、鈴': 4042,
#  '鍋に水が入っている。': 4033,
#  '鍋が沸騰しているそばを私は通ったところ、鍋を私はこぼして手を火傷した。': 4032,
#  '鍋が沸騰しているそばを私は通ったところ、私はすべって鍋をこぼしててを火傷した。': 4031,
#  '鍋、釜と竹を全部持って来い。': 4030,
#  '錨': 4025,
#  '銀': 4023,
#  '（アイヌ語）で言ってください。': 4252,
#  '鉛': 4020,
#  '鉄道があったらいい。': 4019,
#  '鉄瓶に水を入れて沸かしたたら、もう湯気が立っているから、鉄瓶を（火から）あげなさい。': 4018,
#  '釣竿': 4017,
#  '釣り針;釣り針': 4015,
#  '釜に水を入れる。': 4012,
#  '金（きん）': 4010,
#  '野草を湯がきなさい。': 4009,
#  '醜い人': 4007,
#  '酒を飲むのはどうだ？': 4003,
#  '釘': 4011,
#  '酒を多く飲むな。': 4002,
#  '酒をつぐ': 4000,
#  '酒は米でつくられるものだ。': 3998,
#  '酒に酔う': 3996,
#  '酒かす': 3993,
#  '部屋へ入りなさい。': 3990,
#  '邪魔だ、ゴチャゴチャとうるさい': 3986,
#  '遠くに稲光は見えるが、雷さまはここには来ないだろう。': 3984,
#  '食べ物;食べ物': 4162,
#  '遠くに光が見えても、雷はここには来ないだろう。': 3983,
#  '遠くにある': 3982,
#  '遠い祖先': 3981,
#  '違っている;別々だ': 3979,
#  '違うよ。': 3978,
#  '道路ぶちに': 3977,
#  '道路ぶち': 3976,
#  '道具': 3975,
#  '道を横切る': 3974,
#  '道は本当にいい。': 3973,
#  '道の途中で': 3970,
#  '道の途中': 3969,
#  '道に迷う、道を見失う': 3967,
#  '過ぎる': 3963,
#  '遅鈍である': 3961,
#  '這う': 3955,
#  '途中でやめる': 3952,
#  '途中': 3951,
#  '逃げるな。': 3950,
#  '逃げる': 3949,
#  '近ければ一緒に行く。遠ければ行かない。': 3945,
#  '近くに;～の近くに': 3943,
#  '近くない;遠い': 3942,
#  '近い道を通って行かないで、いい道を通って行け。': 3941,
#  '輪': 3938,
#  '輝く;輝く': 3937,
#  '車の軸が折れたのです。': 3931,
#  '踏舞する;踊る': 3923,
#  '踏臼': 3922,
#  '釣る': 4016,
#  '踊りましょう': 3921,
#  '足りない;数が足りない': 3917,
#  '足の甲;足首から先': 3915,
#  '足の指': 3914,
#  '足が固くなったから揉みほぐしているよ。': 3910,
#  '足が不自由な人;足を引きずって歩く人': 3909,
#  '足;足': 3908,
#  '越年する': 3907,
#  '起きろ。誰だ？': 3905,
#  '走る': 3903,
#  '赤ん坊の泣き声': 3901,
#  '赤ん坊が夜泣きしたら、お化けが来ておっかないから、泣かずに寝なさい。': 3898,
#  '赤ん坊;赤ん坊;男の子': 3895,
#  '赤ちゃんの歯が生えるようになると、かゆいようでフーフー吹いてばかりいる。': 3894,
#  '貰い子（男の子）': 3891,
#  '負債者': 3888,
#  '身内': 3928,
#  '負債': 3887,
#  '途中にどこかで食べ物があるところはありますか？': 3954,
#  '豆や芋餅を作って、芋餅も作って食べて美味しかった。塩をちょっと入れると美味しくて沢山食べて大きくなった。': 3873,
#  '豆の皮': 3872,
#  '豆のさや': 3871,
#  '豆': 3869,
#  '謝る': 3868,
#  '談判をするために私は怒って行った。': 3867,
#  '調子が悪い': 3866,
#  '誰でも悪いことをすることもあるものだ。': 3865,
#  '誰でも': 3862,
#  '誰がしたの？': 3861,
#  '誰かが座っていた場所ですか？': 3857,
#  '語り合いましょう': 3853,
#  '話す': 3851,
#  '話し合う、議論しあう': 3850,
#  '貧乏人;豊かでない人;貧乏人': 3889,
#  '話がきらいな人': 3849,
#  '言葉': 3847,
#  '言って聞かせてください。': 3845,
#  '角': 3840,
#  '親戚ですよ。': 3836,
#  '親': 3835,
#  '見た目よりも年をとっているんですね。': 3829,
#  '裸である': 3825,
#  '裕福な人': 3824,
#  '装束する': 3822,
#  '行儀の良い': 3819,
#  '行って誰だか見て来い。': 3818,
#  '行って誰が来たかを見て来い。': 3817,
#  '行って見て来い。': 3816,
#  '行ってよく聞いて来い。': 3813,
#  '行ったおかげで、見ました。': 3811,
#  '行けません': 3810,
#  '行くつもりです。': 3806,
#  '行きなさい。': 3801,
#  '血管': 3799,
#  '蚊が来たようだよ。手で追い払いなさい。': 3794,
#  '蚊': 3792,
#  '虫を吸い込む': 3790,
#  '虫': 3789,
#  '藻': 3788,
#  '薪を持って来い。': 3786,
#  '薄い': 3784,
#  '葦簀〔よしず〕は、オニガヤでつくるものだ。': 3782,
#  '葉': 3781,
#  '荷物を預ける': 3778,
#  '荷物': 3775,
#  '草をかき分けてさがす。': 3772,
#  '草が沢山生えたものだから、': 3768,
#  '草が伸びたよ': 3767,
#  '草': 3766,
#  '茶碗を拭きなさい。食器を拭きなさい。': 3765,
#  '茶を三人前持って来い。': 3764,
#  '茣蓙を敷く': 3763,
#  '苦しむ': 3761,
#  '若者': 3758,
#  '若死にする': 3757,
#  '若い雄たけび': 3755,
#  '若い男': 3754,
#  '若い': 3752,
#  '良い馬ですよ。心配しないでください。': 3748,
#  '船首': 3747,
#  '船頭': 3746,
#  '船を出す': 3743,
#  '～を立てかける': 4469,
#  '船に酔ったので、私たちはどうすることもできませんか？': 3741,
#  '船に乗っている人': 3739,
#  '船があります。': 3738,
#  '舟を出しなさい。': 3736,
#  '舟に酔わなかったらいいな。': 3735,
#  '舟に荷物を乗せる': 3734,
#  '舟が壊れる、難破する': 3733,
#  '舟': 3730,
#  '臼': 3728,
#  '自分の家に帰るのに山から下りた。': 3727,
#  '開く': 4056,
#  '自分の体を洗う': 3726,
#  '自分で': 3724,
#  '自分が馬鹿だった。': 3723,
#  '臆病者': 3722,
#  '腹;腹の中': 3714,
#  '腫れ物ができる': 3711,
#  '腫れ物': 3710,
#  '腐乱する、腐る': 3708,
#  '脂身': 3704,
#  '胸焼けする': 3702,
#  '誰、どのように;誰': 3854,
#  '背の中央': 3697,
#  '背が高い': 3695,
#  '飢饉になる;飢饉': 4172,
#  '肺病、ぜんそくである': 3693,
#  '肝臓': 3689,
#  '肝と毛皮だけを使うのです。': 3688,
#  '肛門;肛門': 3687,
#  '肌脱ぎになる': 3686,
#  '聞きたくもない': 3678,
#  '聞いたこともないものだったので私は聞くのも嫌だった(聞くのを避けた)。': 3676,
#  '耳の穴': 3674,
#  '退屈する': 3948,
#  '耳に穴を開ける': 3673,
#  '耳が聞こえない人': 3671,
#  '雨天': 4094,
#  '耳': 3670,
#  '耕作する': 3669,
#  '考える': 3668,
#  '馬に乗って帰ったの？': 4184,
#  '考えてみる': 3667,
#  '老衰で動けない': 3666,
#  '老女、おばあさん;婆': 3665,
#  '老人': 3664,
#  '道;通り道、通る所': 3964,
#  '翼': 3663,
#  '美味しい食べ物を作った時に、隣に食べさせたいので、皿に入れて……火を入れて、': 3660,
#  '身じたくし終わりましたか？': 3924,
#  '罰せられる人': 3657,
#  '罪を犯す': 3656,
#  '織る、機織りする': 3655,
#  '近くに水はあるの？': 3944,
#  '織る、厚司織をする': 3654,
#  '～について～に命令する': 4320,
#  '酒くさい。': 3994,
#  '縫い糸がもつれて、すそを縫うこともできない。': 3652,
#  '網をつくるために、それをよった。': 3646,
#  '網;簗（やな）': 3645,
#  '綱': 3643,
#  '終わりになる': 3638,
#  '終わったか？': 3637,
#  '細いもの': 3635,
#  '素敵な美味しいものを私は食べたいわ。': 3633,
#  '素敵な男性を私は選ぶ。': 3632,
#  '酒の酔いがさめる': 3997,
#  '紐': 3627,
#  '約束、前もって知らせたこと': 3625,
#  '糸;縫い糸': 3624,
#  '糠': 3623,
#  '米屋はどこがいいですか？': 3618,
#  '血が出る': 3798,
#  '簡単だ、たやすい': 3610,
#  '節約しない': 3609,
#  '見るだけでも': 3833,
#  '節制する、節約する': 3608,
#  '箸はありますか？': 3607,
#  '見てもいいです。': 3831,
#  '箸;捧酒箸': 3606,
#  '箱': 3605,
#  '箕（み）': 3604,
#  '答える、返答する': 3603,
#  '答える、承諾の返事をする': 3602,
#  '第六、六番目（？）': 3599,
#  '竜': 3594,
#  '空である': 3587,
#  '穴': 3583,
#  '飢えを耐え忍ぶ': 4171,
#  '穀物を臼で搗く': 3582,
#  '魚の背骨;胸びれ;魚のほおの薄い骨;魚の背びれ': 4214,
#  '魚だの、穀物だのでお祓いした。': 4211,
#  '穀物をついて、箕でふるって籾殻を飛ばして、揺すって選り分けた。': 3581,
#  '稲光がする、光がさす': 3578,
#  '秋;秋になる': 3576,
#  '私達': 3573,
#  '私を馬鹿にしようと思うな。': 3572,
#  '私を馬に乗せてください。': 3571,
#  '私を追い越して行け。': 3570,
#  '間がくぼんだり、もりあがったりしている。': 4058,
#  '私を誘う': 3569,
#  '私を祓い清めて、それで外に出て、外で何をやっていたのかはわからないけれど二度三度そのようなことをするのを見た。': 3568,
#  '私より君は大きい。': 3564,
#  '私も行くつもりです。': 3562,
#  '私も元気でいたよ。': 3560,
#  '私は（この）着物だけ持っているので、毎日（それ）ばかり着ている。': 3558,
#  '腿股、腿;股、腿': 3721,
#  '私は飲みながら歌を言いたい。': 3555,
#  '私は頭が悪いものだから、いろんな話を聞かせてもらったけれど、': 3552,
#  '私は静内の人間の目つきだと言われた。': 3551,
#  '私は酔っぱらってる。飲んでいるもんだから、酔っぱらっている。': 3549,
#  '私は遠い村から来ました。': 3548,
#  '私は足をとられた。泥があって行くのが面倒だ。': 3545,
#  '私は誰に頼んだらいいの？': 3543,
#  '静かに話せ。': 4124,
#  '米': 3611,
#  '私は言えないよ。': 3541,
#  '私は言うこともできない。私は怒って、悪いものの血統だと言った。': 3540,
#  '空': 3585,
#  '私は言い置いた': 3538,
#  '私は見る': 3536,
#  '私は見たけれどもわからない。': 3535,
#  '私は裕福じゃないものだよ。': 3534,
#  '私は行くつもりです。': 3532,
#  '私は船酔いしそうな感じがしますよ。憐んでください。': 3528,
#  '私は腹が立った。': 3527,
#  '私は腰が痛いので、立ちたいけれど腰が痛いので歩くことも…立つこともできずに、よつんばいになって流しのところまで行った。': 3526,
#  '私は胸騒ぎがする': 3525,
#  '私は聞いていますよ。何かいい話をしてください。': 3524,
#  '私は綱を張って私の着物を干した': 3520,
#  '私は穀物を炊いていたら、滴を鍋のふちからしたたらせているから、ふたを取って下さい。': 3517,
#  '私は知る': 3516,
#  '私は知りたいので教えてください': 3515,
#  '私は百姓です。': 3512,
#  '私は登って山菜を採った。': 3510,
#  '私は病気で寝ていたよ。': 3508,
#  '私は疲れて、途中で休んだ。': 3505,
#  '私は町へ行きたかったけれど、孫が私から離れないので、行くこともできなかった。': 3502,
#  '私は火箸を探しています。': 3501,
#  '貝が皆流れてなくなってしまって、私は…': 3884,
#  '言うつもりですよ。': 3844,
#  '私は泳げない。': 3498,
#  '私は泣きながら遺言した': 3497,
#  '響く': 4131,
#  '私は気分が悪い（？）。': 3496,
#  '私は気分が悪い;私は少し気分が悪い。': 3495,
#  '私は歩けません。': 3494,
#  '私は欲しくもない': 3493,
#  '私は桜が一番好きだ。': 3491,
#  '私は暑かったので着物を脱いだ。': 3486,
#  '私は明日また来るつもりですよ。': 3485,
#  '私は日帰りで山に行ってきたわ。': 3484,
#  '私は料理の仕度をする気にもなれない。': 3483,
#  '（鳥が枝に）とまる': 4288,
#  '私は怒りながら、悪いものの血統だとののしった。': 3479,
#  '私は少し車をまた…持ってまた…けれど…': 3476,
#  '私は小さな女の子が病気でどうやってもよくならなくて、私はわあわあと泣いた。': 3473,
#  '私は家に帰ります。': 3472,
#  '私は大便をしに行く。': 3470,
#  '私は外へ出る。': 3469,
#  '私は呪う': 3468,
#  '私は君をからかったんだよ。': 3467,
#  '黄・青・緑色である': 4231,
#  '私は危なく道に迷うところだった。': 3466,
#  '私は十分食べました。': 3465,
#  '私は初めて聞いた。': 3463,
#  '私は分かりません': 3462,
#  '私は聞いたことないけれど。': 3523,
#  '私は分からない': 3461,
#  '私は今まで歩き回っていました。': 3457,
#  '私は二日前に来ました。': 3456,
#  '私は二、三日いるでしょう。': 3455,
#  '私は一日泊まるつもりだ。': 3453,
#  '私はヤマブドウが食べたいので、冬になって山に行ったけれど、もはやヤマブドウは無かった。採れる所も無かった。': 3451,
#  '私はアイヌ語が相変わらず下手だ。': 3448,
#  '私はゆうべ遅く寝たのですよ。': 3445,
#  '私はもらい泣きする（？）': 3444,
#  '私はもっと水が欲しい。': 3443,
#  '～を番をする、～を守る': 4459,
#  '私はどこかへ行って家の外を見ると、きれいに掃除してあったのを見た。この家に住む人は働き者ばかりなんだと思った。': 3437,
#  '私はそれを持って歩く。': 3435,
#  '私はそれが見当たらなかった。': 3434,
#  '私はそうだと思う。': 3433,
#  '私はすすった': 3432,
#  '私はこの話は少しも知りません。': 3431,
#  '私はこの仕事でとても疲れた。': 3429,
#  '雪が舞う。': 4098,
#  '私はお金を少しお財布から、使いたいので、探したけども、わからなかった。': 3428,
#  '私はいつも早く起きます。': 3427,
#  '私はあなた達の足を踏んでしまってごめんなさい。': 3426,
#  '私はあなた(あなた達)を呼んだけれど、返事しない。': 3425,
#  '腐ってしまったと私は思いながら見たら、傷んで無くて…': 3706,
#  '私は、私の': 3423,
#  '私は…を了解する': 3422,
#  '私は…に納得する': 3421,
#  '間違いなくあの人だね。': 4059,
#  '私は20才です。': 3419,
#  '私の頭に白髪があるように私は思うよ。抜いて下さいな。': 3417,
#  '私の部屋に火を持って来い。': 3416,
#  '私の足を君が踏んだので痛いよ。': 3414,
#  '私の足にまめができた。': 3413,
#  '私の財布をどこに置いたのか見失った。わからない。': 3412,
#  '私の言う言葉がわかりますか？': 3411,
#  '私の荷物はもう到着したか？': 3410,
#  '私の考えは違っている。': 3408,
#  '私の着物をどこかへ置いて見失ってしまったの？': 3406,
#  '私の着物が破れた。': 3405,
#  '私の着ていたものは全部濡れた。': 3404,
#  '私は疲れたので、これ以上行けません。': 3503,
#  '私の爺さんは、素敵な爺さんだった。世を去ってしまって、今はいない。': 3401,
#  '私の父は元気にしているよ。': 3400,
#  '糊気がない': 3622,
#  '米ぬか': 3612,
#  '私の歯を抜いてください。': 3396,
#  '集まる': 4075,
#  '私の息子は働きもしないで遊んでばかりいて私は説教したけれど駄目だ': 3393,
#  '静かにしなければ殴るぞ。': 4122,
#  '私の後から来なさいよ。': 3389,
#  '私の年はどのくらいだと君は思いますか？': 3388,
#  '私の家へ帰りますね。': 3385,
#  '私の家の表で恐ろしい物（蛇）が横切っていて、びっくりした。': 3382,
#  '私の家のまわりの草がいっぱい生えて、取るのも面倒だ。': 3381,
#  '私の家に行ったとき、畑にいた鹿が道を横切って逃げるのを見た。': 3380,
#  '～を避ける': 4496,
#  '私の家に彼／彼女が帰ってきたら言うことがあるから。': 3379,
#  '私の孫は学校に遅れそうで、走って行った。': 3378,
#  '私の孫たちがご飯を持って行かなかったので、おなかがすいていると思って行くのだよ。': 3377,
#  '私の婆ちゃんは病気になると、私の家の外にいる婆ちゃんがヨモギをとって来て、私のばあちゃんを祓い清めた。何か悪神を得たようだと言いながら、ヨモギをとって来て祓い清めると、私の婆ちゃんの病気は良くなった。': 3376,
#  '私の娘が遠くに行ったので、元気で帰ってくるように私は願って（？）いる。': 3374,
#  '雨が激しくて、この着物が濡れて縮んだよ。': 4085,
#  '私の女の子が木綿の布で遊んで裂いてしまった': 3373,
#  '私の口もぴくぴくして、何かまた私は見るのも、おしゃべりするのも、よじれ苦しむようだと思って': 3372,
#  '私の傍に寄りなさい。': 3370,
#  '私のところへ遊びに来い。': 3367,
#  '私のお爺さんは私が病気をすると、供物をこしらえて、供物で私の体を払い清めて窓から供物を外に出した。風邪の神様に憑かれたけれど、何も美味しい物はありませんから、よい国土へ行ったら美味しいものばかりたくさんあるはずですよ。我々は、貧乏なものだから何も無いので、風の神様はよい国土へお行きなさいと言いながら…': 3365,
#  '私に見せなかったら殴るよ。': 3363,
#  '～を着る': 4460,
#  '私に腹を立てていると思います。': 3362,
#  '私に慣れて吠えはしない。': 3359,
#  '私にこのように話したこと': 3357,
#  '私にくれるの？': 3356,
#  '鍔': 4037,
#  '私と一緒に行く。': 3353,
#  '私と一緒に行く…': 3352,
#  '笛': 3598,
#  '私たち二人で行こう。': 3350,
#  '私たち三人で行こう。': 3349,
#  '私たちは子どもと一緒に抱き合って寝た。': 3346,
#  '私たちはここに立っていなければなりませんか？': 3344,
#  '私たちはいつ沙流に到着しますか？': 3343,
#  '私たちのもの': 3341,
#  '私たちが使う包丁も小刀も刃物。鉈も刀も刃物。': 3340,
#  '私たちが、私たちの;私たちが、私たちの': 3339,
#  '私たち': 3338,
#  '私が食事している最中に、誰かが私を誘いに来た。': 3337,
#  '私が見たところ': 3335,
#  '笑う': 3597,
#  '私が行ったら私がしましょう。': 3333,
#  '私が行ったけれども、留守だった。': 3332,
#  '私が行くと、君はいなかったのです。': 3331,
#  '私が行くと、六匹の狐を土とともに草とともに刻んで、私は殺してしまった。': 3330,
#  '私が笑うと、みんなが私を叩いた。': 3329,
#  '私が町に行って来ると、私の犬がどこかへ行ってしまった。（犬は）お腹がすいてどこかへ行ってしまった。': 3328,
#  '私が持っているのは新品だ。': 3326,
#  '私が持っていたものをどこに置いたのかわからない。': 3325,
#  '高い所に置いて。': 4205,
#  '私が幼い頃は、ヤマブドウやイチゴを採って食べた。': 3324,
#  '私が小さかった時は、寄せ煮やお汁やお粥を食べて、母親が作ってくれて食べて大きくなった。': 3322,
#  '私が小さい時は、私ばかり火に灰をかけていたよ。': 3321,
#  '美青年': 3662,
#  '私が寝ていたが子どもが来たので私は目が覚めた': 3317,
#  '私が子どもの頃、土をこねて遊んでばかりいたものだから母は私を叱った。': 3315,
#  '私がいると;私がいるときに': 3313,
#  '私がいなくてすみませんでした。': 3312,
#  '祭壇を司る神': 3309,
#  '～のそばにある;～の近くにある': 4342,
#  '神のおばさん、ケナㇱウナㇻペ（魔物の一種）': 3307,
#  '祝い、婚礼;酒宴': 3305,
#  '空吐きする': 3588,
#  '祖父、近い先祖': 3304,
#  '祈る': 3303,
#  '蚊;蚊': 3793,
#  '磯': 3301,
#  '硫黄': 3300,
#  '破れ着物': 3299,
#  '破れているよ。': 3298,
#  '砂ぼこり': 3297,
#  '親類;親類': 3838,
#  '砂': 3296,
#  '短い': 3294,
#  '知りません。': 3293,
#  '矢骨': 3291,
#  '矢羽': 3290,
#  '矢筈（やはず）': 3289,
#  '雄ジカ': 4074,
#  '矢でシカを殺したのだ。': 3287,
#  '矢がら、箆（の）': 3286,
#  '馬に乗って登れますか？': 4185,
#  '誰でも体が疲れると寝られるものです。': 3864,
#  '矢': 3285,
#  '着物の前身ごろ': 3284,
#  '着物でもなんでも干すのに干し竿にぶら下げる。': 3283,
#  '着物だけなら、足りないものだから、': 3282,
#  '私を一緒に行こうと誘ってくれ。': 3565,
#  '着物が干される。': 3281,
#  '着物、私の持ち物': 3280,
#  '着物;着物': 3279,
#  '眠りましょう': 3275,
#  '黒い;真っ黒だ': 4232,
#  '私はアイヌ語…': 3447,
#  '眠らないでください。今行くつもりですよ。': 3274,
#  '真夜中でも戸を開けているのですか？': 3272,
#  '真っ直ぐに、間違いなく、正確に': 3270,
#  '眉毛': 3268,
#  '相撲取り': 3267,
#  '～を赤くする': 4486,
#  '直される': 3265,
#  '私は立つこともできずによつんばいになって流しに行った。': 3519,
#  '目配せする': 3264,
#  '目で合図する': 3260,
#  '目じり': 3259,
#  '絹、布': 3642,
#  '目くそ': 3258,
#  '目が悪くなって、よく見えなくなった。': 3256,
#  '目': 3253,
#  '盛り上がっている': 3252,
#  '盗人、泥棒': 3251,
#  '盗む': 3250,
#  '遅い': 3958,
#  '紙一枚': 3631,
#  '皮': 3247,
#  '白髪の老人;白髪のおじいさん;おじ': 3244,
#  '白目;まつげ': 3243,
#  '白い': 3242,
#  '私の傍': 3369,
#  '痰': 3240,
#  '病気になる': 3237,
#  '病気で死ぬ': 3236,
#  '病気': 3235,
#  '病床に伏す': 3234,
#  '病人': 3233,
#  '疲れる、くたびれる': 3232,
#  '疲れたので、ちょっと横になりたい。': 3231,
#  '留守を案ずる': 3229,
#  '留守なのかい？': 3228,
#  '畑を耕すつもりだけど、誰もいないよ。どこか行って人頼みしてきて。': 3226,
#  '畑の草を燃やすと別のところに火がついて、あわてて…': 3225,
#  '畑で、豆を刈るのに風が強くて、バラバラに撒き散らされていたので、よせ集めた。': 3224,
#  '違っているものが欲しい。': 3980,
#  '男ばかりです。': 3222,
#  '申し訳ありませんが、言いましょうか？': 3220,
#  '用心する': 3218,
#  '男児が生まれた。': 3223,
#  '甥;甥': 3217,
#  '生まれる;産む': 3215,
#  '生の肉': 3214,
#  '生の米': 3213,
#  '生のシナなの？': 3211,
#  '生である': 3210,
#  '玄関の上り口にゆっくり腰かけなさい。': 3207,
#  '猟師': 3202,
#  '猛犬だから噛まれるよ。': 3199,
#  '狭い': 3198,
#  '狩猟する': 3197,
#  '狩小屋': 3196,
#  '～を何度も叩く': 4401,
#  '犬を追い払え。': 3194,
#  '犬を追い払う。': 3193,
#  '若者、青年;若者': 3759,
#  '犬が鳴いているよ。追い出してこい。': 3192,
#  '赤ん坊が何かにとり憑かれ、泣いてばかりいる。': 3897,
#  '犬が私に吠えたので、石をぶつけると逃げて行った。': 3191,
#  '片袖': 3187,
#  '片方の;半ば;～の片方;～の半数、半分': 3186,
#  '父親に不孝をする': 3185,
#  '私は身支度した。': 3546,
#  '爪;～の爪;～の爪': 3183,
#  '熱湯を私の手の上に私はこぼして、自分の手を火傷して…痛い。': 3181,
#  '熱い': 3180,
#  '熟れる': 3179,
#  '煮たシナ皮だよ。': 3173,
#  '煙': 3172,
#  '私が寝ると夢でうなされて、疲れて、それに驚いた。': 3318,
#  '焼ける': 3171,
#  '焼き串': 3170,
#  '焦げた匂い': 3169,
#  '無料であげる;無料であげる': 3168,
#  '無傷である傷んでいないこわれてない': 3166,
#  '炭焼き（炭を作る人）': 3165,
#  '炉鉤': 3163,
#  '炉ぶち': 3161,
#  '火鉢に火はありますか？': 3159,
#  '火を消す。': 3156,
#  '目がしら': 3255,
#  '火を消す': 3155,
#  '火を消しなさい': 3154,
#  '火を掃き集めて埋める。': 3153,
#  '火を吹いてください。': 3152,
#  '火をうずめる': 3151,
#  '若い木': 3753,
#  '火の神': 3147,
#  '火の光': 3146,
#  '軽い': 3935,
#  '火のそばで': 3145,
#  '火が見事だ。': 3144,
#  '火が激しい': 3143,
#  '火が小さい。': 3140,
#  '火がメラメラと燃える': 3139,
#  '火がはじける。': 3138,
#  '濡れた木を燃やしていても、燃えないで煙ばかり上がる。喘息の私の母は、煙でむせて、こんこんと何度も咳をするから、私はそれをかわいそうに思った。': 3133,
#  '濃い;濁る': 3131,
#  '濃い': 3130,
#  '激しい;燃える': 3129,
#  '漕ぐ': 3127,
#  '滝': 3126,
#  '湧き上がる、湧き出る': 3119,
#  '湧いているよ。': 3118,
#  '湖の向かい側に': 3117,
#  '湖': 3116,
#  '港': 3115,
#  '渡し船はありますか？': 3109,
#  '渡し場はどこにありますか？': 3108,
#  '脇': 3705,
#  '清潔にする': 3107,
#  '豊作である': 3879,
#  '淵': 3104,
#  '深い川なのです。': 3102,
#  '雲があって星も見えない。': 4104,
#  '酒を一杯、余計に付けていますよ。': 4001,
#  '深い川ですか？': 3101,
#  '深い川ですか、浅い川ですか？': 3100,
#  '深い川です。': 3099,
#  '雨がたくさん激しくて外にも出かねる': 4082,
#  '消し炭を持って来い。': 3096,
#  '海の神様': 3093,
#  '私も年をとったものだから、きちんと座ってから、立ち上がって歩くこともできないので、少しずつ体をほぐして、それで初めて歩くことができる。': 3561,
#  '海の向こうに住んでいる人びと': 3089,
#  '～を迎える': 4490,
#  '海に行くと魚がたくさん捕れているのを見て、うらやましかった。': 3085,
#  '身じたくをする、自分の支度をする': 3925,
#  '海': 3083,
#  '浜に私が下りると、貝がたくさん上がっていてカラスが群がってその貝をむしっている様子を私は見たよ。': 3081,
#  '浜で網を引いていたら、魚がたくさん網の中に入っていて、それが陸に上がってくると、和人もアイヌも大勢集まって来て手伝った。': 3078,
#  '私たちも行きたい。;私たち全員も行きたい。': 3348,
#  '浜': 3076,
#  '浅い川ですか？': 3074,
#  '浅い': 3073,
#  '流木': 3072,
#  '流れ落ちる': 3071,
#  '流れに沿って上って行く': 3069,
#  '米を私はぎゅっと握った。': 3616,
#  '流れてしまった。': 3068,
#  '流し網をする網': 3067,
#  '津波': 3062,
#  '私はアイヌ語を知りたいけれど': 3449,
#  '泳ぐ': 3061,
#  '波がしら': 3058,
#  '泉;池': 3056,
#  '～を買う': 4485,
#  '～を思い出す': 4429,
#  '芋を茹でて、水が垂れるので煮汁をこぼした。': 3749,
#  '油': 3055,
#  '沸騰している鍋のそばを私は通ったところ、すべってその鍋を自分にひっくり返して火傷した。': 3054,
#  '沸騰しているなべのそばを私は通ったところ、その鍋を私は自分にこぼして火傷した。': 3053,
#  '沸かし湯': 3049,
#  '沢をさかのぼる;川をさかのぼる': 3046,
#  '沙流へ行くでしょう。': 3044,
#  '沙流に到着した。': 3043,
#  '沖津波と山津波が来て、ぶつかり合って、流れて': 3041,
#  '沖へ出る': 3040,
#  '沖の方へ行く;沖へ行く': 3038,
#  '沖に': 3037,
#  '犬が二匹私を追いかけてきた。': 3190,
#  '決して～してはいけない。': 3035,
#  '～を閉じる、～をふさぐ': 4497,
#  '決して怒ってはいけません。': 3032,
#  '決して何も忘れないよう、よく気をつけろ。': 3031,
#  '火;火': 3135,
#  '汚れている': 3030,
#  '汚い、よごれる;～を汚くする、～をよごす': 3029,
#  '氷;流氷': 3024,
#  '水鳥': 3023,
#  '錨を下ろす': 4027,
#  '水流が流れる': 3021,
#  '水汲みに行く道': 3020,
#  '水を汲んで来い。': 3019,
#  '水をください。': 3015,
#  '水でむせる': 3011,
#  '水が減る': 3008,
#  '水が沸く。': 3007,
#  '気前のいい人（？）': 3003,
#  '気をつける': 3002,
#  '気をつけなさい。': 3001,
#  '荷を背負う': 3774,
#  '気が重い、だるい': 2999,
#  '毛皮で作った衣服': 2997,
#  '毛皮': 2995,
#  '毎月': 2991,
#  '毎晩一人でいて、私はつらい。': 2990,
#  '私は縫い物(編み物)ばかりしているよ。': 3521,
#  '毎晩、私は横になっても眠れないと、目を開けて外を見ると、あの窓から星を見て、「あの星はどこまで来た」と思いながら毎晩過ごしている。': 2989,
#  '毎日毎日、天気がいいからでしょう。': 2986,
#  '毎日天気がいい。': 2984,
#  '連日、一人ぼっちでいるものだから、食事するのも面倒くさい。': 3957,
#  '毎日、何もしないで、何か考えるがど忘れする。': 2983,
#  '毎日、何かしようと思っても、ど忘ればかりしている。': 2981,
#  '毎日、何かしようと思いながらも、私は大儀で過ごしている': 2980,
#  '～を集める;集まる;': 4501,
#  '毎日、なおなおこっちにばかり私は来ている。': 2979,
#  '私に教えてくれ': 3360,
#  '毎年': 2977,
#  '私は使いませんから。': 3459,
#  '殺されて、その皮を剥ぐ': 2975,
#  '死人': 2974,
#  '死んでしまった。': 2973,
#  '死に殻': 2970,
#  '米を買って余った金': 3617,
#  '歯;～の歯': 2969,
#  '歩き回る': 2967,
#  '歩いてきたので私は疲れた。少し横になりたい。': 2966,
#  '道の東側': 3968,
#  '竹、ネマガリダケ': 3595,
#  '火山': 3157,
#  '正直だ、気立てがいい': 2964,
#  '歌を一曲歌いなさい。': 2961,
#  '歌う、即興歌を歌う': 2960,
#  '歌う': 2959,
#  '目玉': 3261,
#  '歌いましょう': 2958,
#  '欺く;欺く（？）;人をだます;欺く': 2957,
#  '欲しい': 2956,
#  '次の船はいつ出るの？': 2954,
#  '次の': 2953,
#  '櫂': 2952,
#  '橋を渡る': 2951,
#  '（外に）出る、抜ける': 4263,
#  '行く…': 3805,
#  '橋': 2949,
#  '樽の縁におかゆがついて汚い。': 2948,
#  '私は話せません。': 3542,
#  '浜に下りたくて、とるものもとりあえず走った。': 3079,
#  '樽;樽': 2945,
#  '横糸': 2942,
#  '買って来ました。': 3892,
#  '横': 2941,
#  '様子である': 2940,
#  '槍の鞘': 2939,
#  '雷が鳴って今や雨が激しくなった。': 4109,
#  '構うな。': 2937,
#  '行く;行く;行く': 3804,
#  '梶': 2933,
#  '～を知らない': 4462,
#  '根元': 2929,
#  '栗のいが': 2925,
#  '栗': 2924,
#  '柱': 2921,
#  '柄（つか）': 2920,
#  '柄杓（ひしゃく）': 2919,
#  '枝わかれしている角': 2918,
#  '林;木原': 2916,
#  '杼（ひ）（織具）': 2914,
#  '杵': 2913,
#  '東（風）の風下がある（？）': 2912,
#  '東風（？）': 2911,
#  '東風（地方により異なる）': 2910,
#  '東南風': 2909,
#  '（値段を）下げる': 4255,
#  '湯、温泉': 3122,
#  '次の馬車はいつ外に出ますか？': 2955,
#  '東に住む人;北海道の東南地方の人': 2907,
#  '杯の台': 2906,
#  '来月には雪が降るだろうね。': 2905,
#  '来月': 2904,
#  '来るつもりでしたが。': 2900,
#  '来る': 2898,
#  '私達は米をついて、私の母がヨモギをとって、上手につくって…米粉に入れて、上手につくって、茹でて、食べさせてくれて美味しかったというのを聞いて、美味ししかったことを': 3574,
#  '来ましたよ。': 2897,
#  '高いところにいる者': 4204,
#  '来ないの？': 2896,
#  '村のまわりで': 2892,
#  '村が蘇る。': 2891,
#  '耳たぶ、耳朶': 3672,
#  '村': 2889,
#  '朽ち木': 2888,
#  '札幌という町を知っていますか？': 2884,
#  '本流': 2883,
#  '本当のことか？': 2882,
#  '本当に本当のことか？': 2877,
#  '本当に。': 2873,
#  '草を刈る': 3773,
#  '本当です。': 2872,
#  '木綿の布': 2870,
#  '木片、木端': 2868,
#  '木を焼く。': 2866,
#  '木の枝': 2863,
#  '見たのですか？': 3828,
#  '期待する、望む;～を相談する;～を頼る、～に頼む': 2858,
#  '朝食は食べ終えてしまいましたか？': 2857,
#  '朝から夕方まで': 2854,
#  '朝、行くのですか？': 2853,
#  '朝、お湯をわかして飲みたかったから、茶碗にお湯を入れるとこぼして手を火傷した。': 2851,
#  '望んでいる': 2850,
#  '月末（？）': 2848,
#  '水を汲むように言え。': 3018,
#  '月光': 2847,
#  '月が欠ける。': 2846,
#  '月;月': 2844,
#  '栗を拾い集める。': 2928,
#  '最も大きな家': 2843,
#  '最も': 2840,
#  '暗くなる': 2838,
#  '霜;霜': 4116,
#  '暗くなっている': 2837,
#  '暖かくしていなさい。': 2835,
#  '暑いですね': 2833,
#  '貝がら': 3883,
#  '晩夏': 2830,
#  '時計を持っていません。': 2829,
#  '昨晩私は寝られずにいるとなにか音がちゅるちゅるしているのを聞いて、「何の音だろう」と思っていたが、眠れないので起きてみると': 2828,
#  '昨夜よく寝ましたか？': 2824,
#  '昨夜はお前が悪く言ったから、今日は仕返しをしてやるぞ、この野郎。': 2823,
#  '春になると雪が解けて、どこかに行きたいけど汚いものだから行くのも億劫だ。': 2821,
#  '春になる': 2820,
#  '星の天': 2817,
#  '星': 2816,
#  '昔から使ってきた…': 2814,
#  '昔から': 2813,
#  '昔、来たの？': 2812,
#  '明朝早く起こしてくれ。': 2810,
#  '明日魚とりに行こう。': 2809,
#  '骨': 4199,
#  '明日舟に乗りなさい。': 2807,
#  ...}

# %% [markdown]
# ### Vanilla Transformer Model

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, Embedding, Dropout, LayerNormalization, MultiHeadAttention
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# Load the tokenizers
source_tokenizer = RobertaTokenizerFast.from_pretrained("AinuBERTTokenizer")
target_tokenizer = AutoTokenizer.from_pretrained("cl-tohoku/bert-base-japanese")

import pandas as pd
from sklearn.model_selection import train_test_split

# read txt file
df_ain = pd.read_csv("poysuwop_ain.txt", sep="\t", header=None)
df_jpn = pd.read_csv("poysuwop_jpn.txt", sep="\t", header=None)

# rename columns
df_ain.columns = ["ain"]
df_jpn.columns = ["jpn"]

# combine dataframes
df = pd.concat([df_ain, df_jpn], axis=1)

# split data into train and validation sets
train_data, val_data = train_test_split(df, test_size=0.2, random_state=42)

# ハイパーパラメータの設定
num_layers = 6
d_model = 25 #128
dff = 1024 #512
num_heads = 16 #8
dropout_rate = 0.1
batch_size = 32
max_seq_length = 100
source_vocab_size = source_tokenizer.vocab_size
target_vocab_size = target_tokenizer.vocab_size

# create generator functions for train and validation data
def train_dataset():
    for _, row in train_data.iterrows():
        decoder_input = target_tokenizer.encode(row['jpn'], max_length=max_seq_length, padding='max_length', truncation=True)
        target_sequence = decoder_input[1:]
        target_sequence.append(0)  # パディングトークン
        target_one_hot = tf.keras.utils.to_categorical(target_sequence, num_classes=target_vocab_size)
        yield {
            'ain': source_tokenizer.encode(row['ain'], max_length=max_seq_length, padding='max_length', truncation=True),
            'jpn': decoder_input,
            'target': target_one_hot
        }

def val_dataset():
    for _, row in val_data.iterrows():
        decoder_input = target_tokenizer.encode(row['jpn'], max_length=max_seq_length, padding='max_length', truncation=True)
        target_sequence = decoder_input[1:]
        target_sequence.append(0)  # パディングトークン
        target_one_hot = tf.keras.utils.to_categorical(target_sequence, num_classes=target_vocab_size)
        yield {
            'ain': source_tokenizer.encode(row['ain'], max_length=max_seq_length, padding='max_length', truncation=True),
            'jpn': decoder_input,
            'target': target_one_hot
        }

# データセットの作成
train_dataset = tf.data.Dataset.from_generator(
    train_dataset,
    output_signature={
        'ain': tf.TensorSpec(shape=(max_seq_length,), dtype=tf.int32),
        'jpn': tf.TensorSpec(shape=(max_seq_length,), dtype=tf.int32),
        'target': tf.TensorSpec(shape=(max_seq_length, target_vocab_size), dtype=tf.float32)
    }
)

val_dataset = tf.data.Dataset.from_generator(
    val_dataset,
    output_signature={
        'ain': tf.TensorSpec(shape=(max_seq_length,), dtype=tf.int32),
        'jpn': tf.TensorSpec(shape=(max_seq_length,), dtype=tf.int32),
        'target': tf.TensorSpec(shape=(max_seq_length, target_vocab_size), dtype=tf.float32)
    }
)

train_dataset = train_dataset.batch(batch_size)
val_dataset = val_dataset.batch(batch_size)

# Transformerのエンコーダーレイヤー
def transformer_encoder_layer(inputs, d_model, num_heads, dff, rate=0.1):
    attention_output = MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(inputs, inputs)
    attention_output = Dropout(rate)(attention_output)
    out1 = LayerNormalization(epsilon=1e-6)(inputs + attention_output)

    ffn_output = Dense(dff, activation='relu')(out1)
    ffn_output = Dense(d_model)(ffn_output)
    ffn_output = Dropout(rate)(ffn_output)
    out2 = LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

    return out2

def transformer_decoder_layer(inputs, enc_output, d_model, num_heads, dff, rate=0.1):
    attention_output1 = MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(inputs, inputs)
    attention_output1 = Dropout(rate)(attention_output1)
    out1 = LayerNormalization(epsilon=1e-6)(inputs + attention_output1)

    attention_output2 = MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(out1, enc_output)
    attention_output2 = Dropout(rate)(attention_output2)
    out2 = LayerNormalization(epsilon=1e-6)(out1 + attention_output2)

    ffn_output = Dense(dff, activation='relu')(out2)
    ffn_output = Dense(d_model)(ffn_output)
    ffn_output = Dropout(rate)(ffn_output)
    out3 = LayerNormalization(epsilon=1e-6)(out2 + ffn_output)

    return out3

# Transformerモデルの構築
def build_transformer_model(source_vocab_size, target_vocab_size, num_layers, d_model, num_heads, dff, max_seq_length, rate=0.1):
    inputs = Input(shape=(max_seq_length,), name='ain')
    dec_inputs = Input(shape=(max_seq_length,), name='jpn')

    enc_embedding = Embedding(source_vocab_size, d_model)(inputs)
    enc_outputs = enc_embedding

    for _ in range(num_layers):
        enc_outputs = transformer_encoder_layer(enc_outputs, d_model, num_heads, dff, rate)

    dec_embedding = Embedding(target_vocab_size, d_model)(dec_inputs)
    dec_outputs = dec_embedding

    for _ in range(num_layers):
        dec_outputs = transformer_decoder_layer(dec_outputs, enc_outputs, d_model, num_heads, dff, rate)

    outputs = Dense(target_vocab_size, activation='softmax')(dec_outputs)

    model = Model([inputs, dec_inputs], outputs, name='transformer')

    return model

# モデルのコンパイル
model = build_transformer_model(source_vocab_size, target_vocab_size, num_layers, d_model, num_heads, dff, max_seq_length, dropout_rate)
model.compile(optimizer=Adam(beta_1=0.9, beta_2=0.98, epsilon=1e-9), loss='categorical_crossentropy', metrics=['accuracy'])

# モデルの訓練
model.fit(train_dataset.map(lambda x: ({"ain": x["ain"], "jpn": x["jpn"]}, x["target"])),
          epochs=20,
          validation_data=val_dataset.map(lambda x: ({"ain": x["ain"], "jpn": x["jpn"]}, x["target"])))
# Out:
# Epoch 1/20
# 127/127 [==============================] - 200s 1s/step - loss: 1.5448 - accuracy: 0.9121 - val_loss: 0.7772 - val_accuracy: 0.9179
# Epoch 2/20
# 127/127 [==============================] - 151s 1s/step - loss: 0.7512 - accuracy: 0.9195 - val_loss: 0.7821 - val_accuracy: 0.9179
# Epoch 3/20
# 127/127 [==============================] - 150s 1s/step - loss: 0.7475 - accuracy: 0.9195 - val_loss: 0.7889 - val_accuracy: 0.9179
# Epoch 4/20
# 127/127 [==============================] - 150s 1s/step - loss: 0.7451 - accuracy: 0.9195 - val_loss: 0.7972 - val_accuracy: 0.9179
# Epoch 5/20
# 127/127 [==============================] - 150s 1s/step - loss: 0.7427 - accuracy: 0.9195 - val_loss: 0.8008 - val_accuracy: 0.9179
# Epoch 6/20
# 127/127 [==============================] - 150s 1s/step - loss: 0.7407 - accuracy: 0.9195 - val_loss: 0.8112 - val_accuracy: 0.9179
# Epoch 7/20
# 127/127 [==============================] - 150s 1s/step - loss: 0.7394 - accuracy: 0.9195 - val_loss: 0.8098 - val_accuracy: 0.9179
# Epoch 8/20
# 127/127 [==============================] - 150s 1s/step - loss: 0.7376 - accuracy: 0.9195 - val_loss: 0.8177 - val_accuracy: 0.9179
# Epoch 9/20
# 127/127 [==============================] - 150s 1s/step - loss: 0.7360 - accuracy: 0.9195 - val_loss: 0.8162 - val_accuracy: 0.9179
# Epoch 10/20
# 127/127 [==============================] - 149s 1s/step - loss: 0.7340 - accuracy: 0.9195 - val_loss: 0.8222 - val_accuracy: 0.9179
# Epoch 11/20
# 127/127 [==============================] - 146s 1s/step - loss: 0.7328 - accuracy: 0.9195 - val_loss: 0.8208 - val_accuracy: 0.9179
# Epoch 12/20
# 127/127 [==============================] - 146s 1s/step - loss: 0.7323 - accuracy: 0.9195 - val_loss: 0.8265 - val_accuracy: 0.9179
# Epoch 13/20
# 127/127 [==============================] - 150s 1s/step - loss: 0.7320 - accuracy: 0.9195 - val_loss: 0.8278 - val_accuracy: 0.9179
# Epoch 14/20
# 127/127 [==============================] - 150s 1s/step - loss: 0.7314 - accuracy: 0.9195 - val_loss: 0.8232 - val_accuracy: 0.9179
# Epoch 15/20
# 127/127 [==============================] - 148s 1s/step - loss: 0.7340 - accuracy: 0.9195 - val_loss: 0.8220 - val_accuracy: 0.9179
# Epoch 16/20
# 127/127 [==============================] - 147s 1s/step - loss: 0.7455 - accuracy: 0.9195 - val_loss: 0.8096 - val_accuracy: 0.9179
# Epoch 17/20
# 127/127 [==============================] - 146s 1s/step - loss: 0.7429 - accuracy: 0.9195 - val_loss: 0.8103 - val_accuracy: 0.9179
# Epoch 18/20
# 127/127 [==============================] - 148s 1s/step - loss: 0.7433 - accuracy: 0.9195 - val_loss: 0.8072 - val_accuracy: 0.9179
# Epoch 19/20
# 127/127 [==============================] - 150s 1s/step - loss: 0.7425 - accuracy: 0.9195 - val_loss: 0.8064 - val_accuracy: 0.9179
# Epoch 20/20
# 127/127 [==============================] - 150s 1s/step - loss: 0.7417 - accuracy: 0.9195 - val_loss: 0.8069 - val_accuracy: 0.9179

# %%
# モデルの保存
save_path = "./translation_model"
tf.keras.models.save_model(model, save_path)

# %%
# モデルのロード
loaded_model = tf.keras.models.load_model(save_path)

# %%
# テスト用の入力文
test_sentence = "ohonno somo unukar þan"
# test_sentence = "Itak=as aynu itak anu?"

# 入力文をトークン化
test_input = source_tokenizer.encode(test_sentence, max_length=max_seq_length, padding='max_length', truncation=True)
test_input = np.expand_dims(test_input, axis=0)

# デコーダーの初期入力
decoder_input = target_tokenizer.encode("", max_length=max_seq_length, padding='max_length', truncation=True)
output = tf.expand_dims(decoder_input, 0)

# 翻訳ループ
for i in range(max_seq_length):
    predictions = loaded_model([test_input, output[:, :max_seq_length]], training=False)
    predictions = predictions[:, i, :]
    predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

    if predicted_id == target_tokenizer.eos_token_id:
        break

    output = tf.concat([output, tf.reshape(predicted_id, (1, 1))], axis=-1)

# トークンを文字列に変換
predicted_sentence = target_tokenizer.decode(tf.squeeze(output[:, :max_seq_length], axis=0).numpy())
print("Input: ", test_sentence)
print("Translation: ", predicted_sentence)
# Out:
# Input:  ohonno somo unukar þan
# Translation:  [CLS] [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]

# %% [markdown]
# ### MT5 Fine-tuning

# %%
from transformers import MT5ForConditionalGeneration, MT5Tokenizer, Trainer, TrainingArguments

model = MT5ForConditionalGeneration.from_pretrained("google/mt5-base")

# %%
train_test_split = ds.train_test_split(test_size=0.2, seed=42)

# 分割されたデータセットを取得
train_dataset = train_test_split["train"]
validation_dataset = train_test_split["test"]

# データセットを結合
dataset = datasets.DatasetDict({"train": train_dataset, "validation": validation_dataset})

# トークナイズ関数を定義
def tokenize_function(examples):
    inputs = examples["ain"]
    targets = examples["jpn"]
    model_inputs = ain_tokenizer(inputs, max_length=128, padding="max_length", truncation=True)
    labels = jpn_tokenizer(targets, max_length=128, padding="max_length", truncation=True)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# Tokenize dataset
tokenized_datasets = dataset.map(tokenize_function, batched=True)

# Arguments
training_args = TrainingArguments(
    output_dir="./mt5_results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
)

# Initialise Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
)

# Train
trainer.train()
# Out:
# Parameter 'function'=<function tokenize_function at 0x7a2312836560> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# WARNING:datasets.fingerprint:Parameter 'function'=<function tokenize_function at 0x7a2312836560> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# Map:   0%|          | 0/4038 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1010 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
#     <div>
#
#       <progress value='1515' max='1515' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1515/1515 28:16, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>35.389100</td>
#       <td>16.195009</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>11.713600</td>
#       <td>4.856948</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.557500</td>
#       <td>3.505664</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1515, training_loss=17.429033008739108, metrics={'train_runtime': 1699.9015, 'train_samples_per_second': 7.126, 'train_steps_per_second': 0.891, 'total_flos': 3631311209889792.0, 'train_loss': 17.429033008739108, 'epoch': 3.0})

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

def translate(text):
    input_ids = ain_tokenizer(text, return_tensors="pt", max_length=128, padding="max_length", truncation=True)
    input_ids = input_ids.to(device)  # 入力テンソルをモデルと同じデバイスに移動
    output = model.generate(**input_ids, max_length=128, num_beams=4, early_stopping=True)
    translated_text = jpn_tokenizer.decode(output[0], skip_special_tokens=True)
    return translated_text

input_text = "ohonno somo unukar þan"
translated_text = translate(input_text)
print("Input:", input_text)
print("Translation:", translated_text)
# Out:
# Input: ohonno somo unukar þan
# Translation: [UNK] [UNK] [UNK] [UNK]

# %%
output_dir = '/content/drive/MyDrive'
model.save_pretrained(output_dir)

# %%
dataset = load_dataset("csv", data_files="train.csv")
dataset = dataset["train"].shuffle(seed=42)

def preprocess_function(examples):
    padding = "max_length"
    max_length = 200

    inputs = [ex for ex in examples["Text"]]
    targets = [ex for ex in examples["Expected"]]
    model_inputs = tokenizer(inputs, max_length=max_length, padding=padding, truncation=True)
    labels = tokenizer(targets, max_length=max_length, padding=padding, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
train_dataset = dataset.map(preprocess_function, batched=True, desc="Running tokenizer")

data_collator = DataCollatorForSeq2Seq(
    tokenizer,
    model=model,
    label_pad_token_id=tokenizer.pad_token_id,
    pad_to_multiple_of=64,
    return_tensors="np")

tf_train_dataset = model.prepare_tf_dataset(
    train_dataset,
    collate_fn=data_collator,
    batch_size=8,
    shuffle=True)

# %%
model.compile(optimizer=Adam(3e-5))
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.fit(tf_train_dataset, epochs=10, callbacks=[early_stopping])
